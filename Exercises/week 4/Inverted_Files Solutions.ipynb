# %% [markdown]
# ## 📚 Exercise 2: Inverted Files - SOLUTIONS
#
# In this exercise, we will understand the functioning of the Inverted Files and how implement them using MapReduce.
#
# ### Overview
#
# We learnt in the lecture that terms are typically stored in an inverted list. Now, in the inverted list, instead of only storing document identifiers of the documents in which the term appears, assume we also store an *offset* of the appearance of a term in a document. An $offset$ of a term $l_k$ given a document is defined as the number of words between the start of the document and $l_k$. Thus our inverted list is now:
#
# $l_k= \langle f_k: \{d_{i_1} \rightarrow [o_1,\ldots,o_{n_{i_1}}]\},
# \{d_{i_2} \rightarrow [o_1,\ldots,o_{n_{i_2}}]\}, \ldots,
# \{d_{i_k} \rightarrow [o_1,\ldots,o_{n_{i_k}}]\} \rangle$
#
# This means that in document $d_{i_1}$ term $l_k$ appears $n_{i_1}$ times and at offset $[o_1,\ldots,o_{n_{i_1}}]$, where $[o_1,\ldots,o_{n_{i_1}}]$ are sorted in ascending order, these type of indices are also known as term-offset indices. An example of a term-offset index is as follows:
#
# **Obama** = $⟨4 : {1 → [3]},{2 → [6]},{3 → [2,17]},{4 → [1]}⟩$
#
# **Governor** = $⟨2 : {4 → [3]}, {7 → [14]}⟩$
#
# **Election** = $⟨4 : {1 → [1]},{2 → [1,21]},{3 → [3]},{5 → [16,22,51]}⟩$
#
# Which is to say that the term **Governor** appear in 2 documents. In document 4 at offset 3, in document 7 at offset 14. Now let us consider the *SLOP/x* operator in text retrieval. This operator has the syntax: *QueryTerm1 SLOP/x QueryTerm2* finds occurrences of *QueryTerm1* within $x$ (but not necessarily in that order) words of *QueryTerm2*, where $x$ is a positive integer argument ($x \geq 1$). Thus $x = 1$ demands that *QueryTerm1* be adjacent to *QueryTerm2*.
#
# ### Questions
#
# 1. List the set of documents that satisfy the query **Obama** *SLOP/2* **Election**.
# 2. List each set of values for which the query **Obama** *SLOP/x* **Election** has a different set of documents as answers (starting from $x = 1$).
# 3. Consider the general procedure for "merging" two term-offset inverted lists for a given document, to determine where the document satisfies a *SLOP/x* clause (since in general there will be many offsets at which each term occurs in a document). Let $L$ denote the total number of occurrences of the two terms in the document. Assume we have a pointer to the list of occurrences of each term and can move the pointer along this list. As we do so we check whether we have a hit for $SLOP/x$ (i.e. the $SLOP/x$ clause is satisfied). Each move of either pointer counts as a step. Based on this assumption is there a general "merging" procedure to determine whether the document satisfies a $SLOP/x$ clause, for which the following is true? Justify your answer.
#
#     1. The merge can be accomplished in a number of steps linear in $L$ regardless of $x$, and we can ensure that each pointer moves only to the right (i.e. forward).
#     2. The merge can be accomplished in a number of steps linear in $L$, but a pointer may be forced to move to the left (i.e. backwards).
#     3. The merge can require $x \times L$ steps in some cases.
#
# **Solution in pdf.**

# %% [markdown]
# ## Create inverted files using MapReduce
# In this exercise, we want to create the inverted files using the MapReduce framework. Write the **map** and **reduce** function.
# Note that the code of **run_mapreduce** is just a simulation of the behavior of  map-reduce system.
#
# ## Goal:
# - Create inverted files using the MapReduce framework.
# - Test the implementation on `epfldocs.txt` data.
#
# ### What you are learning in this exercise:
# - Having a better understanding of inverted files.
# - Learn how to implement inverted files using the MapReduce framework.

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer
import nltk
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
import string
from nltk.corpus import stopwords
import math
from collections import Counter
import numpy as np
nltk.download('stopwords')
nltk.download('punkt')

stemmer = PorterStemmer()

# Tokenize, stem a document
def tokenize(text):
    """
    It tokenizes and stems an input text.
    
    :param text: str, with the input text
    :return: list, of the tokenized and stemmed tokens.
    """
    text = "".join([ch for ch in text if ch not in string.punctuation])
    tokens = nltk.word_tokenize(text)
    return " ".join([stemmer.stem(word.lower()) for word in tokens])

with open("epfldocs.txt") as f:
    content = f.readlines()
original_documents = [x.strip() for x in content] 
documents = [tokenize(d).split() for d in original_documents]
docs_n_doc_ids = list(zip(range(len(documents)), documents))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sebastian/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/sebastian/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Take a pair (doc_id, content). Example: (0, ['how', 'to', 'bake', 'bread', 'without', 'bake', 'recip'])
#Return: list of (word, doc_id). Example: ('bake', 0)
# For simplicity, we assume each mapper handles a document
def map_function(doc_id, content):
    keyvals = []
    for word in content:
        keyvals.append((word, doc_id))
    return keyvals

# %%
# Take a list of pairs (word, doc_id). Example:  [('bake', 0), ('bake', 0), ('bake', 3)]
# Return: (word, frequency, list of document ids). Example ('bake', 3, [0, 0, 3])
# For simplicity, we assume each reducer handles a word
def reduce_function(lst):
    total = 0
    word = lst[0][0]
    doc_ids = []
    for w, doc_id in lst:
        assert(word==w)
        total += 1
        doc_ids.append(doc_id)
    return (word,total, doc_ids)

# %%
# We simulate the mapreduce framework by this function
def run_mapreduce(docs_n_doc_ids):
    # Map phase
    key_values = []
    for doc_id, doc_content in docs_n_doc_ids:
        key_values.extend(map_function(doc_id, doc_content))
    # Shuffle phase
    values = set(map(lambda x:x[0], key_values))
    grouped_key_values = [[y for y in key_values if y[0]==x] for x in values]
    # Reduce phase
    inverted_files = []
    for grouped_key_value in grouped_key_values:
        word, total, doc_ids = reduce_function(grouped_key_value)
        inverted_files.append((word, total, doc_ids))
    return inverted_files

# %%
run_mapreduce(docs_n_doc_ids)
# Out:
# [('relev', 1, [262]),
#  ('gelähmten', 1, [701]),
#  ('httpstco0whox0aktr', 1, [109]),
#  ('httpstcoaskf9ui0mi', 1, [511]),
#  ('httpstcodrtxjxjdzd', 1, [155]),
#  ('httpstcoiawwhc0abh', 1, [550]),
#  ('gafam', 1, [924]),
#  ('rapist', 1, [278]),
#  ('interdisciplinair', 1, [183]),
#  ('promet', 1, [644]),
#  ('laser', 2, [504, 544]),
#  ('qualité', 1, [788]),
#  ('f', 1, [107]),
#  ('dan',
#   20,
#   [81,
#    172,
#    345,
#    382,
#    456,
#    548,
#    554,
#    570,
#    610,
#    665,
#    739,
#    789,
#    825,
#    844,
#    860,
#    876,
#    976,
#    977,
#    983,
#    996]),
#  ('nissan', 2, [387, 387]),
#  ('modul', 3, [694, 890, 959]),
#  ('driver', 3, [387, 387, 804]),
#  ('didnt', 2, [409, 938]),
#  ('prime', 1, [403]),
#  ('enacresearchday', 1, [931]),
#  ('access', 6, [107, 107, 348, 878, 911, 917]),
#  ('httpstcohpzanzzkzi', 1, [900]),
#  ('on🇪🇺eufund', 1, [717]),
#  ('1112', 1, [642]),
#  ('httpstcoxrkh9oamyb', 1, [668]),
#  ('enr', 2, [913, 1070]),
#  ('httpstcojr2dh5kofq', 1, [22]),
#  ('qualifi', 1, [308]),
#  ('dachat', 1, [325]),
#  ('sccerfeebd', 1, [608]),
#  ('seri', 3, [163, 166, 691]),
#  ('100kg', 1, [430]),
#  ('darchitectur', 1, [633]),
#  ('stabil', 5, [66, 289, 377, 551, 628]),
#  ('envscitech', 1, [248]),
#  ('httpstcocgupoky9b', 1, [219]),
#  ('wir', 1, [319]),
#  ('httpstcoptv8wrfg9u', 1, [484]),
#  ('httpstcociezy0jtbm', 1, [750]),
#  ('httpstcod7slk6ruat', 1, [742]),
#  ('will',
#   26,
#   [15,
#    78,
#    102,
#    137,
#    213,
#    223,
#    259,
#    301,
#    365,
#    390,
#    401,
#    422,
#    461,
#    464,
#    479,
#    654,
#    655,
#    722,
#    760,
#    772,
#    791,
#    849,
#    863,
#    870,
#    873,
#    899]),
#  ('prosecitor', 1, [163]),
#  ('shashank', 1, [748]),
#  ('attain', 1, [580]),
#  ('dieser', 1, [105]),
#  ('ucadseneg', 1, [233]),
#  ('riff', 1, [787]),
#  ('httpstcoxnciwuqcxw', 1, [15]),
#  ('silenc', 1, [221]),
#  ('inspect', 1, [53]),
#  ('might', 2, [340, 818]),
#  ('fulltext', 1, [469]),
#  ('impressionnant', 1, [947]),
#  ('fractur', 1, [1030]),
#  ('democrat', 1, [614]),
#  ('eeg', 1, [290]),
#  ('architectur', 9, [77, 123, 232, 376, 453, 455, 714, 788, 788]),
#  ('flipclass', 1, [429]),
#  ('polytechniqu', 5, [98, 164, 482, 841, 1062]),
#  ('weather', 2, [45, 919]),
#  ('place', 12, [0, 0, 137, 283, 429, 560, 764, 873, 886, 976, 977, 1048]),
#  ('europ', 5, [270, 531, 686, 912, 958]),
#  ('recour', 1, [183]),
#  ('intens', 1, [714]),
#  ('cisbat2017', 1, [804]),
#  ('httpstcorssxorvwmg', 1, [957]),
#  ('12', 4, [264, 499, 525, 546]),
#  ('bonjour', 1, [467]),
#  ('stem', 5, [193, 271, 680, 734, 775]),
#  ('andrej', 1, [745]),
#  ('drug', 3, [211, 284, 577]),
#  ('chuvlausann', 6, [266, 352, 437, 494, 701, 922]),
#  ('wirkung', 1, [49]),
#  ('populair', 1, [742]),
#  ('httpstcobh4l44zsmn', 1, [166]),
#  ('httpstcoynvyv7enuk', 1, [222]),
#  ('httpstcooamiwkxmgm', 1, [644]),
#  ('toss2017', 1, [471]),
#  ('learn',
#   27,
#   [33,
#    60,
#    176,
#    194,
#    208,
#    229,
#    231,
#    337,
#    347,
#    347,
#    390,
#    390,
#    411,
#    426,
#    464,
#    587,
#    600,
#    613,
#    623,
#    747,
#    859,
#    872,
#    888,
#    899,
#    974,
#    1009,
#    1048]),
#  ('whose', 1, [979]),
#  ('order', 1, [87]),
#  ('httpstcolzv1sgvsvl', 1, [859]),
#  ('simplifi', 1, [692]),
#  ('sigchi', 1, [435]),
#  ('produit', 1, [283]),
#  ('jimstolz', 1, [898]),
#  ('romandi', 1, [1027]),
#  ('électroniqu', 1, [265]),
#  ('wurd', 1, [338]),
#  ('💡👉httpstcogz0y5vtrij', 1, [99]),
#  ('la',
#   102,
#   [11,
#    11,
#    11,
#    12,
#    12,
#    16,
#    20,
#    26,
#    26,
#    26,
#    26,
#    26,
#    47,
#    51,
#    56,
#    61,
#    61,
#    81,
#    94,
#    118,
#    149,
#    149,
#    149,
#    157,
#    168,
#    182,
#    183,
#    197,
#    199,
#    202,
#    244,
#    252,
#    287,
#    300,
#    304,
#    304,
#    322,
#    325,
#    342,
#    345,
#    357,
#    362,
#    382,
#    383,
#    386,
#    386,
#    392,
#    404,
#    404,
#    452,
#    463,
#    526,
#    565,
#    566,
#    568,
#    584,
#    592,
#    603,
#    604,
#    610,
#    636,
#    644,
#    659,
#    706,
#    723,
#    766,
#    783,
#    784,
#    788,
#    788,
#    800,
#    806,
#    842,
#    844,
#    860,
#    874,
#    894,
#    895,
#    901,
#    902,
#    913,
#    919,
#    923,
#    929,
#    958,
#    958,
#    961,
#    976,
#    977,
#    978,
#    988,
#    996,
#    1016,
#    1016,
#    1018,
#    1022,
#    1030,
#    1030,
#    1042,
#    1054,
#    1066,
#    1066]),
#  ('du',
#   41,
#   [12,
#    20,
#    26,
#    56,
#    63,
#    123,
#    182,
#    243,
#    304,
#    304,
#    311,
#    356,
#    388,
#    495,
#    565,
#    569,
#    592,
#    604,
#    653,
#    766,
#    780,
#    782,
#    800,
#    842,
#    851,
#    862,
#    894,
#    895,
#    902,
#    923,
#    924,
#    947,
#    958,
#    961,
#    967,
#    1016,
#    1030,
#    1042,
#    1043,
#    1063,
#    1068]),
#  ('httpstcoqdxcmza3bv', 1, [47]),
#  ('valentina', 1, [240]),
#  ('condit', 1, [986]),
#  ('httpstcodc4jeabheo', 1, [359]),
#  ('4th', 2, [748, 912]),
#  ('stratocor', 3, [509, 509, 662]),
#  ('r2t2', 1, [735]),
#  ('constant', 1, [848]),
#  ('venez', 3, [243, 983, 1037]),
#  ('microprojector', 1, [624]),
#  ('mylausann', 1, [749]),
#  ('compbio', 1, [30]),
#  ('👉httpstcoplgg4cfe4t', 1, [281]),
#  ('t6ss', 1, [591]),
#  ('httpstcouy5r7w0a9r', 1, [886]),
#  ('réell', 1, [794]),
#  ('httpstcod8i7iov05c', 1, [652]),
#  ('kickoff', 3, [390, 464, 974]),
#  ('agenda', 1, [58]),
#  ('or', 8, [35, 85, 104, 640, 641, 715, 791, 951]),
#  ('chimi', 3, [265, 311, 362]),
#  ('epflsb', 2, [406, 757]),
#  ('630730pm', 1, [464]),
#  ('offer', 9, [60, 73, 138, 184, 246, 332, 606, 839, 914]),
#  ('dtutweet', 2, [71, 1006]),
#  ('dedic', 2, [125, 673]),
#  ('50000', 1, [688]),
#  ('httpstcocmoowb3eh6', 1, [93]),
#  ('elluba', 1, [418]),
#  ('breast', 1, [8]),
#  ('spacewatchm', 1, [798]),
#  ('uzhscienc', 1, [489]),
#  ('membr', 1, [63]),
#  ('psychologist', 1, [507]),
#  ('exzellenz', 1, [954]),
#  ('httpstco1ktfeyqze6', 1, [904]),
#  ('shortli', 1, [108]),
#  ('manag', 4, [510, 515, 640, 673]),
#  ('best', 10, [14, 77, 277, 348, 493, 531, 560, 691, 875, 995]),
#  ('retour', 1, [1049]),
#  ('knecht', 2, [137, 506]),
#  ('julnicola', 1, [478]),
#  ('httpstco9jgkw9qz6x', 1, [550]),
#  ('beibringen', 1, [701]),
#  ('commenc', 3, [331, 452, 1063]),
#  ('neighborhub', 1, [705]),
#  ('hopitauxunig', 3, [116, 357, 437]),
#  ('eight', 1, [984]),
#  ('httpstcodntchhce5l', 1, [541]),
#  ('serendip', 1, [258]),
#  ('httpstco1nu0esmrbg', 1, [759]),
#  ('product', 1, [499]),
#  ('5060', 1, [1068]),
#  ('httpstconjovod2dsn', 1, [243]),
#  ('httpstcomrtgu1nzsl', 1, [1053]),
#  ('physilog®', 1, [786]),
#  ('32', 1, [492]),
#  ('pyeongchang', 1, [706]),
#  ('soin', 1, [386]),
#  ('httpstcoot4yk1wuoo', 1, [493]),
#  ('président', 2, [989, 1022]),
#  ('vie', 2, [266, 705]),
#  ('markram', 1, [818]),
#  ('prêter', 1, [1049]),
#  ('httpstco1zauh8ulfo', 1, [311]),
#  ('justinegdc', 1, [808]),
#  ('55', 1, [150]),
#  ('être', 1, [283]),
#  ('httpstcohqep6odmnw', 1, [33]),
#  ('httpstcoxvevamgjgi', 1, [299]),
#  ('réalitéaugmenté', 1, [251]),
#  ('adelio', 1, [419]),
#  ('httpstco5aowo9rolr', 1, [723]),
#  ('microbi', 1, [555]),
#  ('hessovalai', 5, [130, 200, 205, 742, 829]),
#  ('bulletin', 1, [150]),
#  ('reconcil', 1, [299]),
#  ('rethink', 1, [762]),
#  ('petewarden', 1, [276]),
#  ('httpstcouwfykmcz5p', 1, [297]),
#  ('sil', 1, [467]),
#  ('opticsorg', 1, [317]),
#  ('besoin', 3, [118, 283, 1030]),
#  ('erlaubt', 1, [638]),
#  ('itw', 2, [526, 1068]),
#  ('cruelamom', 1, [582]),
#  ('deploy', 1, [903]),
#  ('httpstcoehgkchyud6', 1, [183]),
#  ('africain', 2, [683, 1010]),
#  ('humbl', 1, [548]),
#  ('délicat', 1, [665]),
#  ('fiber', 3, [544, 544, 959]),
#  ('asemday', 1, [270]),
#  ('begin', 3, [471, 605, 625]),
#  ('said', 1, [938]),
#  ('fsrm', 1, [1005]),
#  ('asia', 2, [270, 531]),
#  ('fab', 1, [916]),
#  ('httpstcomrcygxna6g', 1, [229]),
#  ('passionnant', 1, [895]),
#  ('ladysmith', 1, [272]),
#  ('vont', 1, [1026]),
#  ('sensat', 1, [247]),
#  ('15', 3, [759, 967, 1015]),
#  ('wo', 1, [438]),
#  ('isabel', 1, [801]),
#  ('smile', 1, [894]),
#  ('evalu', 2, [101, 469]),
#  ('organoid', 1, [607]),
#  ('hr', 1, [301]),
#  ('cornavin', 1, [671]),
#  ('httpstcocmhoigyevq', 1, [349]),
#  ('lnco', 1, [247]),
#  ('prépare', 1, [265]),
#  ('daeinar', 2, [213, 479]),
#  ('stupéfiant', 1, [627]),
#  ('beim', 2, [309, 890]),
#  ('robotera', 1, [828]),
#  ('analyz', 1, [690]),
#  ('femm', 1, [488]),
#  ('httpstcojovwcjqzeh', 1, [903]),
#  ('get',
#   19,
#   [5,
#    211,
#    222,
#    348,
#    352,
#    390,
#    464,
#    554,
#    557,
#    649,
#    688,
#    719,
#    941,
#    953,
#    979,
#    985,
#    1006,
#    1046,
#    1065]),
#  ('httpstcoym6u32ngfp', 1, [566]),
#  ('ai',
#   23,
#   [21,
#    27,
#    50,
#    97,
#    165,
#    181,
#    198,
#    236,
#    323,
#    414,
#    448,
#    501,
#    534,
#    580,
#    581,
#    610,
#    692,
#    722,
#    747,
#    765,
#    899,
#    946,
#    999]),
#  ('httpstcom3h6iyav3k', 1, [44]),
#  ('commun', 4, [301, 387, 519, 910]),
#  ('roi', 1, [98]),
#  ('join',
#   18,
#   [27,
#    46,
#    245,
#    246,
#    320,
#    391,
#    420,
#    493,
#    503,
#    623,
#    623,
#    654,
#    733,
#    741,
#    757,
#    946,
#    990,
#    1003]),
#  ('httpstcoslz0pbxvi', 1, [1029]),
#  ('sa\u200b', 1, [1053]),
#  ('year',
#   16,
#   [104,
#    263,
#    263,
#    264,
#    267,
#    267,
#    525,
#    531,
#    550,
#    716,
#    820,
#    886,
#    979,
#    987,
#    1014,
#    1041]),
#  ('pecub', 1, [1035]),
#  ('transform', 4, [9, 555, 774, 815]),
#  ('oskarfreysing', 1, [979]),
#  ('amit', 1, [469]),
#  ('manif', 1, [988]),
#  ('hightech', 2, [898, 901]),
#  ('mieux', 7, [383, 543, 610, 627, 976, 977, 978]),
#  ('newslett', 1, [929]),
#  ('rive', 2, [167, 252]),
#  ('artificiel', 3, [62, 610, 942]),
#  ('irrat', 1, [1056]),
#  ('nanostructur', 4, [113, 193, 332, 680]),
#  ('tini', 1, [1000]),
#  ('broadspectrum', 1, [577]),
#  ('jouer', 1, [983]),
#  ('seront', 1, [554]),
#  ('httpstcojkeufaeydp', 1, [897]),
#  ('httpstcoqnooqf1xmm', 1, [334]),
#  ('overdu', 1, [768]),
#  ('flyerlft', 1, [375]),
#  ('class', 3, [383, 429, 882]),
#  ('scm2018', 2, [203, 662]),
#  ('dem', 1, [188]),
#  ('erfahrung', 1, [309]),
#  ('hasti', 1, [938]),
#  ('realli', 8, [58, 260, 353, 387, 691, 790, 938, 999]),
#  ('httpstcoitu0ssebug', 1, [892]),
#  ('présentat', 2, [20, 947]),
#  ('while', 2, [938, 960]),
#  ('politonew', 2, [196, 639]),
#  ('child', 1, [979]),
#  ('watch', 11, [17, 84, 99, 301, 353, 459, 613, 635, 649, 718, 992]),
#  ('fort', 1, [543]),
#  ('klein', 1, [319]),
#  ('fifpro', 1, [291]),
#  ('httpstcormj8q7zfkl', 1, [161]),
#  ('solarpow', 1, [870]),
#  ('deepartio', 1, [612]),
#  ('ml', 7, [34, 97, 347, 501, 691, 899, 899]),
#  ('liaison', 1, [821]),
#  ('lepfl', 6, [47, 182, 385, 584, 877, 1040]),
#  ('stflour', 1, [535]),
#  ('contrib', 1, [740]),
#  ('campus…', 1, [326]),
#  ('yunchul', 1, [210]),
#  ('présentent', 1, [889]),
#  ('polyvalent', 1, [894]),
#  ('feather', 1, [1055]),
#  ('swisscom', 2, [62, 605]),
#  ('httpstcovktvhlb0el', 1, [880]),
#  ('protect', 3, [41, 124, 830]),
#  ('automat', 1, [734]),
#  ('meilleurduwebch', 1, [973]),
#  ('berlin', 2, [422, 642]),
#  ('développeur', 1, [862]),
#  ('httpstco8staqsmknh', 1, [84]),
#  ('cryogen', 1, [916]),
#  ('multipl', 1, [180]),
#  ('lextensoetudian', 2, [61, 682]),
#  ('titl', 2, [103, 845]),
#  ('post', 1, [286]),
#  ('mossoul', 1, [1067]),
#  ('rule', 1, [291]),
#  ('perditab', 1, [661]),
#  ('inscript', 2, [277, 958]),
#  ('center',
#   17,
#   [54,
#    194,
#    390,
#    443,
#    464,
#    476,
#    480,
#    546,
#    606,
#    640,
#    829,
#    872,
#    973,
#    974,
#    992,
#    1009,
#    1048]),
#  ('httpstcot3lufzpnhx', 1, [451]),
#  ('httpstco6lmgbkcsdb', 1, [76]),
#  ('cosi', 1, [265]),
#  ('femtoprint', 1, [225]),
#  ('epflenac',
#   14,
#   [202, 299, 400, 400, 421, 446, 512, 601, 608, 710, 736, 867, 881, 931]),
#  ('intern', 11, [121, 139, 220, 631, 632, 684, 759, 807, 817, 934, 959]),
#  ('battin', 1, [119]),
#  ('httpstcotcovytrn9i', 1, [983]),
#  ('carboneutr', 1, [996]),
#  ('code', 8, [233, 347, 525, 528, 636, 707, 742, 752]),
#  ('mélodi', 1, [942]),
#  ('stone', 1, [293]),
#  ('spectacl', 1, [604]),
#  ('httpstcolqtqqyt5mx', 1, [224]),
#  ('ditmai', 1, [659]),
#  ('horizon2020ict', 1, [457]),
#  ('archizoom', 1, [453]),
#  ('1200cet', 1, [992]),
#  ('ist', 3, [105, 167, 319]),
#  ('httpstcodoj2hmekbc', 1, [828]),
#  ('httpstcormxjlczif6', 1, [64]),
#  ('pest', 1, [485]),
#  ('swisseconom', 1, [1041]),
#  ('pic', 2, [375, 1005]),
#  ('georgio', 1, [1027]),
#  ('presidentielle2017', 1, [825]),
#  ('doc', 1, [840]),
#  ('stop', 5, [131, 134, 142, 532, 997]),
#  ('beer', 2, [416, 416]),
#  ('httpstco6tiu1sc7oi', 1, [601]),
#  ('httpstcoarkwnybioy', 1, [471]),
#  ('httpstcotavirrwpkc', 1, [178]),
#  ('httpstco6yigv1nt', 1, [421]),
#  ('lymphoma', 1, [35]),
#  ('hypocr', 1, [862]),
#  ('trumpinaugur', 1, [936]),
#  ('httpstcoxcrufbsg5a', 1, [524]),
#  ('httpstco6uwi3r9ku', 1, [587]),
#  ('pratt', 1, [189]),
#  ('mobilitätswend', 1, [1011]),
#  ('dominiqueforay', 2, [126, 704]),
#  ('erstmal', 1, [638]),
#  ('chemistri', 5, [171, 275, 720, 743, 847]),
#  ('amparistech', 1, [654]),
#  ('débutent', 1, [56]),
#  ('sensima', 1, [53]),
#  ('dario', 1, [318]),
#  ('rapid', 1, [726]),
#  ('genom', 4, [228, 284, 352, 358]),
#  ('revolution', 3, [69, 136, 856]),
#  ('articl', 11, [74, 103, 243, 407, 526, 705, 808, 844, 856, 905, 986]),
#  ('httpstcogq9outmsd4', 1, [399]),
#  ('belt', 1, [598]),
#  ('lectur', 10, [32, 107, 164, 223, 293, 371, 413, 600, 816, 859]),
#  ('variou', 1, [65]),
#  ('current', 5, [242, 307, 731, 903, 903]),
#  ('joystick', 1, [102]),
#  ('diaspora', 1, [746]),
#  ('5ten', 1, [1011]),
#  ('créatif', 1, [363]),
#  ('appli',
#   14,
#   [33, 60, 196, 222, 260, 337, 347, 422, 576, 640, 676, 688, 899, 987]),
#  ('scientif', 2, [13, 103]),
#  ('httpstco6epuivmddz', 1, [586]),
#  ('privé', 3, [467, 574, 821]),
#  ('lifespan', 1, [55]),
#  ('devic', 1, [878]),
#  ('investig', 4, [303, 446, 661, 979]),
#  ('advantag', 1, [341]),
#  ('httpstcocixq0xhiu9', 1, [657]),
#  ('number', 1, [519]),
#  ('news', 2, [4, 630]),
#  ('flexibl', 1, [440]),
#  ('limport', 2, [160, 181]),
#  ('slingshot', 1, [746]),
#  ('swissquotefr', 1, [538]),
#  ('httpstcoh9i17a12yx', 1, [380]),
#  ('salon', 1, [902]),
#  ('strong', 5, [103, 116, 150, 187, 640]),
#  ('httpstcoiewa0fhu09', 1, [227]),
#  ('httpstco8hjddrifxi', 1, [238]),
#  ('healthyag', 1, [588]),
#  ('deadpooly96', 1, [637]),
#  ('rtsi', 1, [144]),
#  ('httpstcoz5czqofiyv', 1, [879]),
#  ('adnovum', 1, [700]),
#  ('httpstcov534v2bsnc', 1, [334]),
#  ('chocol', 1, [253]),
#  ('gem', 2, [262, 674]),
#  ('dphroy', 1, [735]),
#  ('httpstco8hh2xacpdn', 1, [139]),
#  ('httpstcokrppxbgqqk', 1, [537]),
#  ('psd', 1, [965]),
#  ('and',
#   215,
#   [0,
#    10,
#    10,
#    13,
#    27,
#    27,
#    28,
#    34,
#    42,
#    44,
#    59,
#    64,
#    65,
#    65,
#    66,
#    68,
#    68,
#    68,
#    68,
#    78,
#    80,
#    86,
#    101,
#    103,
#    103,
#    108,
#    108,
#    108,
#    109,
#    112,
#    116,
#    121,
#    121,
#    124,
#    125,
#    126,
#    126,
#    138,
#    139,
#    142,
#    150,
#    164,
#    166,
#    166,
#    170,
#    171,
#    175,
#    176,
#    185,
#    190,
#    191,
#    193,
#    195,
#    210,
#    210,
#    217,
#    220,
#    229,
#    250,
#    250,
#    258,
#    259,
#    262,
#    263,
#    263,
#    264,
#    269,
#    272,
#    284,
#    290,
#    290,
#    291,
#    292,
#    292,
#    294,
#    296,
#    299,
#    301,
#    307,
#    308,
#    313,
#    315,
#    321,
#    328,
#    334,
#    336,
#    337,
#    339,
#    339,
#    341,
#    341,
#    348,
#    352,
#    352,
#    376,
#    376,
#    390,
#    390,
#    401,
#    409,
#    416,
#    419,
#    419,
#    427,
#    440,
#    442,
#    449,
#    458,
#    458,
#    464,
#    468,
#    469,
#    485,
#    498,
#    501,
#    507,
#    513,
#    515,
#    518,
#    518,
#    525,
#    526,
#    526,
#    527,
#    531,
#    545,
#    547,
#    557,
#    561,
#    561,
#    575,
#    575,
#    577,
#    585,
#    589,
#    598,
#    606,
#    613,
#    623,
#    625,
#    626,
#    628,
#    639,
#    639,
#    641,
#    641,
#    642,
#    650,
#    658,
#    660,
#    662,
#    663,
#    666,
#    671,
#    671,
#    671,
#    675,
#    678,
#    679,
#    686,
#    688,
#    689,
#    690,
#    694,
#    699,
#    699,
#    703,
#    719,
#    724,
#    733,
#    734,
#    741,
#    743,
#    743,
#    745,
#    745,
#    756,
#    777,
#    785,
#    798,
#    807,
#    813,
#    820,
#    820,
#    830,
#    830,
#    845,
#    847,
#    850,
#    858,
#    859,
#    866,
#    869,
#    873,
#    898,
#    905,
#    908,
#    928,
#    933,
#    938,
#    941,
#    959,
#    960,
#    973,
#    981,
#    982,
#    995,
#    1014,
#    1036,
#    1036,
#    1036,
#    1046,
#    1060,
#    1065,
#    1072]),
#  ('natureinspir', 1, [379]),
#  ('anyth', 1, [585]),
#  ('cyber', 1, [1048]),
#  ('woman', 1, [956]),
#  ('“', 12, [18, 69, 103, 166, 212, 260, 292, 393, 497, 504, 863, 985]),
#  ('swisscomm', 1, [212]),
#  ('cholera', 1, [738]),
#  ('eaten', 1, [1033]),
#  ('exhibit', 2, [93, 914]),
#  ('httpstcold04jbxpsw', 1, [978]),
#  ('territori', 1, [261]),
#  ('farm', 1, [2]),
#  ('riponn', 2, [976, 977]),
#  ('fiwar', 1, [549]),
#  ('httpstcojw8swvtltq', 1, [494]),
#  ('signé', 1, [423]),
#  ('vrai', 2, [659, 687]),
#  ('marco', 1, [209]),
#  ('évalu', 1, [788]),
#  ('kind', 1, [414]),
#  ('httpstco16zzhx0prn', 1, [843]),
#  ('contr', 2, [603, 740]),
#  ('am', 7, [48, 52, 167, 338, 582, 741, 863]),
#  ('httpstcor3zicsbwcc', 1, [314]),
#  ('deliveri', 1, [1061]),
#  ('par',
#   22,
#   [157,
#    160,
#    172,
#    197,
#    261,
#    327,
#    382,
#    383,
#    404,
#    495,
#    627,
#    633,
#    651,
#    665,
#    844,
#    862,
#    955,
#    1010,
#    1018,
#    1022,
#    1054,
#    1068]),
#  ('focu', 2, [754, 911]),
#  ('quantum', 8, [44, 113, 328, 377, 395, 527, 551, 865]),
#  ('mental', 1, [627]),
#  ('développé', 1, [129]),
#  ('laboratori', 4, [18, 343, 512, 617]),
#  ('1012', 1, [107]),
#  ('thinksportsuccessstori', 1, [1060]),
#  ('bibliothèqu', 2, [157, 197]),
#  ('httpstcoqzv4saerzq', 1, [178]),
#  ('airsportsfai', 1, [888]),
#  ('httpstcobymmkjagz1', 1, [1042]),
#  ('studio', 1, [453]),
#  ('fabienfontannaz', 1, [163]),
#  ('misus', 1, [201]),
#  ('disgrac', 1, [281]),
#  ('wed', 1, [301]),
#  ('appliedmlday', 8, [34, 127, 276, 501, 503, 572, 605, 612]),
#  ('biorobot', 1, [169]),
#  ('rais', 2, [499, 1014]),
#  ('resid', 1, [210]),
#  ('7', 6, [167, 252, 390, 519, 631, 979]),
#  ('we',
#   36,
#   [60,
#    65,
#    65,
#    78,
#    98,
#    108,
#    134,
#    134,
#    191,
#    203,
#    221,
#    223,
#    247,
#    264,
#    281,
#    307,
#    333,
#    346,
#    353,
#    414,
#    445,
#    572,
#    580,
#    601,
#    671,
#    703,
#    760,
#    802,
#    863,
#    886,
#    909,
#    935,
#    963,
#    1013,
#    1046,
#    1065]),
#  ('yosef', 1, [910]),
#  ('without', 4, [109, 221, 361, 750]),
#  ('httpstcoiluaoazwju', 1, [1014]),
#  ('europarlen…', 3, [1057, 1058, 1059]),
#  ('research',
#   57,
#   [8,
#    30,
#    35,
#    45,
#    64,
#    74,
#    88,
#    98,
#    110,
#    135,
#    140,
#    146,
#    201,
#    213,
#    316,
#    340,
#    376,
#    397,
#    398,
#    440,
#    444,
#    448,
#    479,
#    502,
#    507,
#    544,
#    547,
#    577,
#    585,
#    597,
#    609,
#    626,
#    628,
#    639,
#    673,
#    676,
#    697,
#    709,
#    712,
#    728,
#    741,
#    754,
#    755,
#    771,
#    786,
#    804,
#    835,
#    865,
#    897,
#    903,
#    914,
#    931,
#    931,
#    945,
#    966,
#    997,
#    1033]),
#  ('former', 5, [390, 493, 741, 874, 978]),
#  ('httpstconskyrpea6b', 1, [447]),
#  ('ngi4eu', 1, [549]),
#  ('httpstcoyrkoycbsl', 1, [1022]),
#  ('jmlatt', 3, [356, 603, 857]),
#  ('honor', 1, [258]),
#  ('gut', 1, [105]),
#  ('découvert', 2, [266, 895]),
#  ('kickstartacceler', 1, [386]),
#  ('aziz', 1, [55]),
#  ('httpstcobtfmcsw0xp', 1, [970]),
#  ('klok', 1, [336]),
#  ('httpstcomwb4zuqjjo', 1, [1062]),
#  ('predict', 2, [127, 557]),
#  ('fribourg', 1, [705]),
#  ('findet', 1, [167]),
#  ('ed', 1, [119]),
#  ('transbord', 1, [519]),
#  ('🦈💦', 1, [860]),
#  ('sme', 1, [321]),
#  ('forêt', 3, [543, 653, 784]),
#  ('cisdk', 1, [684]),
#  ('ericdubay', 2, [99, 240]),
#  ('3', 7, [53, 538, 555, 840, 894, 989, 1064]),
#  ('httpstcobkliewfcro', 1, [100]),
#  ('réaménag', 1, [1063]),
#  ('emr', 1, [484]),
#  ('chaqu', 1, [925]),
#  ('finland', 1, [102]),
#  ('httpstcosi9sz9cxpv', 1, [257]),
#  ('insect', 3, [74, 379, 835]),
#  ('dsmeu', 3, [140, 263, 549]),
#  ('softrobots……………', 1, [1046]),
#  ('sinc', 1, [720]),
#  ('irrespect', 1, [1044]),
#  ('deconvolutionlab2', 2, [80, 100]),
#  ('lead', 7, [139, 237, 354, 558, 577, 712, 966]),
#  ('minh', 1, [658]),
#  ('webot', 1, [74]),
#  ('soon', 3, [963, 972, 998]),
#  ('kurs', 1, [167]),
#  ('go', 12, [323, 347, 430, 471, 525, 542, 572, 772, 981, 999, 1006, 1036]),
#  ('votr', 6, [12, 160, 548, 665, 848, 1048]),
#  ('studenten', 1, [309]),
#  ('workshop',
#   18,
#   [68,
#    78,
#    148,
#    176,
#    337,
#    337,
#    347,
#    347,
#    525,
#    645,
#    700,
#    709,
#    756,
#    886,
#    899,
#    906,
#    941,
#    999]),
#  ('surround', 1, [1032]),
#  ('isadilenardo', 1, [316]),
#  ('b3', 1, [149]),
#  ('fev', 1, [144]),
#  ('from',
#   77,
#   [22,
#    30,
#    32,
#    59,
#    59,
#    83,
#    89,
#    100,
#    108,
#    164,
#    223,
#    227,
#    247,
#    260,
#    271,
#    276,
#    303,
#    318,
#    335,
#    359,
#    365,
#    365,
#    409,
#    413,
#    414,
#    416,
#    427,
#    427,
#    444,
#    464,
#    469,
#    481,
#    486,
#    499,
#    507,
#    515,
#    532,
#    535,
#    535,
#    545,
#    562,
#    563,
#    575,
#    587,
#    591,
#    593,
#    607,
#    608,
#    614,
#    615,
#    622,
#    630,
#    648,
#    655,
#    663,
#    694,
#    694,
#    712,
#    731,
#    734,
#    734,
#    735,
#    738,
#    765,
#    776,
#    831,
#    847,
#    849,
#    849,
#    855,
#    905,
#    930,
#    966,
#    992,
#    1013,
#    1033,
#    1064]),
#  ('begreifbar', 1, [48]),
#  ('😊💪', 1, [56]),
#  ('onlineschul', 1, [188]),
#  ('cyclobiblio', 1, [194]),
#  ('seht', 1, [319]),
#  ('san', 4, [70, 351, 927, 963]),
#  ('gender', 2, [60, 646]),
#  ('httpstco2eruzdhgxv', 1, [610]),
#  ('domest', 1, [228]),
#  ('built', 3, [442, 1014, 1055]),
#  ('resumé', 1, [181]),
#  ('souvent', 1, [840]),
#  ('irak', 1, [1067]),
#  ('inscrivezv', 1, [929]),
#  ('httpstcoeac5pmdphr', 1, [1046]),
#  ('httpstcobid211ncnp', 1, [558]),
#  ('httpstcoxorkl6jcgv', 1, [1071]),
#  ('healthi', 3, [131, 532, 997]),
#  ('interessant', 1, [969]),
#  ('no8', 1, [4]),
#  ('grâce', 1, [882]),
#  ('alway', 1, [689]),
#  ('jeu', 1, [633]),
#  ('siemen', 1, [522]),
#  ('httpstco6ztzov8ylh', 1, [837]),
#  ('httpstcobeqgfwefwz', 1, [1021]),
#  ('uniarct', 1, [1025]),
#  ('mensch', 1, [425]),
#  ('designresearch', 1, [245]),
#  ('httpstcozie2dckwsg', 1, [1055]),
#  ('multimedia', 1, [114]),
#  ('stay', 5, [78, 125, 722, 813, 836]),
#  ('epflcdm', 1, [817]),
#  ('deliv', 2, [124, 223]),
#  ('visibl', 1, [746]),
#  ('nicerbettermor', 1, [685]),
#  ('itfaconfer', 3, [294, 468, 468]),
#  ('31', 2, [250, 272]),
#  ('éternel', 1, [570]),
#  ('✌🏽🌱', 1, [253]),
#  ('who', 11, [99, 245, 323, 511, 576, 699, 743, 764, 778, 795, 813]),
#  ('fatti', 1, [298]),
#  ('17h', 1, [967]),
#  ('glisser', 1, [548]),
#  ('poser', 1, [467]),
#  ('cortex', 1, [290]),
#  ('solvingproblem', 1, [714]),
#  ('ucl', 1, [303]),
#  ('httpstcocodsk7agck', 1, [516]),
#  ('tablet', 2, [435, 533]),
#  ('moi', 1, [706]),
#  ('httpstcopxrazr8xo1', 1, [245]),
#  ('gefordert', 1, [338]),
#  ('ageficom', 2, [742, 905]),
#  ('manquez', 1, [604]),
#  ('httpstcohwhjoi3lw5', 1, [865]),
#  ('carbon', 2, [575, 918]),
#  ('httpstcoudxvqdi2no', 1, [437]),
#  ('addit', 3, [327, 883, 884]),
#  ('httpstcox56decpc0n', 1, [354]),
#  ('httpstcolyf2gfihav', 1, [486]),
#  ('formid', 1, [12]),
#  ('ihr', 2, [309, 319]),
#  ('lesopb', 1, [442]),
#  ('gisiq', 1, [441]),
#  ('ins2017', 1, [114]),
#  ('pie', 1, [383]),
#  ('bern', 2, [480, 523]),
#  ('roysocchem', 1, [807]),
#  ('2030agenda', 1, [541]),
#  ('httpstcopuml0rsj8d', 1, [782]),
#  ('bouri', 1, [861]),
#  ('petit', 1, [467]),
#  ('httpstcousyuegvzb9', 1, [410]),
#  ('microenvironment', 1, [32]),
#  ('helga', 1, [210]),
#  ('savanna', 1, [235]),
#  ('2015', 1, [241]),
#  ('45th', 1, [550]),
#  ('kinemat', 1, [786]),
#  ('httpstcohwhyyevln4', 1, [987]),
#  ('httpstcot4tf9ynf4c', 1, [649]),
#  ('httpstcogtxlhi6lt', 1, [5]),
#  ('champion', 3, [180, 487, 990]),
#  ('httpstcoxddm5pf3d', 1, [263]),
#  ('subwavelength', 1, [36]),
#  ('nsf', 1, [697]),
#  ('cytometri', 5, [98, 203, 365, 509, 578]),
#  ('ailleur', 1, [896]),
#  ('hubaux', 2, [182, 724]),
#  ('big', 4, [315, 442, 625, 731]),
#  ('dtsbourg', 2, [65, 312]),
#  ('elsevierchemist', 1, [745]),
#  ('sestrin1', 1, [35]),
#  ('catalyt', 1, [334]),
#  ('détruir', 1, [789]),
#  ('bon', 3, [168, 325, 682]),
#  ('wslresearch', 4, [526, 653, 785, 984]),
#  ('deserv', 1, [413]),
#  ('documentalist', 1, [439]),
#  ('surtout', 1, [1049]),
#  ('smartbuild', 1, [510]),
#  ('forumwslsuisseromand', 1, [653]),
#  ('magnet', 1, [558]),
#  ('httpstcozkvrbayrqw', 1, [830]),
#  ('iranian', 2, [359, 556]),
#  ('decisionmak', 2, [692, 755]),
#  ('compress', 1, [855]),
#  ('gratzel', 1, [296]),
#  ('essentiel', 1, [636]),
#  ('letemp', 4, [295, 610, 665, 844]),
#  ('oncl', 1, [927]),
#  ('fabriqu', 1, [877]),
#  ('smlotzd', 1, [732]),
#  ('again', 2, [646, 1029]),
#  ('angewchem', 1, [550]),
#  ('preserv', 1, [299]),
#  ('pervert', 1, [979]),
#  ('rate', 1, [834]),
#  ('aid', 1, [861]),
#  ('httpstco9f2iuduopr', 1, [1008]),
#  ('httpstcolznfvtycr7', 1, [645]),
#  ('passport', 1, [1073]),
#  ('goal', 1, [126]),
#  ('mesot', 1, [785]),
#  ('didn', 1, [692]),
#  ('chief', 1, [629]),
#  ('httpstcoassaroj5bc', 1, [739]),
#  ('appreci', 1, [151]),
#  ('pentacen', 2, [303, 303]),
#  ('httpstcoqdj5vmkuwu', 1, [1049]),
#  ('nrel', 5, [398, 595, 681, 771, 834]),
#  ('elfirepfl', 1, [30]),
#  ('académiqu', 1, [182]),
#  ('httpstcoebjlvalhzz', 1, [133]),
#  ('mytechni', 1, [800]),
#  ('httpstcoa5in0tcls7', 1, [731]),
#  ('fret', 1, [959]),
#  ('action', 2, [541, 549]),
#  ('lespac', 1, [570]),
#  ('httpstcomyvdqpm7r4', 1, [394]),
#  ('war', 1, [890]),
#  ('lallianc', 1, [565]),
#  ('6', 5, [90, 175, 272, 767, 975]),
#  ('airbnb', 6, [324, 507, 507, 692, 692, 832]),
#  ('oh', 1, [620]),
#  ('roberv', 1, [710]),
#  ('lhistoir', 1, [1022]),
#  ('iso', 4, [199, 682, 739, 840]),
#  ('believ', 1, [278]),
#  ('david', 1, [916]),
#  ('smattheydoret', 1, [437]),
#  ('fourthrevolut', 1, [22]),
#  ('ecommerc', 1, [733]),
#  ('tisseo', 1, [857]),
#  ('uni', 1, [1014]),
#  ('garfieldabh', 1, [1019]),
#  ('httpstcoaz7xlfk3da', 1, [961]),
#  ('httpstcoit0sbqlkqc', 1, [228]),
#  ('born', 2, [221, 231]),
#  ('tout', 4, [63, 356, 382, 740]),
#  ('httpstcogyclie4vhl', 1, [1054]),
#  ('oxid', 1, [334]),
#  ('smartciti', 1, [963]),
#  ('oneshot', 2, [332, 680]),
#  ('epflen',
#   324,
#   [0,
#    1,
#    3,
#    10,
#    13,
#    15,
#    17,
#    19,
#    21,
#    22,
#    24,
#    30,
#    35,
#    36,
#    37,
#    38,
#    39,
#    41,
#    44,
#    45,
#    48,
#    50,
#    53,
#    54,
#    58,
#    64,
#    65,
#    65,
#    67,
#    71,
#    72,
#    73,
#    76,
#    78,
#    79,
#    82,
#    84,
#    89,
#    95,
#    109,
#    110,
#    111,
#    113,
#    114,
#    117,
#    119,
#    120,
#    121,
#    126,
#    127,
#    128,
#    132,
#    139,
#    142,
#    148,
#    152,
#    153,
#    155,
#    156,
#    159,
#    161,
#    169,
#    170,
#    173,
#    177,
#    179,
#    186,
#    187,
#    196,
#    200,
#    206,
#    211,
#    214,
#    215,
#    219,
#    222,
#    225,
#    227,
#    228,
#    238,
#    242,
#    251,
#    254,
#    256,
#    257,
#    258,
#    262,
#    270,
#    271,
#    280,
#    286,
#    288,
#    293,
#    294,
#    295,
#    298,
#    301,
#    312,
#    318,
#    319,
#    321,
#    324,
#    328,
#    332,
#    336,
#    337,
#    339,
#    349,
#    354,
#    355,
#    360,
#    361,
#    364,
#    365,
#    372,
#    376,
#    377,
#    379,
#    389,
#    394,
#    395,
#    398,
#    399,
#    406,
#    410,
#    414,
#    415,
#    418,
#    421,
#    425,
#    426,
#    430,
#    432,
#    434,
#    441,
#    442,
#    443,
#    445,
#    450,
#    457,
#    461,
#    464,
#    465,
#    468,
#    469,
#    473,
#    474,
#    478,
#    480,
#    482,
#    484,
#    486,
#    490,
#    493,
#    499,
#    501,
#    504,
#    505,
#    506,
#    507,
#    508,
#    510,
#    512,
#    513,
#    515,
#    517,
#    522,
#    524,
#    525,
#    527,
#    529,
#    532,
#    534,
#    535,
#    538,
#    539,
#    542,
#    546,
#    549,
#    557,
#    558,
#    562,
#    573,
#    580,
#    581,
#    587,
#    591,
#    593,
#    597,
#    600,
#    601,
#    605,
#    606,
#    608,
#    612,
#    613,
#    615,
#    616,
#    617,
#    620,
#    622,
#    623,
#    624,
#    630,
#    635,
#    639,
#    643,
#    645,
#    646,
#    649,
#    652,
#    656,
#    657,
#    660,
#    661,
#    668,
#    669,
#    670,
#    671,
#    675,
#    678,
#    686,
#    692,
#    693,
#    694,
#    698,
#    699,
#    700,
#    702,
#    703,
#    704,
#    707,
#    708,
#    709,
#    712,
#    717,
#    718,
#    722,
#    725,
#    732,
#    736,
#    741,
#    749,
#    753,
#    754,
#    758,
#    760,
#    764,
#    766,
#    771,
#    772,
#    777,
#    779,
#    787,
#    790,
#    790,
#    803,
#    809,
#    810,
#    810,
#    811,
#    816,
#    817,
#    818,
#    820,
#    830,
#    831,
#    833,
#    834,
#    838,
#    839,
#    846,
#    852,
#    853,
#    854,
#    856,
#    858,
#    859,
#    863,
#    865,
#    867,
#    875,
#    880,
#    883,
#    884,
#    888,
#    897,
#    898,
#    909,
#    910,
#    912,
#    914,
#    916,
#    917,
#    918,
#    932,
#    933,
#    934,
#    940,
#    943,
#    949,
#    965,
#    966,
#    968,
#    970,
#    972,
#    973,
#    974,
#    982,
#    984,
#    987,
#    994,
#    995,
#    997,
#    1000,
#    1002,
#    1006,
#    1007,
#    1012,
#    1027,
#    1029,
#    1055,
#    1056,
#    1074]),
#  ('vuill', 1, [107]),
#  ('han', 1, [1015]),
#  ('powder', 1, [289]),
#  ('luckili', 1, [1013]),
#  ('polarfound', 1, [108]),
#  ('gosh', 1, [393]),
#  ('httpstcoh5x6sei7od', 1, [387]),
#  ('personalis', 1, [758]),
#  ('i',
#   41,
#   [8,
#    21,
#    52,
#    108,
#    122,
#    163,
#    278,
#    278,
#    367,
#    393,
#    409,
#    409,
#    409,
#    411,
#    413,
#    413,
#    461,
#    491,
#    509,
#    580,
#    582,
#    685,
#    691,
#    692,
#    692,
#    731,
#    751,
#    764,
#    768,
#    812,
#    813,
#    813,
#    863,
#    910,
#    938,
#    938,
#    945,
#    957,
#    987,
#    1034,
#    1034]),
#  ('httpstco3bjtbr7d5l', 1, [892]),
#  ('adrien', 1, [855]),
#  ('storag', 3, [117, 558, 575]),
#  ('julienguex', 1, [800]),
#  ('incubateur', 1, [297]),
#  ('sérieux', 1, [392]),
#  ('carmelatroncoso', 1, [68]),
#  ('httpstcot9zid3kv0c', 1, [237]),
#  ('robohub', 1, [699]),
#  ('httpstcoevlw3kf6v', 1, [998]),
#  ('forschung', 1, [822]),
#  ('httpstcovhhnid4xqm', 1, [944]),
#  ('laptop', 1, [979]),
#  ('stormi', 1, [919]),
#  ('circular', 1, [46]),
#  ('cyberattack', 1, [321]),
#  ('compromi', 1, [592]),
#  ('landesmuseum', 1, [844]),
#  ('marc', 1, [900]),
#  ('unigenova', 1, [639]),
#  ('est',
#   15,
#   [61,
#    252,
#    382,
#    604,
#    627,
#    627,
#    627,
#    659,
#    665,
#    729,
#    766,
#    929,
#    996,
#    1016,
#    1031]),
#  ('httpstcow4ax9gcawo', 1, [440]),
#  ('royes', 1, [290]),
#  ('wasserstein', 1, [859]),
#  ('thiel', 1, [957]),
#  ('richter', 1, [1053]),
#  ('httpstcog0hzwjpurg', 1, [465]),
#  ('veri', 11, [125, 260, 293, 307, 333, 575, 629, 771, 808, 830, 963]),
#  ('maxplanckpress', 1, [303]),
#  ('httpstcoxfrvqn5ceu', 1, [626]),
#  ('cesmichigan', 2, [294, 468]),
#  ('kornatowski', 1, [960]),
#  ('particularli', 1, [323]),
#  ('httpstcogos2e6k7ba', 1, [303]),
#  ('httpstco42qaeby17w', 1, [452]),
#  ('avoir', 2, [752, 939]),
#  ('readership', 1, [935]),
#  ('vraiment', 1, [627]),
#  ('httpstcon8diph71tu', 1, [582]),
#  ('no', 8, [65, 107, 236, 615, 620, 674, 938, 979]),
#  ('thereof', 1, [166]),
#  ('httpstcoeomfj5c9rg', 1, [422]),
#  ('mister', 2, [330, 819]),
#  ('venir', 2, [604, 627]),
#  ('although', 1, [685]),
#  ('demonstr', 2, [104, 909]),
#  ('measur', 6, [86, 184, 186, 242, 361, 508]),
#  ('httpstco9j5gplmcoi', 1, [481]),
#  ('cargobik', 1, [944]),
#  ('propriété', 1, [923]),
#  ('microchip', 1, [636]),
#  ('ein', 5, [49, 209, 638, 721, 721]),
#  ('loch', 1, [189]),
#  ('032017', 1, [862]),
#  ('gillet', 1, [921]),
#  ('an',
#   53,
#   [18,
#    21,
#    50,
#    91,
#    103,
#    119,
#    167,
#    198,
#    217,
#    264,
#    268,
#    290,
#    303,
#    309,
#    321,
#    341,
#    350,
#    393,
#    393,
#    414,
#    474,
#    524,
#    556,
#    576,
#    585,
#    613,
#    616,
#    619,
#    628,
#    640,
#    713,
#    717,
#    722,
#    724,
#    733,
#    741,
#    790,
#    791,
#    795,
#    799,
#    812,
#    822,
#    881,
#    900,
#    904,
#    905,
#    910,
#    914,
#    930,
#    954,
#    984,
#    1008,
#    1047]),
#  ('httpstcokjzgnss9y0', 1, [265]),
#  ('medal', 1, [413]),
#  ('gewch2017', 2, [72, 623]),
#  ('deciph', 2, [755, 809]),
#  ('httpstcolmp8ss9czw', 1, [1004]),
#  ('nad', 1, [694]),
#  ('httpstco7lr3x8nkqn', 1, [1029]),
#  ('httpstcogyvwr4hg0h', 1, [385]),
#  ('janvier', 1, [958]),
#  ('portivechju', 2, [207, 989]),
#  ('informat', 1, [116]),
#  ('swisstechconventioncent', 1, [1005]),
#  ('sundancefest', 2, [247, 615]),
#  ('n', 1, [282]),
#  ('civil', 1, [842]),
#  ('childcar', 2, [60, 308]),
#  ('httpstcomboskllti5', 1, [507]),
#  ('dream', 1, [667]),
#  ('avez', 1, [1030]),
#  ('sanit', 1, [166]),
#  ('imag', 8, [80, 100, 193, 235, 332, 676, 680, 859]),
#  ('httpstcolbew6a8gsu', 1, [1060]),
#  ('30', 4, [64, 782, 834, 894]),
#  ('vlemondefr', 1, [599]),
#  ('tocar', 1, [887]),
#  ('opensci', 6, [78, 125, 238, 329, 466, 799]),
#  ('httpstcolgylhxfmc0', 1, [844]),
#  ('natur', 8, [44, 104, 169, 414, 532, 562, 749, 831]),
#  ('mooc',
#   18,
#   [23,
#    41,
#    138,
#    141,
#    164,
#    166,
#    166,
#    233,
#    408,
#    436,
#    454,
#    515,
#    614,
#    619,
#    619,
#    798,
#    906,
#    975]),
#  ('edu', 1, [338]),
#  ('httpstcot9oxzgtx4h', 1, [997]),
#  ('fast', 3, [233, 495, 941]),
#  ('shameless', 1, [290]),
#  ('pictur', 2, [559, 866]),
#  ('short', 2, [301, 518]),
#  ('listen', 1, [21]),
#  ('programm', 12, [56, 167, 233, 252, 342, 347, 382, 495, 677, 742, 742, 958]),
#  ('quid', 1, [356]),
#  ('httpstcomrdf4m2rgm', 1, [1039]),
#  ('diplom', 1, [188]),
#  ('race', 1, [178]),
#  ('httpstco3qhw8vh9il', 2, [173, 854]),
#  ('seguin', 1, [316]),
#  ('winter', 3, [368, 749, 963]),
#  ('marion', 1, [824]),
#  ('repositori', 1, [799]),
#  ('laisser', 1, [1049]),
#  ('httpstcoggjxqokinp', 1, [231]),
#  ('handson', 2, [337, 985]),
#  ('maddoxpr', 2, [778, 1006]),
#  ('httpstcowzvufmyxid', 1, [188]),
#  ('httpstcoegweg4aqj4', 1, [724]),
#  ('againstbc', 1, [8]),
#  ('long', 4, [26, 246, 948, 1012]),
#  ('digitalimag', 1, [226]),
#  ('near', 1, [957]),
#  ('cont', 1, [375]),
#  ('forbesunder30', 1, [143]),
#  ('tucci', 1, [915]),
#  ('is',
#   95,
#   [14,
#    17,
#    18,
#    27,
#    44,
#    58,
#    59,
#    71,
#    85,
#    85,
#    87,
#    103,
#    104,
#    108,
#    126,
#    126,
#    134,
#    195,
#    198,
#    212,
#    214,
#    231,
#    248,
#    250,
#    258,
#    264,
#    278,
#    281,
#    288,
#    293,
#    301,
#    306,
#    307,
#    312,
#    312,
#    312,
#    317,
#    333,
#    368,
#    375,
#    394,
#    412,
#    415,
#    418,
#    422,
#    444,
#    483,
#    485,
#    490,
#    504,
#    512,
#    530,
#    531,
#    537,
#    553,
#    591,
#    605,
#    607,
#    608,
#    623,
#    628,
#    640,
#    641,
#    641,
#    648,
#    669,
#    669,
#    671,
#    674,
#    684,
#    691,
#    717,
#    717,
#    730,
#    731,
#    764,
#    768,
#    776,
#    797,
#    810,
#    814,
#    816,
#    833,
#    879,
#    898,
#    903,
#    903,
#    905,
#    907,
#    957,
#    965,
#    999,
#    1002,
#    1044,
#    1056]),
#  ('a3forum', 2, [104, 292]),
#  ('uneth', 1, [198]),
#  ('laserbas', 1, [1000]),
#  ('dgtswitzerland',
#   16,
#   [148,
#    200,
#    251,
#    263,
#    321,
#    382,
#    399,
#    501,
#    506,
#    525,
#    573,
#    573,
#    624,
#    645,
#    826,
#    1024]),
#  ('biociment', 1, [283]),
#  ('haenni', 1, [903]),
#  ('httpstcotlieahzlsd', 1, [232]),
#  ('mouvement', 2, [279, 861]),
#  ('jesusmessiah7', 1, [52]),
#  ('httpstcoq3zob59dwu', 1, [337]),
#  ('jcangelini', 1, [989]),
#  ('bertarellineuro', 1, [481]),
#  ('fièr', 1, [1016]),
#  ('done', 5, [591, 691, 761, 948, 1006]),
#  ('verg', 3, [234, 241, 387]),
#  ('httpstcot31ekfpq93', 1, [209]),
#  ('rampd', 1, [71]),
#  ('screen', 2, [301, 339]),
#  ('upmc', 1, [311]),
#  ('httpstcouk0qph305h', 1, [741]),
#  ('bright', 1, [671]),
#  ('stuck', 1, [195]),
#  ('lore25n', 1, [933]),
#  ('httpstcocxoi7zmv8a', 1, [508]),
#  ('clock', 1, [361]),
#  ('phdlife', 1, [491]),
#  ('delight', 2, [575, 703]),
#  ('pmaurericrc', 1, [830]),
#  ('parametr', 1, [101]),
#  ('xaviercoad', 1, [472]),
#  ('✊📰', 1, [48]),
#  ('abbschweizag', 1, [425]),
#  ('httpstcol4mhqa7upb', 1, [8]),
#  ('👌elektromobilitaet', 1, [1011]),
#  ('moham', 1, [861]),
#  ('respond', 1, [507]),
#  ('😇', 1, [988]),
#  ('function', 3, [231, 365, 370]),
#  ('decentr', 2, [68, 101]),
#  ('dutilis', 1, [889]),
#  ('httpstcoqnijn705t9', 1, [1065]),
#  ('posit', 3, [442, 869, 1036]),
#  ('univers',
#   23,
#   [4,
#    13,
#    64,
#    71,
#    121,
#    139,
#    195,
#    294,
#    468,
#    482,
#    531,
#    632,
#    648,
#    686,
#    759,
#    759,
#    812,
#    817,
#    912,
#    912,
#    934,
#    944,
#    995]),
#  ('languag', 1, [792]),
#  ('perriard', 1, [898]),
#  ('smileseq', 1, [170]),
#  ('httpstco4xduwhjtu', 1, [782]),
#  ('mfe', 1, [946]),
#  ('henri', 1, [818]),
#  ('httpstco6ixddicblu', 1, [964]),
#  ('leila', 1, [935]),
#  ('dessin', 1, [462]),
#  ('lharmonis', 1, [602]),
#  ('save', 5, [339, 441, 698, 887, 1060]),
#  ('sunris', 1, [749]),
#  ('httpstcon4yqbge3m', 1, [438]),
#  ('vitrag', 1, [1070]),
#  ('bertrandpiccard', 1, [582]),
#  ('httpstcozj5yvdq6w8', 1, [560]),
#  ('httpstcomftlolyolu', 1, [410]),
#  ('praxisorientiert', 1, [167]),
#  ('httpstcolcs564yavr', 1, [98]),
#  ('ceux', 2, [168, 282]),
#  ('label', 1, [557]),
#  ('savonario', 1, [70]),
#  ('départ', 1, [26]),
#  ('hall', 1, [971]),
#  ('sv', 6, [28, 320, 381, 513, 593, 957]),
#  ('swissskil', 1, [346]),
#  ('httpstcopkikecf1ux', 1, [594]),
#  ('enhanc', 4, [349, 668, 708, 864]),
#  ('materi', 6, [34, 132, 176, 545, 663, 669]),
#  ('martin', 3, [568, 643, 863]),
#  ('extens', 1, [899]),
#  ('braintovehicl', 1, [387]),
#  ('saphana', 1, [955]),
#  ('httpstcoeoe8vhmgek', 1, [804]),
#  ('unifr', 7, [83, 163, 200, 391, 489, 705, 979]),
#  ('httpstcoyyfhsr2qsb', 1, [121]),
#  ('cyberspac', 1, [830]),
#  ('httpstcohpfqgy1yuf', 1, [304]),
#  ('httpstcobbzb8julcc', 1, [680]),
#  ('’',
#   81,
#   [13,
#    32,
#    44,
#    58,
#    58,
#    60,
#    62,
#    107,
#    123,
#    144,
#    152,
#    197,
#    197,
#    243,
#    243,
#    243,
#    248,
#    278,
#    282,
#    282,
#    282,
#    337,
#    363,
#    373,
#    388,
#    403,
#    411,
#    414,
#    414,
#    453,
#    473,
#    495,
#    517,
#    532,
#    543,
#    584,
#    589,
#    604,
#    610,
#    610,
#    627,
#    627,
#    627,
#    627,
#    630,
#    644,
#    665,
#    684,
#    691,
#    691,
#    692,
#    710,
#    723,
#    731,
#    755,
#    770,
#    770,
#    800,
#    817,
#    821,
#    843,
#    843,
#    849,
#    849,
#    851,
#    853,
#    861,
#    862,
#    862,
#    901,
#    935,
#    958,
#    968,
#    975,
#    1023,
#    1025,
#    1026,
#    1026,
#    1040,
#    1067,
#    1071]),
#  ('public', 10, [13, 107, 163, 301, 339, 366, 635, 745, 975, 1017]),
#  ('on',
#   148,
#   [4,
#    10,
#    17,
#    22,
#    27,
#    27,
#    32,
#    41,
#    51,
#    68,
#    77,
#    89,
#    91,
#    98,
#    108,
#    108,
#    108,
#    114,
#    119,
#    130,
#    134,
#    150,
#    151,
#    155,
#    164,
#    164,
#    164,
#    166,
#    177,
#    179,
#    200,
#    201,
#    203,
#    214,
#    216,
#    223,
#    257,
#    265,
#    270,
#    278,
#    296,
#    301,
#    303,
#    318,
#    320,
#    323,
#    337,
#    339,
#    371,
#    371,
#    373,
#    375,
#    376,
#    387,
#    390,
#    393,
#    400,
#    407,
#    407,
#    410,
#    419,
#    426,
#    430,
#    436,
#    437,
#    444,
#    447,
#    455,
#    458,
#    459,
#    465,
#    485,
#    503,
#    507,
#    507,
#    512,
#    513,
#    515,
#    519,
#    526,
#    528,
#    535,
#    537,
#    538,
#    538,
#    550,
#    557,
#    557,
#    575,
#    597,
#    600,
#    601,
#    607,
#    608,
#    612,
#    613,
#    613,
#    614,
#    622,
#    626,
#    634,
#    639,
#    642,
#    645,
#    649,
#    655,
#    662,
#    684,
#    691,
#    700,
#    704,
#    719,
#    724,
#    724,
#    741,
#    756,
#    756,
#    757,
#    765,
#    787,
#    787,
#    799,
#    804,
#    805,
#    808,
#    812,
#    818,
#    845,
#    855,
#    860,
#    867,
#    878,
#    897,
#    899,
#    899,
#    916,
#    917,
#    928,
#    935,
#    935,
#    936,
#    937,
#    960,
#    979,
#    979,
#    986,
#    990,
#    1012]),
#  ('httpstcosca1n4ayuq', 1, [624]),
#  ('énergétiqu', 1, [644]),
#  ('spaceship', 1, [92]),
#  ('ofandebiomim', 1, [789]),
#  ('she', 1, [270]),
#  ('shametortur', 1, [278]),
#  ('httpstcohjbhwul4pv', 1, [979]),
#  ('migrat', 1, [955]),
#  ('httpstco7vf2txcuio', 1, [60]),
#  ('gruenebw', 3, [1057, 1058, 1059]),
#  ('13', 2, [887, 1060]),
#  ('fun', 2, [542, 587]),
#  ('httpstcogykdblzsr5', 1, [660]),
#  ('brief', 3, [334, 704, 704]),
#  ('manchu', 1, [48]),
#  ('httpstco4hmazta9qa', 1, [49]),
#  ('httpstcoqaggznh4uk', 1, [803]),
#  ('denken', 1, [338]),
#  ('ran', 1, [88]),
#  ('42', 1, [561]),
#  ('exchang', 1, [106]),
#  ('northwesterneng', 1, [805]),
#  ('each', 2, [858, 858]),
#  ('parcouru', 1, [392]),
#  ('tumuenchen', 4, [71, 522, 669, 1006]),
#  ('lausannoi', 1, [644]),
#  ('polycopié', 1, [157]),
#  ('drpetti', 2, [320, 381]),
#  ('massiv', 1, [515]),
#  ('vp', 1, [688]),
#  ('httpstco89ziiby5f', 1, [990]),
#  ('intellig', 6, [62, 69, 292, 610, 797, 1070]),
#  ('30th', 1, [762]),
#  ('leader', 3, [13, 30, 610]),
#  ('employe', 1, [938]),
#  ('bhutan', 1, [271]),
#  ('httpstcoxlnmwh85oj', 1, [1020]),
#  ('smartmobl', 1, [963]),
#  ('hubert', 1, [424]),
#  ('significantli', 1, [193]),
#  ('crosstalk', 1, [696]),
#  ('darkmatt', 3, [111, 355, 811]),
#  ('httpstcoqm2ctalgea', 1, [699]),
#  ('it',
#   62,
#   [21,
#    31,
#    44,
#    44,
#    50,
#    58,
#    58,
#    73,
#    85,
#    91,
#    91,
#    103,
#    110,
#    115,
#    124,
#    126,
#    134,
#    155,
#    198,
#    206,
#    214,
#    215,
#    224,
#    247,
#    271,
#    312,
#    312,
#    318,
#    337,
#    348,
#    373,
#    390,
#    390,
#    418,
#    464,
#    480,
#    490,
#    499,
#    501,
#    530,
#    530,
#    581,
#    581,
#    613,
#    635,
#    650,
#    650,
#    657,
#    703,
#    722,
#    726,
#    809,
#    839,
#    845,
#    858,
#    903,
#    904,
#    938,
#    938,
#    1009,
#    1055,
#    1060]),
#  ('pool', 1, [905]),
#  ('emmanuelmacron', 1, [1037]),
#  ('leçon', 2, [172, 843]),
#  ('savoglidi', 1, [1027]),
#  ('500', 1, [429]),
#  ('cour', 11, [20, 157, 161, 252, 252, 304, 627, 742, 752, 827, 1001]),
#  ('runtim', 1, [917]),
#  ('datadriven', 4, [524, 616, 713, 904]),
#  ('involv', 1, [591]),
#  ('courtin', 1, [114]),
#  ('review', 4, [225, 334, 694, 948]),
#  ('httpstcoqnsa7r8don', 1, [1073]),
#  ('grapheneco', 1, [334]),
#  ('comment', 7, [615, 683, 784, 962, 976, 977, 1010]),
#  ('kaufmann', 1, [463]),
#  ('😉', 5, [209, 325, 735, 802, 1049]),
#  ('httpstcovkmbzf7wc0', 1, [307]),
#  ('httpstcoyq7umjzvin', 1, [180]),
#  ('scicomm', 4, [301, 339, 420, 730]),
#  ('mobilité', 2, [463, 618]),
#  ('joetheshark', 1, [620]),
#  ('spark', 1, [315]),
#  ('pepsico', 1, [522]),
#  ('cantongenev', 1, [11]),
#  ('bibliothécair', 1, [94]),
#  ('httpstco462ghoecml', 1, [1033]),
#  ('httpstco8wktgl06vq', 1, [881]),
#  ('welcom', 5, [57, 258, 286, 847, 1013]),
#  ('travel', 4, [136, 179, 372, 930]),
#  ('httpstcokcwnh9i9sf', 1, [396]),
#  ('walli', 2, [185, 743]),
#  ('amp8207', 1, [334]),
#  ('httpstcowy69jze1zc', 1, [393]),
#  ('httpstcosoiiictqnr', 1, [70]),
#  ('httpstco60smllndjx', 1, [330]),
#  ('geteschool', 3, [512, 590, 601]),
#  ('court', 2, [475, 475]),
#  ('dire', 1, [1043]),
#  ('actuat', 2, [609, 660]),
#  ('placecosandey', 1, [604]),
#  ('inactiv', 1, [248]),
#  ('dmfunil', 1, [86]),
#  ('knowledgecomscor', 1, [262]),
#  ('technew', 1, [414]),
#  ('4pm', 1, [743]),
#  ('⚠️', 1, [185]),
#  ('concept', 3, [136, 275, 1061]),
#  ('httpstcorfp5dcojw4', 1, [651]),
#  ('pfsc', 1, [291]),
#  ('remark', 1, [470]),
#  ('polair', 1, [636]),
#  ('villar', 1, [601]),
#  ('ateli', 3, [11, 265, 265]),
#  ('gamelab🕹rtstribu', 1, [893]),
#  ('nanotechnolog', 1, [196]),
#  ('journal', 2, [552, 1003]),
#  ('boybat', 1, [77]),
#  ('inherit', 1, [422]),
#  ('bach', 1, [1051]),
#  ('déjeuner', 1, [207]),
#  ('valeur', 2, [325, 844]),
#  ('danss', 1, [1030]),
#  ('won', 2, [178, 364]),
#  ('labdigitalhum', 1, [592]),
#  ('httpstcohrx0n07gtj', 1, [469]),
#  ('than', 12, [21, 64, 64, 111, 214, 355, 379, 531, 580, 778, 811, 858]),
#  ('mainten', 3, [307, 567, 1019]),
#  ('httpstcojnmlxmguo', 1, [316]),
#  ('httpstcoddeefomq87', 1, [874]),
#  ('motif', 1, [170]),
#  ('fleshandblood', 2, [216, 634]),
#  ('amld', 1, [612]),
#  ('httpstcoo5ido16day', 1, [492]),
#  ('fifel', 1, [107]),
#  ('satellit', 1, [666]),
#  ('stage', 1, [56]),
#  ('fail', 1, [813]),
#  ('mail', 1, [641]),
#  ('tempor', 2, [176, 290]),
#  ('httpstco4r7b6cemhk', 1, [849]),
#  ('sxswiss', 5, [50, 198, 580, 581, 722]),
#  ('clipair', 2, [711, 711]),
#  ('cdmissionindia', 1, [15]),
#  ('aebisch', 3, [702, 821, 1071]),
#  ('koebenhavnsuni', 1, [817]),
#  ('french', 7, [150, 185, 286, 492, 682, 702, 905]),
#  ('québec', 1, [1030]),
#  ('publié', 1, [710]),
#  ('httpstcobsrf78yslc', 1, [1007]),
#  ('imecint', 1, [428]),
#  ('haut', 1, [919]),
#  ('acquisit', 1, [80]),
#  ('staircas', 1, [455]),
#  ('httpstcogghuh49wmi', 1, [822]),
#  ('idrrim', 1, [815]),
#  ...]

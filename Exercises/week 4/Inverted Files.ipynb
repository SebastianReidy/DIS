# %% [markdown]
# ## 📚 Exercise 2: Inverted Files
#
# In this exercise, we will understand the functioning of the Inverted Files and how implement them using MapReduce.
#
# ### Overview
#
# We learnt in the lecture that terms are typically stored in an inverted list. Now, in the inverted list, instead of only storing document identifiers of the documents in which the term appears, assume we also store an *offset* of the appearance of a term in a document. An $offset$ of a term $l_k$ given a document is defined as the number of words between the start of the document and $l_k$. Thus our inverted list is now:
#
# $l_k= \langle f_k: \{d_{i_1} \rightarrow [o_1,\ldots,o_{n_{i_1}}]\},
# \{d_{i_2} \rightarrow [o_1,\ldots,o_{n_{i_2}}]\}, \ldots,
# \{d_{i_k} \rightarrow [o_1,\ldots,o_{n_{i_k}}]\} \rangle$
#
# This means that in document $d_{i_1}$ term $l_k$ appears $n_{i_1}$ times and at offset $[o_1,\ldots,o_{n_{i_1}}]$, where $[o_1,\ldots,o_{n_{i_1}}]$ are sorted in ascending order, these type of indices are also known as term-offset indices. An example of a term-offset index is as follows:
#
# **Obama** = $⟨4 : {1 → [3]},{2 → [6]},{3 → [2,17]},{4 → [1]}⟩$
#
# **Governor** = $⟨2 : {4 → [3]}, {7 → [14]}⟩$
#
# **Election** = $⟨4 : {1 → [1]},{2 → [1,21]},{3 → [3]},{5 → [16,22,51]}⟩$
#
# Which is to say that the term **Governor** appear in 2 documents. In document 4 at offset 3, in document 7 at offset 14. Now let us consider the *SLOP/x* operator in text retrieval. This operator has the syntax: *QueryTerm1 SLOP/x QueryTerm2* finds occurrences of *QueryTerm1* within $x$ (but not necessarily in that order) words of *QueryTerm2*, where $x$ is a positive integer argument ($x \geq 1$). Thus $x = 1$ demands that *QueryTerm1* be adjacent to *QueryTerm2*.
#
# ### Questions
#
# 1. List the set of documents that satisfy the query **Obama** *SLOP/2* **Election**.
# - 1, 3
# 2. List each set of values for which the query **Obama** *SLOP/x* **Election** has a different set of documents as answers (starting from $x = 1$).
# - x = 1: 3
# - x = 2: 1,3
# - x = 5: 1,2,3
# 3. Consider the general procedure for "merging" two term-offset inverted lists for a given document, to determine where the document satisfies a *SLOP/x* clause (since in general there will be many offsets at which each term occurs in a document). Let $L$ denote the total number of occurrences of the two terms in the document. Assume we have a pointer to the list of occurrences of each term and can move the pointer along this list. As we do so we check whether we have a hit for $SLOP/x$ (i.e. the $SLOP/x$ clause is satisfied). Each move of either pointer counts as a step. Based on this assumption is there a general "merging" procedure to determine whether the document satisfies a $SLOP/x$ clause, for which the following is true? Justify your answer.
#
#     1. The merge can be accomplished in a number of steps linear in $L$ regardless of $x$, and we can ensure that each pointer moves only to the right (i.e. forward).
#     2. The merge can be accomplished in a number of steps linear in $L$, but a pointer may be forced to move to the left (i.e. backwards).
#     3. The merge can require $x \times L$ steps in some cases.
#
# Option 1: we can move to the right with 1 pointer then move to the right with the other pointer until it leaves the frame.

# %% [markdown]
# ## Create inverted files using MapReduce
# In this exercise, we want to create the inverted files using the MapReduce framework. Write the **map** and **reduce** function.
# Note that the code of **run_mapreduce** is just a simulation of the behavior of  map-reduce system.
#
# ## Goal:
# - Create inverted files using the MapReduce framework.
# - Test the implementation on `epfldocs.txt` data.
#
# ### What you are learning in this exercise:
# - Having a better understanding of inverted files.
# - Learn how to implement inverted files using the MapReduce framework.

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer
import nltk
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
import string
from nltk.corpus import stopwords
import math
from collections import Counter
import numpy as np
nltk.download('stopwords')
nltk.download('punkt')

stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sebastian/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/sebastian/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Tokenize, stem a document
def tokenize(text):
    """
    It tokenizes and stems an input text.
    
    :param text: str, with the input text
    :return: list, of the tokenized and stemmed tokens.
    """
    text = "".join([ch for ch in text if ch not in string.punctuation])
    tokens = nltk.word_tokenize(text)
    return " ".join([stemmer.stem(word.lower()) for word in tokens])

with open("epfldocs.txt") as f:
    content = f.readlines()
original_documents = [x.strip() for x in content] 
documents = [tokenize(d).split() for d in original_documents]
docs_n_doc_ids = list(zip(range(len(documents)), documents))

# %%
# Take a pair (doc_id, content). Example: (0, ['how', 'to', 'bake', 'bread', 'without', 'bake', 'recip'])
# Return: list of (word, doc_id). Example: ('bake', 0)
# For simplicity, we assume each mapper handles a document
def map_function(doc_id, content):
    keyvals = []
    for word in content:
        keyvals.append((word, doc_id))
    return keyvals

# %%
# Take a list of pairs (word, doc_id). Example:  [('bake', 0), ('bake', 0), ('bake', 3)]
# Return: (word, frequency, list of document ids). Example ('bake', 3, [0, 0, 3])
# For simplicity, we assume each reducer handles a word
def reduce_function(lst):
    total = 0
    word = lst[0][0]
    doc_ids = []
    for w, doc_id in lst:
        assert(word==w) # Assume each reducer handles 1 word
        total += 1
        doc_ids.append(doc_id)
    return (word, total, doc_ids)

# %%
# We simulate the mapreduce framework by this function
def run_mapreduce(docs_n_doc_ids):
    # Map phase
    key_values = []
    for doc_id, doc_content in docs_n_doc_ids:
        key_values.extend(map_function(doc_id, doc_content))
    # Shuffle phase
    values = set(map(lambda x:x[0], key_values))
    grouped_key_values = [[y for y in key_values if y[0]==x] for x in values]
    # Reduce phase
    inverted_files = []
    for grouped_key_value in grouped_key_values:
        word, total, doc_ids = reduce_function(grouped_key_value)
        inverted_files.append((word, total, doc_ids))
    return inverted_files

# %%
run_mapreduce(docs_n_doc_ids)
# Out:
# [('dies', 1, [451]),
#  ('grâce', 1, [882]),
#  ('précieux', 1, [279]),
#  ('pain', 3, [718, 907, 907]),
#  ('labor', 2, [294, 468]),
#  ('6902010', 1, [739]),
#  ('flowecommerc', 1, [427]),
#  ('httpstcoefcvq215nh', 1, [618]),
#  ('httpstco5nmydbcuzk', 1, [884]),
#  ('réaménag', 1, [1063]),
#  ('hk–chic', 1, [90]),
#  ('limité', 1, [283]),
#  ('acetyl', 1, [622]),
#  ('ont', 5, [183, 282, 383, 1047, 1047]),
#  ('chbotschaftd', 1, [319]),
#  ('httpstcovcqxjwcrfr', 1, [944]),
#  ('anniversari', 1, [762]),
#  ('polymtl', 1, [654]),
#  ('ee', 1, [875]),
#  ('httpstcot9imltiuel', 1, [476]),
#  ('httpstco6ztzov8ylh', 1, [837]),
#  ('crosstalk', 1, [696]),
#  ('hslu', 1, [11]),
#  ('httpstcogp8mbyxeqt', 1, [149]),
#  ('httpstcovpzbekanay', 1, [86]),
#  ('didnt', 2, [409, 938]),
#  ('teamwork', 1, [955]),
#  ('harmanton', 1, [336]),
#  ('nips2016', 1, [97]),
#  ('genova', 1, [639]),
#  ('learn',
#   27,
#   [33,
#    60,
#    176,
#    194,
#    208,
#    229,
#    231,
#    337,
#    347,
#    347,
#    390,
#    390,
#    411,
#    426,
#    464,
#    587,
#    600,
#    613,
#    623,
#    747,
#    859,
#    872,
#    888,
#    899,
#    974,
#    1009,
#    1048]),
#  ('funprog', 1, [224]),
#  ('aleaf', 1, [237]),
#  ('😃', 1, [654]),
#  ('httpstcodbgbotyhez', 1, [792]),
#  ('mahamad', 1, [56]),
#  ('cors', 1, [906]),
#  ('httpstcohocwlvumq1', 1, [283]),
#  ('hp1a', 2, [66, 959]),
#  ('solar',
#   24,
#   [29,
#    40,
#    83,
#    152,
#    296,
#    299,
#    317,
#    364,
#    396,
#    398,
#    406,
#    419,
#    473,
#    517,
#    595,
#    681,
#    684,
#    705,
#    771,
#    853,
#    913,
#    968,
#    1002,
#    1004]),
#  ('secret', 2, [70, 414]),
#  ('httpstcowpkspxtdc9', 1, [460]),
#  ('httpstcohf3tyz8li1', 1, [1001]),
#  ('laperrouza', 1, [900]),
#  ('constraint', 1, [260]),
#  ('heur', 2, [627, 983]),
#  ('edacyhq', 4, [7, 56, 233, 269]),
#  ('nanopattern', 1, [949]),
#  ('httpstcolfirt3mqxv', 1, [660]),
#  ('on🇪🇺eufund', 1, [717]),
#  ('context', 2, [601, 975]),
#  ('cv', 1, [674]),
#  ('coffe', 1, [951]),
#  ('notr', 7, [63, 243, 362, 565, 710, 821, 927]),
#  ('mensch', 1, [425]),
#  ('ecolog', 2, [41, 41]),
#  ('sanit', 1, [166]),
#  ('void', 1, [410]),
#  ('vitamin', 1, [149]),
#  ('häuschen', 1, [451]),
#  ('anouch', 1, [610]),
#  ('trevano', 1, [202]),
#  ('fibril', 1, [661]),
#  ('understood', 1, [938]),
#  ('ecal', 1, [245]),
#  ('lîlot', 1, [952]),
#  ('httpstcodhjuvdnb24', 1, [543]),
#  ('read',
#   13,
#   [109, 109, 150, 236, 262, 278, 546, 550, 577, 820, 935, 981, 986]),
#  ('thafid64', 1, [1071]),
#  ('lepfllesp', 1, [495]),
#  ('dévoil', 1, [651]),
#  ('robotiqu', 3, [20, 382, 929]),
#  ('httpstcolrvirfnywc', 1, [924]),
#  ('fmondada', 4, [20, 343, 382, 735]),
#  ('collegium', 1, [304]),
#  ('httpstcojlnocxclmg', 1, [868]),
#  ('httpstcoa0fsbkkmwn', 1, [148]),
#  ('stack', 2, [66, 66]),
#  ('traveltuesday', 1, [136]),
#  ('vuill', 1, [107]),
#  ('enquêt', 1, [821]),
#  ('vr', 7, [102, 313, 313, 518, 654, 907, 1014]),
#  ('prize', 4, [288, 316, 484, 720]),
#  ('ces2018', 1, [387]),
#  ('meinen', 1, [954]),
#  ('httpstconpgbukjhbl', 1, [228]),
#  ('déjà', 2, [168, 996]),
#  ('srf', 1, [576]),
#  ('constitut', 1, [905]),
#  ('catalyt', 1, [334]),
#  ('bi', 1, [1015]),
#  ('node', 1, [696]),
#  ('httpstcog0hzwjpurg', 1, [465]),
#  ('hide', 1, [930]),
#  ('httpstcobezxs7dnvg', 1, [273]),
#  ('mise', 1, [844]),
#  ('franceia', 1, [118]),
#  ('famili', 1, [142]),
#  ('centr', 5, [16, 182, 182, 723, 947]),
#  ('bci', 3, [178, 438, 459]),
#  ('httpstcoapgzetdcu', 1, [614]),
#  ('thermal', 1, [949]),
#  ('mean', 1, [312]),
#  ('170', 1, [697]),
#  ('httpstcotxqbyqdzsl', 1, [882]),
#  ('websit', 1, [673]),
#  ('httpstcoa5in0tcls7', 1, [731]),
#  ('draw', 2, [738, 992]),
#  ('belong', 1, [759]),
#  ('opportun', 11, [3, 100, 126, 296, 339, 341, 393, 505, 512, 697, 973]),
#  ('microcityn', 1, [402]),
#  ('montreuxjazz', 1, [1032]),
#  ('stroke', 2, [972, 1029]),
#  ('1946', 1, [674]),
#  ('mitochondri', 1, [149]),
#  ('httpstcoqnijn705t9', 1, [1065]),
#  ('12000', 1, [684]),
#  ('nobel', 2, [674, 720]),
#  ('ständigen', 1, [638]),
#  ('porcelain', 1, [770]),
#  ('iciq', 1, [237]),
#  ('httpstcobdowqoqx', 1, [308]),
#  ('ingénieur', 2, [205, 862]),
#  ('httpstcopb8uasa3sa', 1, [1050]),
#  ('6', 5, [90, 175, 272, 767, 975]),
#  ('war', 1, [890]),
#  ('vu', 1, [130]),
#  ('httpstcoxgb8ynuklt', 1, [585]),
#  ('xaviercoad', 1, [472]),
#  ('httpstcozx134tvlaf', 1, [1003]),
#  ('mutat', 1, [35]),
#  ('enabl', 3, [229, 259, 628]),
#  ('giraulthubert', 2, [275, 1013]),
#  ('httpstcol977bmopel', 1, [390]),
#  ('fr', 1, [633]),
#  ('httpstco1ktfeyqze6', 1, [904]),
#  ('appli',
#   14,
#   [33, 60, 196, 222, 260, 337, 347, 422, 576, 640, 676, 688, 899, 987]),
#  ('billard', 1, [118]),
#  ('gainde2000', 1, [559]),
#  ('electrochem', 1, [676]),
#  ('excel', 6, [264, 292, 308, 576, 657, 800]),
#  ('recherch', 6, [16, 168, 197, 569, 892, 1023]),
#  ('sofc', 1, [1013]),
#  ('trace', 4, [24, 67, 153, 932]),
#  ('lectur', 10, [32, 107, 164, 223, 293, 371, 413, 600, 816, 859]),
#  ('httpstcoknbo1qjpfq', 1, [976]),
#  ('juli', 1, [222]),
#  ('muscl', 1, [546]),
#  ('gillesjobin1', 1, [313]),
#  ('enoch', 1, [189]),
#  ('piss', 1, [936]),
#  ('happylook', 1, [76]),
#  ('whose', 1, [979]),
#  ('brjsa📀', 1, [99]),
#  ('httpstcoicgwb6puwo', 1, [597]),
#  ('myswitzerland', 1, [749]),
#  ('humanbrainproj', 1, [709]),
#  ('httpstcoa6lliu7txb', 1, [1055]),
#  ('compet', 1, [21]),
#  ('sure', 5, [312, 374, 685, 863, 938]),
#  ('shadaislam', 1, [270]),
#  ('métier', 1, [357]),
#  ('sign', 5, [426, 436, 866, 873, 982]),
#  ('sociologi', 1, [463]),
#  ('ehmicrobiomes2017', 1, [119]),
#  ('oper', 7, [98, 115, 138, 438, 798, 903, 986]),
#  ('electron', 3, [504, 865, 903]),
#  ('nottheashleydunnor', 1, [32]),
#  ('présidenc', 1, [665]),
#  ('httpstcoubw87pouan', 1, [898]),
#  ('scari', 1, [1044]),
#  ('httpstcomgxbfxvk1j', 2, [73, 839]),
#  ('reich', 1, [556]),
#  ('httpstcoeftnavcnh6', 1, [616]),
#  ('serendip', 1, [258]),
#  ('lehner', 1, [62]),
#  ('humbl', 1, [548]),
#  ('httpstco2wg3bbhbnq', 1, [426]),
#  ('pourriez', 1, [1039]),
#  ('neu', 1, [890]),
#  ('land', 1, [451]),
#  ('paper', 10, [79, 248, 393, 407, 415, 418, 550, 608, 917, 959]),
#  ('kevinschawinski', 2, [187, 501]),
#  ('candidatur', 3, [363, 801, 801]),
#  ('herbac', 1, [446]),
#  ('attest', 1, [752]),
#  ('httpstcotavirrwpkc', 1, [178]),
#  ('decaathlon', 1, [705]),
#  ('httpstcofow8wqhbka', 1, [431]),
#  ('esthétiqu', 1, [1023]),
#  ('connect', 1, [62]),
#  ('captiv', 1, [780]),
#  ('contr', 2, [603, 740]),
#  ('scala', 3, [315, 427, 455]),
#  ('120', 1, [175]),
#  ('lettresunil', 1, [301]),
#  ('notredamesci', 1, [296]),
#  ('deni', 3, [359, 783, 921]),
#  ('chemistri', 5, [171, 275, 720, 743, 847]),
#  ('alumni', 4, [190, 257, 309, 553]),
#  ('unicorn', 1, [563]),
#  ('airsportsfai', 1, [888]),
#  ('imdbschool', 1, [563]),
#  ('témoignag', 1, [955]),
#  ('africain', 2, [683, 1010]),
#  ('fintech', 3, [19, 127, 538]),
#  ('rank', 6, [4, 121, 220, 675, 912, 1041]),
#  ('przemek', 1, [960]),
#  ('microscopi', 4, [265, 286, 332, 680]),
#  ('forschung', 1, [822]),
#  ('lîle', 1, [463]),
#  ('demonstr', 2, [104, 909]),
#  ('httpstco856yhgi74j', 1, [58]),
#  ('franc', 9, [51, 150, 185, 304, 471, 546, 687, 806, 858]),
#  ('boybat', 1, [77]),
#  ('workshop',
#   18,
#   [68,
#    78,
#    148,
#    176,
#    337,
#    337,
#    347,
#    347,
#    525,
#    645,
#    700,
#    709,
#    756,
#    886,
#    899,
#    906,
#    941,
#    999]),
#  ('httpstcopqqkry5ny9', 1, [69]),
#  ('sbfich', 1, [200]),
#  ('httpstco3vujybmevd', 1, [341]),
#  ('worth', 1, [650]),
#  ('nonalcohol', 1, [298]),
#  ('dnabind', 1, [159]),
#  ('httpstcoivvkwm8ymi', 1, [656]),
#  ('haïku', 1, [311]),
#  ('roi', 1, [98]),
#  ('httpstconok4aklk3a', 1, [557]),
#  ('pariet', 1, [290]),
#  ('heart', 4, [717, 717, 758, 758]),
#  ('jovanov', 2, [213, 479]),
#  ('what',
#   22,
#   [139,
#    204,
#    278,
#    278,
#    359,
#    397,
#    409,
#    448,
#    474,
#    481,
#    516,
#    521,
#    580,
#    613,
#    671,
#    699,
#    717,
#    799,
#    938,
#    956,
#    995,
#    1060]),
#  ('david', 1, [916]),
#  ('digitaltrust', 3, [10, 182, 384]),
#  ('anyth', 1, [585]),
#  ('featur', 4, [458, 612, 856, 905]),
#  ('vulnérabilité', 1, [1031]),
#  ('cover', 2, [375, 684]),
#  ('httpstcowb1xbztqqn', 1, [842]),
#  ('précédent', 1, [12]),
#  ('mind', 4, [28, 246, 260, 741]),
#  ('httpstcoyjguw9c133', 1, [382]),
#  ('compon', 2, [256, 389]),
#  ('cybersécurité', 2, [182, 251]),
#  ('vdtech',
#   46,
#   [53,
#    62,
#    110,
#    120,
#    132,
#    156,
#    177,
#    206,
#    228,
#    242,
#    256,
#    286,
#    332,
#    354,
#    364,
#    389,
#    405,
#    421,
#    432,
#    508,
#    562,
#    616,
#    623,
#    649,
#    652,
#    693,
#    718,
#    754,
#    788,
#    800,
#    801,
#    831,
#    838,
#    852,
#    865,
#    882,
#    883,
#    884,
#    885,
#    891,
#    902,
#    970,
#    997,
#    1027,
#    1048,
#    1050]),
#  ('naturel', 1, [788]),
#  ('s3', 3, [126, 126, 704]),
#  ('laserbas', 1, [1000]),
#  ('teashop', 1, [192]),
#  ('archivch', 1, [183]),
#  ('help', 12, [60, 109, 236, 359, 450, 511, 530, 547, 818, 948, 979, 1029]),
#  ('►', 1, [647]),
#  ('labdigitalhum', 1, [592]),
#  ('httpstcokggcynsmwa', 1, [179]),
#  ('stand', 3, [1, 566, 1035]),
#  ('hill', 1, [736]),
#  ('folk', 1, [340]),
#  ('eksobion', 1, [871]),
#  ('cultureartsci', 1, [837]),
#  ('découvert', 2, [266, 895]),
#  ('muslimban', 1, [195]),
#  ('jordi', 1, [227]),
#  ('fine', 2, [432, 754]),
#  ('informatiqu', 2, [742, 742]),
#  ('haut', 1, [919]),
#  ('fondamental', 1, [827]),
#  ('henrik', 1, [108]),
#  ('joost', 1, [962]),
#  ('our',
#   49,
#   [65,
#    78,
#    102,
#    108,
#    108,
#    142,
#    154,
#    178,
#    200,
#    203,
#    228,
#    264,
#    264,
#    312,
#    320,
#    341,
#    381,
#    387,
#    407,
#    415,
#    420,
#    436,
#    446,
#    481,
#    493,
#    510,
#    522,
#    526,
#    559,
#    587,
#    613,
#    654,
#    658,
#    662,
#    703,
#    719,
#    756,
#    760,
#    762,
#    776,
#    792,
#    799,
#    863,
#    864,
#    941,
#    959,
#    963,
#    1046,
#    1065]),
#  ('vallebenasqu', 1, [431]),
#  ('amyloid', 1, [661]),
#  ('cdmissionindia', 1, [15]),
#  ('lancé', 1, [567]),
#  ('revolutionari', 1, [577]),
#  ('gratul', 1, [25]),
#  ('pic', 2, [375, 1005]),
#  ('apprenn', 1, [1024]),
#  ('27', 2, [13, 633]),
#  ('fin', 1, [93]),
#  ('optic', 6, [36, 256, 389, 544, 544, 544]),
#  ('startupfit', 2, [286, 891]),
#  ('httpstcob4qwcq4hda', 1, [143]),
#  ('durabl', 1, [996]),
#  ('charl', 1, [921]),
#  ('darker', 3, [111, 355, 811]),
#  ('launch', 9, [57, 421, 453, 504, 506, 559, 586, 677, 703]),
#  ('httpstcoh3jz6pjmta', 1, [544]),
#  ('govend', 1, [869]),
#  ('isbsib', 3, [266, 415, 922]),
#  ('tackl', 1, [879]),
#  ('httpstcojaqq6zqkdc', 1, [358]),
#  ('httpstcowdnmbshqfr', 1, [609]),
#  ('dnasequenc', 1, [159]),
#  ('mettr', 2, [462, 1071]),
#  ('worldwid', 1, [631]),
#  ('invas', 1, [32]),
#  ('privileg', 1, [1072]),
#  ('concret', 3, [304, 883, 884]),
#  ('nfaivr', 1, [290]),
#  ('newyearresolut', 1, [341]),
#  ('rehabilit', 3, [440, 693, 852]),
#  ('tough', 1, [650]),
#  ('doug', 1, [293]),
#  ('gupta', 1, [469]),
#  ('determin', 3, [32, 525, 607]),
#  ('codeweekch', 1, [333]),
#  ('articl', 11, [74, 103, 243, 407, 526, 705, 808, 844, 856, 905, 986]),
#  ('been', 9, [104, 264, 269, 387, 407, 507, 540, 812, 963]),
#  ('pathogen', 1, [641]),
#  ('sciencevalai', 1, [743]),
#  ('titlelength', 1, [280]),
#  ('changement', 1, [962]),
#  ('expans', 1, [171]),
#  ('vitess', 1, [794]),
#  ('rewalkrobot', 1, [871]),
#  ('➡', 2, [894, 958]),
#  ('ngiexp', 1, [549]),
#  ('httpstcopeme43mdfn', 1, [140]),
#  ('httpstcoyeqyacal3c', 1, [783]),
#  ('fun', 2, [542, 587]),
#  ('httpstcojogvkdfeln', 1, [953]),
#  ('divers', 2, [491, 646]),
#  ('ist', 3, [105, 167, 319]),
#  ('marino', 1, [633]),
#  ('bilanz', 1, [295]),
#  ('chui', 1, [287]),
#  ('httpstcoqot0l2xucd', 1, [374]),
#  ('httpstco5t7egh0quw', 1, [29]),
#  ('httpstcorgsyaedoci', 1, [829]),
#  ('httpstcob9jpcjfjsz', 1, [640]),
#  ('sensat', 1, [247]),
#  ('débusqu', 2, [405, 424]),
#  ('siggraph', 1, [615]),
#  ('httpstcoob8ruct0pk', 1, [698]),
#  ('httpstcofhmq51xdjw', 1, [392]),
#  ('socialmedia', 1, [27]),
#  ('microenvironment', 1, [32]),
#  ('boyarkin', 1, [661]),
#  ('iitmadra', 2, [748, 748]),
#  ('nutc', 1, [805]),
#  ('repli', 1, [938]),
#  ('httpstcoyrkoycbsl', 1, [1022]),
#  ('maxconf2018', 2, [545, 663]),
#  ('facialrecognit', 1, [397]),
#  ('insid', 5, [24, 67, 153, 245, 932]),
#  ('aigencycom', 1, [898]),
#  ('s',
#   27,
#   [13,
#    44,
#    58,
#    58,
#    104,
#    114,
#    152,
#    248,
#    292,
#    337,
#    473,
#    517,
#    532,
#    589,
#    592,
#    630,
#    684,
#    755,
#    770,
#    770,
#    817,
#    849,
#    849,
#    853,
#    935,
#    968,
#    975]),
#  ('handexoskeleton', 3, [668, 708, 864]),
#  ('never', 1, [910]),
#  ('feb', 3, [98, 390, 578]),
#  ('professeur', 3, [118, 463, 958]),
#  ('gesisorg', 1, [935]),
#  ('httpstcoqgkbwg220b', 1, [821]),
#  ('upscal', 1, [36]),
#  ('guider', 1, [789]),
#  ('stress', 3, [28, 490, 1031]),
#  ('sequencedirect', 1, [378]),
#  ('httpstcomjqcrfiqkb', 1, [30]),
#  ('biolog', 10, [24, 30, 67, 73, 153, 298, 365, 625, 839, 932]),
#  ('synthesi', 2, [334, 807]),
#  ('🔪', 1, [655]),
#  ('marchand', 1, [1068]),
#  ('httpstcomxk2y5brhf', 1, [339]),
#  ('urswyd', 1, [890]),
#  ('travaux', 3, [207, 961, 1039]),
#  ('practic', 4, [318, 539, 937, 960]),
#  ('creation', 1, [363]),
#  ('bruschini', 1, [226]),
#  ('jeu', 1, [633]),
#  ('httpstcoktstr2m5yi', 1, [984]),
#  ('organisé', 1, [1018]),
#  ('advertis', 1, [555]),
#  ('politonew', 2, [196, 639]),
#  ('httpstco5vujmpeatm', 1, [469]),
#  ('detect', 3, [695, 926, 1008]),
#  ('emp', 1, [611]),
#  ('duboul', 1, [783]),
#  ('jeffrey', 1, [260]),
#  ('pavillon', 1, [451]),
#  ('f', 1, [107]),
#  ('httpstco7zwhp1j03t', 1, [923]),
#  ('grow', 2, [410, 589]),
#  ('nad', 1, [694]),
#  ('pentacen', 2, [303, 303]),
#  ('sur',
#   37,
#   [11,
#    12,
#    26,
#    61,
#    149,
#    244,
#    252,
#    283,
#    302,
#    342,
#    342,
#    383,
#    408,
#    437,
#    463,
#    554,
#    566,
#    571,
#    604,
#    653,
#    705,
#    740,
#    744,
#    922,
#    925,
#    953,
#    961,
#    978,
#    978,
#    1019,
#    1023,
#    1035,
#    1040,
#    1042,
#    1063,
#    1066,
#    1067]),
#  ('young', 6, [259, 264, 489, 531, 1046, 1065]),
#  ('httpstconkj1g5q9ri', 1, [999]),
#  ('follicularlymphoma', 1, [943]),
#  ('extinct', 1, [112]),
#  ('gniarfffff', 1, [311]),
#  ('enorm', 1, [158]),
#  ('qu', 1, [610]),
#  ('lts5', 1, [855]),
#  ('doesnt', 1, [1002]),
#  ('rtsi', 1, [144]),
#  ('httpstcofhw6avwslu', 1, [525]),
#  ('teilen', 1, [49]),
#  ('defens', 2, [645, 743]),
#  ('inventé', 1, [1043]),
#  ('peuvent', 1, [70]),
#  ('recomposé', 1, [806]),
#  ('kippenberg', 1, [293]),
#  ('got', 2, [108, 938]),
#  ('australia', 1, [278]),
#  ('sadress', 1, [1017]),
#  ('httpstcoxivngafghi', 1, [871]),
#  ('samsam86', 1, [956]),
#  ('daccord', 1, [356]),
#  ('foundat', 1, [945]),
#  ('town', 1, [108]),
#  ('stori', 3, [163, 231, 846]),
#  ('aéronautiqu', 1, [16]),
#  ('staatfreiburg', 1, [309]),
#  ('httpstcoyjkjnlqnyw', 1, [87]),
#  ('text', 1, [582]),
#  ('httpstcoyaklj6rwyz', 1, [887]),
#  ('ça', 6, [331, 644, 781, 781, 781, 983]),
#  ('httpstcoa1y1stv0lb', 1, [169]),
#  ('daeinar', 2, [213, 479]),
#  ('connaiss', 2, [118, 893]),
#  ('venture2018', 3, [445, 506, 613]),
#  ('nicholasdemil', 1, [741]),
#  ('april', 4, [30, 479, 642, 990]),
#  ('louvrir', 2, [70, 351]),
#  ('révolutionn', 1, [386]),
#  ('httpstcoyqvbpliwdv', 1, [1026]),
#  ('httpstcop6oxc1fnh6', 1, [683]),
#  ('hightech', 2, [898, 901]),
#  ('it4lif', 1, [521]),
#  ('visual', 3, [316, 450, 867]),
#  ('httpstcorkcvwo6k2p', 1, [182]),
#  ('sex', 1, [928]),
#  ('sccerfeebd', 1, [608]),
#  ('httpstcorlzk8c5ata', 1, [546]),
#  ('red', 2, [777, 1061]),
#  ('alor', 1, [94]),
#  ('dublin', 1, [427]),
#  ('httpstcoxxtf4agbqb', 1, [902]),
#  ('einem', 1, [241]),
#  ('leman', 1, [672]),
#  ('httpstcopntoznv3jk', 1, [397]),
#  ('httpstcojkeufaeydp', 1, [897]),
#  ('httpstcoqgyot0yvzn', 1, [545]),
#  ('daylightsymposium', 1, [376]),
#  ('man', 4, [787, 787, 787, 787]),
#  ('httpstcoestl9bkiyv', 1, [318]),
#  ('camion', 1, [604]),
#  ('osspari', 1, [176]),
#  ('httpstcobpnpc47k3l', 1, [746]),
#  ('leçon', 2, [172, 843]),
#  ('smyle', 1, [304]),
#  ('httpstcovuof6zibbm', 1, [473]),
#  ('httpstcojvzrofbrvb', 1, [1012]),
#  ('suffir', 1, [892]),
#  ('valeur', 2, [325, 844]),
#  ('bid', 1, [594]),
#  ('derrièr', 1, [1024]),
#  ('cryo', 1, [526]),
#  ('respond', 1, [507]),
#  ('attack', 2, [547, 880]),
#  ('subject', 1, [4]),
#  ('microscal', 1, [804]),
#  ('damasio', 1, [472]),
#  ('lassoci', 2, [729, 1035]),
#  ('pool', 1, [905]),
#  ('maddoxpr', 2, [778, 1006]),
#  ('httpstcoblwafqtopd', 1, [694]),
#  ('envirobot', 3, [145, 828, 1008]),
#  ('embl', 1, [674]),
#  ('too', 4, [198, 263, 271, 530]),
#  ('politician', 1, [572]),
#  ('trè', 4, [183, 417, 794, 996]),
#  ('ground', 1, [872]),
#  ('mélodi', 1, [942]),
#  ('également', 1, [682]),
#  ('httpstcote2xm3np15', 1, [502]),
#  ('peac', 1, [263]),
#  ('httpstcomass98crri', 2, [328, 527]),
#  ('…', 10, [90, 674, 981, 981, 981, 981, 981, 981, 981, 981]),
#  ('httpstcogdesyev6cc', 1, [391]),
#  ('httpstcoawob8mwpvw', 1, [681]),
#  ('fusion', 2, [115, 164]),
#  ('appear', 1, [1009]),
#  ('expscifilm17', 2, [301, 339]),
#  ('charg', 1, [303]),
#  ('httpstcoj3gzqu9pqa', 1, [705]),
#  ('kamiahok', 2, [9, 774]),
#  ('touchabl', 1, [435]),
#  ('httpstcotzfefrum9', 1, [1047]),
#  ('httpstco9mwx3ratkh', 1, [834]),
#  ('opensourc', 4, [524, 616, 713, 904]),
#  ('fiwar', 1, [549]),
#  ('ordinateur', 1, [1051]),
#  ('httpstcoxaapgicva3', 1, [139]),
#  ('alahi', 3, [69, 104, 292]),
#  ('umformungsprozessen', 1, [638]),
#  ('util', 1, [1044]),
#  ('httpstcoeuir5wfkca', 1, [470]),
#  ('zurich', 7, [107, 200, 391, 759, 767, 844, 873]),
#  ('texa', 2, [215, 969]),
#  ('antirheumat', 1, [211]),
#  ('genev', 2, [11, 39]),
#  ('la2024', 1, [1042]),
#  ('httpstcok6xzd2bs7m', 1, [332]),
#  ('augmenté', 1, [408]),
#  ('frauduleux', 1, [773]),
#  ('httpstcowcmsrzdv51', 1, [552]),
#  ('explan', 1, [19]),
#  ('bibliothèqu', 2, [157, 197]),
#  ('result', 2, [80, 375]),
#  ('appel', 1, [363]),
#  ('join',
#   18,
#   [27,
#    46,
#    245,
#    246,
#    320,
#    391,
#    420,
#    493,
#    503,
#    623,
#    623,
#    654,
#    733,
#    741,
#    757,
#    946,
#    990,
#    1003]),
#  ('diamond', 2, [256, 389]),
#  ('olivi', 1, [419]),
#  ('rompr', 1, [543]),
#  ('improv', 12, [71, 354, 377, 387, 406, 440, 589, 693, 728, 852, 867, 897]),
#  ('snowscienc', 3, [150, 185, 526]),
#  ('socialventur', 1, [589]),
#  ('bishop', 1, [916]),
#  ('dr', 4, [105, 163, 226, 365]),
#  ('scm2018', 2, [203, 662]),
#  ('votr', 6, [12, 160, 548, 665, 848, 1048]),
#  ('détect', 1, [383]),
#  ('treatment', 2, [166, 547]),
#  ('dec', 1, [301]),
#  ('15th', 1, [590]),
#  ('gafam', 1, [924]),
#  ('polimi', 1, [639]),
#  ('satellit', 1, [666]),
#  ('nutrit', 2, [606, 850]),
#  ('giulia', 1, [633]),
#  ('prototyp', 1, [983]),
#  ('cornavin', 1, [671]),
#  ('inscrir', 1, [402]),
#  ('httpstco99djfmjkt8', 1, [539]),
#  ('1000', 2, [279, 734]),
#  ('exoskeleton', 2, [486, 871]),
#  ('httpstcou09m0mpdu', 1, [396]),
#  ('bouri', 1, [861]),
#  ('httpstco7q3ofxp28a', 1, [311]),
#  ('httpstcotfckevyktq', 1, [89]),
#  ('dite', 1, [174]),
#  ('itself', 1, [84]),
#  ('announc', 7, [78, 137, 479, 703, 950, 963, 1060]),
#  ('oskarfreysing', 1, [979]),
#  ('reli', 1, [1012]),
#  ('httpstcosj1zr4xd52', 1, [243]),
#  ('architecturaux', 1, [967]),
#  ('httpstcornarscdjil', 1, [496]),
#  ('scienceku', 1, [817]),
#  ('httpstcouhcezifc7t', 1, [347]),
#  ('t', 5, [140, 278, 373, 691, 692]),
#  ('flipclass', 1, [429]),
#  ('nwo', 1, [281]),
#  ('forestsandwood', 1, [630]),
#  ('bel', 1, [183]),
#  ('cyberspac', 1, [830]),
#  ('cseminfo', 7, [36, 63, 398, 402, 681, 771, 834]),
#  ('ladysmith', 1, [272]),
#  ('httpstcocvhref9yhb', 1, [252]),
#  ('sec', 1, [492]),
#  ('artmynch', 1, [1073]),
#  ('depriv', 1, [494]),
#  ('dhlab', 1, [316]),
#  ('httpstcoa9sfxas20o', 1, [805]),
#  ('hypocr', 1, [862]),
#  ('industri', 8, [64, 158, 212, 492, 657, 863, 933, 1036]),
#  ('connai', 1, [199]),
#  ('nanoparticl', 1, [577]),
#  ('snsfch', 2, [288, 905]),
#  ('httpstcohm1ccy2pln', 1, [956]),
#  ('httpstcontjzmgmydp', 1, [317]),
#  ('protein', 4, [159, 228, 795, 838]),
#  ('newdawn', 1, [608]),
#  ('16h', 1, [604]),
#  ('epfllibrari', 5, [326, 608, 670, 846, 987]),
#  ('governmentmand', 1, [314]),
#  ('agepoli', 4, [22, 161, 267, 846]),
#  ('thymio', 1, [382]),
#  ('artikel', 1, [969]),
#  ('larsson', 1, [154]),
#  ('httpstcop91qrjk7zg', 1, [242]),
#  ('httpstco1ja3cl59dq', 1, [872]),
#  ('icrc', 2, [830, 975]),
#  ('jilasci', 1, [431]),
#  ('destroy', 1, [577]),
#  ('enc2017', 1, [1005]),
#  ('uneth', 1, [198]),
#  ('lucan', 1, [843]),
#  ('httpstcozpubapi464', 1, [483]),
#  ('naturecomm', 3, [74, 211, 959]),
#  ('golang', 1, [347]),
#  ('httpstcopbmkt2wxcg', 1, [595]),
#  ('ieeeasm', 1, [407]),
#  ('take',
#   17,
#   [27,
#    125,
#    137,
#    341,
#    422,
#    613,
#    628,
#    719,
#    765,
#    772,
#    873,
#    886,
#    937,
#    963,
#    979,
#    1004,
#    1009]),
#  ('unfortun', 1, [461]),
#  ('multidimension', 1, [818]),
#  ('excit',
#   21,
#   [4,
#    60,
#    106,
#    343,
#    358,
#    387,
#    419,
#    427,
#    445,
#    464,
#    474,
#    515,
#    563,
#    576,
#    608,
#    629,
#    951,
#    984,
#    999,
#    1046,
#    1065]),
#  ('ug', 1, [1011]),
#  ('daylight', 1, [376]),
#  ('winter', 3, [368, 749, 963]),
#  ('httpstcozjy1detl', 1, [993]),
#  ('httpstcoohzdqrzejj', 1, [454]),
#  ('zotero', 5, [61, 439, 682, 840, 939]),
#  ('httpstcolyf2gfihav', 1, [486]),
#  ('httpstcob1rcngnblz', 2, [213, 479]),
#  ('soumithchintala', 1, [501]),
#  ('let', 4, [236, 305, 466, 580]),
#  ('butweet', 1, [916]),
#  ('revoir', 1, [12]),
#  ('collis', 2, [210, 318]),
#  ('triest', 2, [545, 663]),
#  ('donnez', 1, [144]),
#  ('pump', 3, [736, 736, 736]),
#  ('httpstcoh7tpm4gwmk', 1, [353]),
#  ('pribabl', 1, [535]),
#  ('lifeinnyon', 1, [192]),
#  ('httpstcox8uurri5oy', 1, [27]),
#  ('blockfest', 1, [561]),
#  ('pratiqu', 4, [61, 252, 265, 342]),
#  ('cluster', 1, [805]),
#  ('postfin', 1, [148]),
#  ('bern', 2, [480, 523]),
#  ('ethrat', 3, [10, 64, 785]),
#  ('villar', 1, [601]),
#  ('cage', 1, [124]),
#  ('clarifi', 1, [133]),
#  ('punta', 1, [919]),
#  ('gillet', 1, [921]),
#  ('citec', 1, [842]),
#  ('lecorbusi', 1, [123]),
#  ('ntusg', 2, [119, 211]),
#  ('soulag', 2, [300, 837]),
#  ('infirmi', 1, [386]),
#  ('justinegdc', 1, [808]),
#  ('skill', 3, [640, 762, 775]),
#  ('entir', 1, [64]),
#  ('policevalai', 1, [979]),
#  ('17', 3, [68, 144, 453]),
#  ('nanofabr', 1, [949]),
#  ('rencontrez', 1, [1035]),
#  ('unildur', 2, [586, 961]),
#  ('type', 4, [356, 732, 840, 880]),
#  ('zusammenarbeit', 1, [425]),
#  ('friday', 1, [765]),
#  ('print', 1, [544]),
#  ('mpagran', 2, [659, 740]),
#  ('httpstcohyakwdur3o', 1, [194]),
#  ('httpstcoxwoypkslri', 1, [221]),
#  ('citecmobilit', 1, [842]),
#  ('chemjob', 1, [617]),
#  ('mayb', 2, [312, 938]),
#  ('meer', 1, [86]),
#  ('stefanotempesta', 1, [127]),
#  ('window', 3, [40, 396, 881]),
#  ('earli', 4, [30, 296, 671, 885]),
#  ('wellunderstood', 1, [809]),
#  ('httpstcoopwuhvzs5d', 1, [896]),
#  ('🇨🇭innov', 1, [888]),
#  ('httpstcoc0vpvlzrbv', 1, [246]),
#  ('swissgam', 2, [313, 624]),
#  ('focus', 2, [303, 507]),
#  ('keep', 3, [14, 91, 1013]),
#  ('jonathonkeat', 1, [534]),
#  ('naturenpj', 1, [119]),
#  ('dark', 6, [110, 111, 355, 620, 674, 811]),
#  ('dy', 1, [1049]),
#  ('deconvolutionlab2', 2, [80, 100]),
#  ('traceepfl', 1, [69]),
#  ('messag', 1, [68]),
#  ('extens', 1, [899]),
#  ('httpstco0xczhd4kon', 1, [949]),
#  ('httpstcofhj9vlbq5r', 1, [1035]),
#  ('warm', 2, [245, 1013]),
#  ('proesbt', 2, [294, 468]),
#  ('darchiv', 1, [202]),
#  ('slasher', 1, [702]),
#  ('httpstcol9zkm8twqz', 1, [579]),
#  ('carandach', 1, [475]),
#  ('internet', 7, [236, 525, 707, 742, 752, 926, 1056]),
#  ('beobsess', 1, [143]),
#  ('past', 1, [296]),
#  ('httpstconxvfsjer13', 1, [823]),
#  ('passionnant', 1, [895]),
#  ('venu', 2, [601, 626]),
#  ('déchet', 1, [383]),
#  ('emmanuelmacron', 1, [1037]),
#  ('ft', 1, [972]),
#  ('volontair', 1, [429]),
#  ('httpstcoxwvnxyfunq', 1, [134]),
#  ('chiefdisrupt', 1, [802]),
#  ('lexposit', 1, [895]),
#  ('httpstcoe16f7bccbu', 1, [529]),
#  ('httpstcoarbz9t2dzx', 1, [181]),
#  ('httpstcovhv9ame2i2', 1, [74]),
#  ('httpstcouocn4jhqwb', 1, [531]),
#  ('sunrised', 1, [582]),
#  ('tout', 4, [63, 356, 382, 740]),
#  ('hang', 2, [411, 626]),
#  ('gianpaolorando', 1, [416]),
#  ('dépend', 1, [783]),
#  ('migrat', 1, [955]),
#  ('erlaubt', 1, [638]),
#  ('faget', 1, [365]),
#  ('voitur', 1, [1021]),
#  ('httpstcoli5nturtjh', 1, [596]),
#  ('5pm', 1, [743]),
#  ('httpstcoyfjvxrlf9n', 1, [354]),
#  ('entreptech', 1, [470]),
#  ('httpstcoj8tp5su3ht', 1, [249]),
#  ('quickli', 1, [289]),
#  ('httpstcot9bil1adqz', 1, [688]),
#  ('need', 9, [65, 65, 116, 510, 511, 519, 736, 802, 915]),
#  ('phantom', 1, [718]),
#  ('payot', 1, [846]),
#  ('plug', 1, [290]),
#  ('swissnexsf', 5, [215, 241, 247, 313, 963]),
#  ('httpstcocbsxy8wduh', 1, [252]),
#  ('httpstco4akq4dxkgd', 1, [430]),
#  ('program', 10, [57, 125, 306, 347, 370, 421, 481, 512, 703, 888]),
#  ('brain',
#   15,
#   [6, 28, 84, 449, 497, 524, 534, 616, 713, 741, 741, 755, 755, 818, 904]),
#  ('3d', 7, [109, 193, 206, 332, 544, 544, 680]),
#  ('duré', 1, [266]),
#  ('bruit', 2, [571, 571]),
#  ('progress', 3, [935, 937, 1053]),
#  ('qualifi', 1, [308]),
#  ('httpstcoqygdqtlvgt', 1, [159]),
#  ('fractur', 1, [1030]),
#  ('httpstcoglezs0jt7p', 1, [74]),
#  ('scellé', 1, [70]),
#  ('lair', 1, [392]),
#  ('love', 6, [125, 263, 418, 466, 624, 743]),
#  ('womenentrepreneur', 1, [688]),
#  ('réalitéaugmenté', 1, [251]),
#  ('souhait', 1, [161]),
#  ('musiqu', 1, [452]),
#  ('fondat', 1, [574]),
#  ('childcar', 2, [60, 308]),
#  ('hubert', 1, [424]),
#  ('occup', 2, [562, 831]),
#  ('eborloz', 1, [282]),
#  ('lyesselaloui', 2, [512, 601]),
#  ('northwesterneng', 1, [805]),
#  ('sequenc', 1, [34]),
#  ('coréenn', 1, [706]),
#  ('httpstco8rlp0zzhyb', 1, [0]),
#  ('vitrag', 1, [1070]),
#  ('poser', 1, [467]),
#  ('prison', 1, [122]),
#  ('wwim15', 2, [475, 476]),
#  ('troi', 2, [43, 900]),
#  ('wirklich', 1, [105]),
#  ('energypoli', 1, [847]),
#  ('sera', 7, [12, 12, 26, 47, 363, 565, 901]),
#  ('httpstcouui9tmgnxt', 1, [916]),
#  ('httpstcot9oxzgtx4h', 1, [997]),
#  ('httpstcodkgmxia7tq', 1, [985]),
#  ('super', 2, [679, 812]),
#  ('httpstcoc9c96wee6b', 1, [106]),
#  ('memotv', 1, [418]),
#  ('cloud', 3, [521, 533, 917]),
#  ('immunotherapyawar', 1, [529]),
#  ('b', 1, [533]),
#  ('int', 1, [1060]),
#  ('rajiv', 1, [915]),
#  ('sestrin1', 1, [35]),
#  ('fight', 2, [229, 717]),
#  ('fulli', 2, [457, 660]),
#  ('finiss', 1, [161]),
#  ('silvia', 1, [322]),
#  ('wave', 5, [44, 328, 527, 534, 908]),
#  ('tonight', 4, [427, 553, 652, 974]),
#  ('transgend', 1, [281]),
#  ('computationalsci', 1, [340]),
#  ('léducat', 2, [297, 382]),
#  ('consid', 2, [340, 350]),
#  ('finland', 1, [102]),
#  ('dashdawai', 1, [952]),
#  ('httpstco94kl7dmd6z', 1, [18]),
#  ('httpstcoy2s3hz1817', 1, [796]),
#  ('bluebrainpjt', 2, [179, 524]),
#  ('easili', 2, [813, 1055]),
#  ('rôle', 1, [488]),
#  ('lallianc', 1, [565]),
#  ('körper', 1, [638]),
#  ('climatechang', 2, [474, 1025]),
#  ('curriculum', 1, [703]),
#  ('httpstcogqk1h9bplr', 1, [825]),
#  ('thebaltimoretim', 1, [814]),
#  ('switzerlandhastal', 1, [285]),
#  ('création', 2, [723, 996]),
#  ('yourself', 3, [7, 50, 260]),
#  ('gqdaley', 2, [359, 556]),
#  ('hubaux', 2, [182, 724]),
#  ('httpstcoxlnmwh85oj', 1, [1020]),
#  ('gise', 2, [441, 772]),
#  ('adrian', 1, [219]),
#  ('toss2017', 1, [471]),
#  ('nachweisbar', 1, [638]),
#  ('modul', 3, [694, 890, 959]),
#  ('mahgenev', 1, [243]),
#  ('httpstcodc4jeabheo', 1, [359]),
#  ('httpstcose4qjvm6z2', 1, [543]),
#  ('moniqu', 1, [1021]),
#  ('lhiver', 1, [877]),
#  ('favorit', 1, [846]),
#  ('perovskit',
#   14,
#   [117, 184, 186, 268, 377, 406, 419, 508, 551, 551, 558, 628, 986, 1004]),
#  ('seasonaldepress', 1, [714]),
#  ('headlin', 2, [630, 808]),
#  ('spread', 1, [530]),
#  ('poverti', 1, [229]),
#  ('projet',
#   13,
#   [12, 205, 304, 386, 403, 567, 569, 740, 780, 857, 955, 1024, 1037]),
#  ('assistez', 1, [894]),
#  ('intracrani', 1, [290]),
#  ('communelausann', 1, [52]),
#  ('anton', 3, [400, 823, 1067]),
#  ('webot', 1, [74]),
#  ('présentent', 1, [889]),
#  ('moyenag', 1, [1054]),
#  ('bionic', 1, [725]),
#  ('particular', 2, [869, 903]),
#  ('ali', 1, [867]),
#  ('should', 4, [108, 572, 691, 791]),
#  ('exempl', 1, [183]),
#  ('wasser', 1, [451]),
#  ('httpstcowabhnsmdd6', 1, [670]),
#  ('gobolo', 1, [698]),
#  ('japan', 3, [144, 342, 715]),
#  ('didn', 1, [692]),
#  ('httpstcoevlw3kf6v', 1, [998]),
#  ('moya', 1, [498]),
#  ('wo', 1, [438]),
#  ('brillant', 1, [246]),
#  ('premier', 4, [390, 464, 570, 939]),
#  ('intel', 4, [234, 241, 533, 624]),
#  ('mikrotechnik', 1, [309]),
#  ('blue', 8, [175, 272, 449, 524, 616, 713, 770, 904]),
#  ('httpstconzhkfztpx', 1, [207]),
#  ('ucadseneg', 1, [233]),
#  ('tune', 5, [78, 125, 374, 432, 813]),
#  ('prendr', 1, [345]),
#  ('httpstcoxaxuscw6kp', 1, [648]),
#  ('versuch', 1, [890]),
#  ('hit', 2, [411, 808]),
#  ('httpstconyebnjz9iq', 1, [726]),
#  ('httpstcojb7mkkvqdd', 1, [20]),
#  ('0', 2, [572, 572]),
#  ('httpstcomrcygxna6g', 1, [229]),
#  ('will',
#   26,
#   [15,
#    78,
#    102,
#    137,
#    213,
#    223,
#    259,
#    301,
#    365,
#    390,
#    401,
#    422,
#    461,
#    464,
#    479,
#    654,
#    655,
#    722,
#    760,
#    772,
#    791,
#    849,
#    863,
#    870,
#    873,
#    899]),
#  ('httpstco5qiiwlrwqj', 1, [129]),
#  ('httpstcoeomfj5c9rg', 1, [422]),
#  ('httpstco4r7b6cemhk', 1, [849]),
#  ('florislondon', 1, [582]),
#  ('développeur', 1, [862]),
#  ('is',
#   95,
#   [14,
#    17,
#    18,
#    27,
#    44,
#    58,
#    59,
#    71,
#    85,
#    85,
#    87,
#    103,
#    104,
#    108,
#    126,
#    126,
#    134,
#    195,
#    198,
#    212,
#    214,
#    231,
#    248,
#    250,
#    258,
#    264,
#    278,
#    281,
#    288,
#    293,
#    301,
#    306,
#    307,
#    312,
#    312,
#    312,
#    317,
#    333,
#    368,
#    375,
#    394,
#    412,
#    415,
#    418,
#    422,
#    444,
#    483,
#    485,
#    490,
#    504,
#    512,
#    530,
#    531,
#    537,
#    553,
#    591,
#    605,
#    607,
#    608,
#    623,
#    628,
#    640,
#    641,
#    641,
#    648,
#    669,
#    669,
#    671,
#    674,
#    684,
#    691,
#    717,
#    717,
#    730,
#    731,
#    764,
#    768,
#    776,
#    797,
#    810,
#    814,
#    816,
#    833,
#    879,
#    898,
#    903,
#    903,
#    905,
#    907,
#    957,
#    965,
#    999,
#    1002,
#    1044,
#    1056]),
#  ('30', 4, [64, 782, 834, 894]),
#  ('séoul', 1, [369]),
#  ('frederickaplan', 5, [183, 501, 592, 925, 958]),
#  ('jmlatt', 3, [356, 603, 857]),
#  ('da', 7, [167, 338, 443, 451, 583, 701, 822]),
#  ('machinelearn', 10, [127, 165, 165, 503, 587, 610, 667, 733, 765, 999]),
#  ('httpstcol86yujnipi', 1, [800]),
#  ('pass', 2, [564, 825]),
#  ('microchip', 1, [636]),
#  ('rethink', 1, [762]),
#  ('dargent', 1, [927]),
#  ('1717', 1, [513]),
#  ('increas', 1, [470]),
#  ('ver', 2, [244, 955]),
#  ('hand', 5, [76, 76, 596, 725, 941]),
#  ('ski', 1, [786]),
#  ('50', 3, [525, 528, 531]),
#  ('startuptickerch', 3, [286, 421, 801]),
#  ('floridi', 1, [22]),
#  ('be',
#   40,
#   [65,
#    78,
#    80,
#    102,
#    108,
#    213,
#    236,
#    263,
#    267,
#    314,
#    325,
#    374,
#    411,
#    447,
#    457,
#    479,
#    501,
#    513,
#    519,
#    547,
#    594,
#    613,
#    613,
#    655,
#    660,
#    666,
#    715,
#    715,
#    760,
#    791,
#    845,
#    846,
#    863,
#    903,
#    909,
#    915,
#    999,
#    1002,
#    1028,
#    1072]),
#  ('swissskil', 1, [346]),
#  ('httpstcon8diph71tu', 1, [582]),
#  ('sustainabilityweek', 1, [586]),
#  ('httpstco1espabvvxp', 1, [379]),
#  ('cleantech', 1, [813]),
#  ('class', 3, [383, 429, 882]),
#  ('support', 10, [60, 99, 157, 264, 286, 522, 594, 605, 703, 720]),
#  ('15h15', 1, [569]),
#  ('httpstcowwogoegeac', 1, [780]),
#  ('about',
#   36,
#   [79,
#    102,
#    103,
#    126,
#    138,
#    163,
#    258,
#    274,
#    288,
#    310,
#    312,
#    323,
#    329,
#    341,
#    365,
#    390,
#    466,
#    481,
#    518,
#    526,
#    545,
#    608,
#    658,
#    663,
#    733,
#    743,
#    790,
#    799,
#    802,
#    804,
#    808,
#    859,
#    888,
#    904,
#    957,
#    987]),
#  ('chuvlausann', 6, [266, 352, 437, 494, 701, 922]),
#  ('novemb', 1, [9]),
#  ('racist', 1, [979]),
#  ('guid', 6, [20, 259, 435, 539, 739, 993]),
#  ('mobilit', 1, [842]),
#  ('hessovalai', 5, [130, 200, 205, 742, 829]),
#  ('raconté', 1, [1022]),
#  ('julnicola', 1, [478]),
#  ('httpstcoqnooqf1xmm', 1, [334]),
#  ('copi', 1, [348]),
#  ('fpbock', 1, [86]),
#  ('problèm', 1, [823]),
#  ('httpstco39urk8zhu9', 1, [905]),
#  ('commentair', 1, [12]),
#  ('these', 8, [85, 116, 269, 323, 414, 511, 641, 859]),
#  ('encor', 3, [168, 402, 627]),
#  ('savanna', 1, [235]),
#  ('httpstcofmf9ged4km', 1, [901]),
#  ('guyparmeiin', 1, [321]),
#  ('httpstcokxjjlgwmy5', 1, [87]),
#  ('traver', 3, [70, 351, 893]),
#  ('42born2cod', 1, [561]),
#  ('afriquemagazin', 1, [1010]),
#  ('alzheim', 6, [131, 149, 264, 532, 879, 997]),
#  ('environ', 4, [104, 171, 292, 442]),
#  ('apprendr', 5, [118, 311, 827, 827, 1026]),
#  ('simul', 4, [74, 74, 436, 454]),
#  ('until', 2, [590, 671]),
#  ('künstlicher', 1, [737]),
#  ('dmp', 1, [756]),
#  ('httpstco6pgdtcpyhq', 1, [817]),
#  ('have',
#   35,
#   [23,
#    45,
#    68,
#    107,
#    122,
#    122,
#    147,
#    269,
#    269,
#    301,
#    427,
#    440,
#    507,
#    512,
#    540,
#    540,
#    547,
#    575,
#    577,
#    620,
#    628,
#    640,
#    671,
#    703,
#    725,
#    732,
#    751,
#    791,
#    812,
#    886,
#    909,
#    1002,
#    1013,
#    1033,
#    1044]),
#  ('httpstcojcpt6xyjzm', 1, [832]),
#  ('neg', 1, [103]),
#  ('chouett', 1, [824]),
#  ('line', 4, [93, 589, 686, 1061]),
#  ('httpstco3qhw8vh9il', 2, [173, 854]),
#  ('retinai', 1, [447]),
#  ('sontil', 1, [921]),
#  ('septembr', 3, [47, 901, 929]),
#  ('httpstcovp03plbbr7', 1, [982]),
#  ('cybersecurityday', 5, [251, 321, 645, 724, 803]),
#  ('internship', 2, [731, 733]),
#  ('wasserstein', 1, [859]),
#  ('albrecht96', 1, [563]),
#  ('molecul', 1, [547]),
#  ('genferse', 1, [451]),
#  ('évaluat', 2, [167, 252]),
#  ('napoleon', 1, [927]),
#  ('httpstcosnrtupk8po', 1, [118]),
#  ('oneher', 1, [591]),
#  ('httpstcomyyi0qn04g', 1, [745]),
#  ('neurosci', 6, [84, 131, 131, 340, 436, 454]),
#  ('flatter', 1, [612]),
#  ('httpstcoluzvtvhqzm', 1, [926]),
#  ('deadlin', 6, [8, 30, 350, 393, 422, 578]),
#  ('climatiqu', 1, [962]),
#  ('progenitor', 1, [734]),
#  ('kiss', 1, [907]),
#  ('museum', 1, [698]),
#  ('trip', 1, [372]),
#  ('potentiel', 1, [889]),
#  ('epigenet', 1, [622]),
#  ('conseil', 1, [857]),
#  ('appri', 1, [1047]),
#  ('fallait', 1, [1071]),
#  ('7047', 1, [161]),
#  ('amparistech', 1, [654]),
#  ('unplug', 1, [333]),
#  ('mental', 1, [627]),
#  ('26', 1, [990]),
#  ('jan', 2, [68, 590]),
#  ('trouverez', 1, [342]),
#  ('httpstcoihihujkfek', 1, [180]),
#  ('researchcheck', 1, [296]),
#  ('flaviacorda', 1, [530]),
#  ('europarlen…', 3, [1057, 1058, 1059]),
#  ('due', 2, [150, 185]),
#  ('nationaltrust', 1, [630]),
#  ('boloabcm', 1, [658]),
#  ('httpstcofeglco5gun', 1, [431]),
#  ('deserv', 1, [413]),
#  ('opportunité', 2, [129, 801]),
#  ('gigant', 1, [75]),
#  ('zhu', 1, [550]),
#  ('falsafi', 1, [533]),
#  ('staircas', 1, [455]),
#  ('sbb', 1, [250]),
#  ('jenmccutcheon', 1, [108]),
#  ('recrut', 1, [592]),
#  ('nobannowal', 1, [1054]),
#  ('httpstcop8px0sqn4q', 1, [803]),
#  ('sketchnot', 1, [431]),
#  ('stone', 1, [293]),
#  ('ucsdnew', 1, [741]),
#  ('pensé', 1, [404]),
#  ('sadapterontel', 1, [962]),
#  ('softrobots……………', 1, [1046]),
#  ('danger', 4, [150, 150, 185, 185]),
#  ('unineuchatel', 1, [402]),
#  ('vélostat', 1, [81]),
#  ('httpstco4hmazta9qa', 1, [49]),
#  ('dachat', 1, [325]),
#  ('ocsdnet', 1, [393]),
#  ('httpstcov534v2bsnc', 1, [334]),
#  ('professionnel', 2, [244, 261]),
#  ('sxswiss', 5, [50, 198, 580, 581, 722]),
#  ('full', 5, [150, 185, 380, 630, 888]),
#  ('httpstcow7pgvntvw', 1, [801]),
#  ('httpstco7lkkao5780', 1, [2]),
#  ('to',
#   298,
#   [0,
#    14,
#    30,
#    38,
#    44,
#    45,
#    57,
#    58,
#    58,
#    60,
#    65,
#    65,
#    65,
#    66,
#    69,
#    71,
#    74,
#    76,
#    77,
#    80,
#    84,
#    84,
#    84,
#    98,
#    100,
#    101,
#    102,
#    104,
#    106,
#    107,
#    107,
#    108,
#    108,
#    109,
#    112,
#    113,
#    114,
#    115,
#    122,
#    122,
#    125,
#    125,
#    140,
#    142,
#    143,
#    148,
#    150,
#    150,
#    150,
#    163,
#    176,
#    180,
#    185,
#    191,
#    198,
#    200,
#    203,
#    206,
#    218,
#    221,
#    229,
#    229,
#    231,
#    232,
#    245,
#    247,
#    247,
#    247,
#    255,
#    257,
#    257,
#    258,
#    259,
#    259,
#    260,
#    260,
#    260,
#    263,
#    267,
#    269,
#    269,
#    274,
#    275,
#    275,
#    285,
#    286,
#    288,
#    293,
#    301,
#    312,
#    312,
#    312,
#    312,
#    312,
#    318,
#    333,
#    335,
#    336,
#    339,
#    339,
#    340,
#    341,
#    343,
#    346,
#    350,
#    353,
#    354,
#    358,
#    359,
#    365,
#    372,
#    374,
#    374,
#    375,
#    375,
#    381,
#    387,
#    387,
#    391,
#    393,
#    395,
#    411,
#    413,
#    418,
#    422,
#    427,
#    428,
#    430,
#    430,
#    434,
#    435,
#    438,
#    440,
#    445,
#    446,
#    447,
#    450,
#    457,
#    460,
#    461,
#    470,
#    471,
#    474,
#    482,
#    485,
#    487,
#    494,
#    496,
#    498,
#    499,
#    501,
#    501,
#    507,
#    507,
#    509,
#    511,
#    512,
#    518,
#    518,
#    518,
#    519,
#    519,
#    522,
#    525,
#    525,
#    530,
#    533,
#    533,
#    539,
#    540,
#    540,
#    542,
#    546,
#    547,
#    550,
#    551,
#    552,
#    556,
#    556,
#    558,
#    561,
#    572,
#    575,
#    577,
#    580,
#    581,
#    582,
#    589,
#    594,
#    601,
#    605,
#    612,
#    613,
#    613,
#    614,
#    615,
#    615,
#    615,
#    615,
#    615,
#    620,
#    624,
#    624,
#    628,
#    637,
#    646,
#    648,
#    652,
#    655,
#    655,
#    656,
#    657,
#    662,
#    669,
#    671,
#    673,
#    677,
#    688,
#    688,
#    692,
#    694,
#    703,
#    703,
#    703,
#    703,
#    712,
#    712,
#    716,
#    717,
#    719,
#    724,
#    726,
#    732,
#    734,
#    734,
#    736,
#    736,
#    736,
#    747,
#    759,
#    769,
#    771,
#    775,
#    778,
#    787,
#    787,
#    787,
#    787,
#    790,
#    802,
#    804,
#    807,
#    814,
#    820,
#    835,
#    846,
#    846,
#    847,
#    849,
#    863,
#    867,
#    869,
#    878,
#    885,
#    888,
#    897,
#    899,
#    907,
#    910,
#    910,
#    915,
#    934,
#    937,
#    938,
#    938,
#    948,
#    951,
#    963,
#    963,
#    966,
#    966,
#    973,
#    979,
#    981,
#    987,
#    991,
#    994,
#    999,
#    999,
#    1000,
#    1002,
#    1002,
#    1006,
#    1006,
#    1009,
#    1013,
#    1064,
#    1072]),
#  ('lappel', 1, [526]),
#  ('walli', 2, [185, 743]),
#  ('février', 1, [252]),
#  ('httpstco1ub7y6bcku', 1, [693]),
#  ('cant', 1, [359]),
#  ('train', 5, [116, 200, 391, 557, 775]),
#  ...]

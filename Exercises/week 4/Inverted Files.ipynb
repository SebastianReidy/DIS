# %% [markdown]
# ## 📚 Exercise 2: Inverted Files
#
# In this exercise, we will understand the functioning of the Inverted Files and how implement them using MapReduce.
#
# ### Overview
#
# We learnt in the lecture that terms are typically stored in an inverted list. Now, in the inverted list, instead of only storing document identifiers of the documents in which the term appears, assume we also store an *offset* of the appearance of a term in a document. An $offset$ of a term $l_k$ given a document is defined as the number of words between the start of the document and $l_k$. Thus our inverted list is now:
#
# $l_k= \langle f_k: \{d_{i_1} \rightarrow [o_1,\ldots,o_{n_{i_1}}]\},
# \{d_{i_2} \rightarrow [o_1,\ldots,o_{n_{i_2}}]\}, \ldots,
# \{d_{i_k} \rightarrow [o_1,\ldots,o_{n_{i_k}}]\} \rangle$
#
# This means that in document $d_{i_1}$ term $l_k$ appears $n_{i_1}$ times and at offset $[o_1,\ldots,o_{n_{i_1}}]$, where $[o_1,\ldots,o_{n_{i_1}}]$ are sorted in ascending order, these type of indices are also known as term-offset indices. An example of a term-offset index is as follows:
#
# **Obama** = $⟨4 : {1 → [3]},{2 → [6]},{3 → [2,17]},{4 → [1]}⟩$
#
# **Governor** = $⟨2 : {4 → [3]}, {7 → [14]}⟩$
#
# **Election** = $⟨4 : {1 → [1]},{2 → [1,21]},{3 → [3]},{5 → [16,22,51]}⟩$
#
# Which is to say that the term **Governor** appear in 2 documents. In document 4 at offset 3, in document 7 at offset 14. Now let us consider the *SLOP/x* operator in text retrieval. This operator has the syntax: *QueryTerm1 SLOP/x QueryTerm2* finds occurrences of *QueryTerm1* within $x$ (but not necessarily in that order) words of *QueryTerm2*, where $x$ is a positive integer argument ($x \geq 1$). Thus $x = 1$ demands that *QueryTerm1* be adjacent to *QueryTerm2*.
#
# ### Questions
#
# 1. List the set of documents that satisfy the query **Obama** *SLOP/2* **Election**.
# - Slop: words in a two neighborhood of the second query have to satisfy the first one: 1, 3
# 2. List each set of values for which the query **Obama** *SLOP/x* **Election** has a different set of documents as answers (starting from $x = 1$).
# - x=0 -> {}, x=1 -> {3}, x=2 -> {1,3}, x=3 -> {1,3}, x=5+ -> {1,2,3}
# 3. Consider the general procedure for "merging" two term-offset inverted lists for a given document, to determine where the document satisfies a *SLOP/x* clause (since in general there will be many offsets at which each term occurs in a document). Let $L$ denote the total number of occurrences of the two terms in the document. Assume we have a pointer to the list of occurrences of each term and can move the pointer along this list. As we do so we check whether we have a hit for $SLOP/x$ (i.e. the $SLOP/x$ clause is satisfied). Each move of either pointer counts as a step. Based on this assumption is there a general "merging" procedure to determine whether the document satisfies a $SLOP/x$ clause, for which the following is true? Justify your answer.
#
#     1. The merge can be accomplished in a number of steps linear in $L$ regardless of $x$, and we can ensure that each pointer moves only to the right (i.e. forward).
#     - This holds if the list is sorted.
#     2. The merge can be accomplished in a number of steps linear in $L$, but a pointer may be forced to move to the left (i.e. backwards).
#     - Again, if the lists are sorted the pointers only move in one direction => O(L) time & NO
#     3. The merge can require $x \times L$ steps in some cases.
#     - No O(L) is possible since the pointer only moves to the left

# %% [markdown]
# ## Create inverted files using MapReduce
# In this exercise, we want to create the inverted files using the MapReduce framework. Write the **map** and **reduce** function.
# Note that the code of **run_mapreduce** is just a simulation of the behavior of  map-reduce system.
#
# ## Goal:
# - Create inverted files using the MapReduce framework.
# - Test the implementation on `epfldocs.txt` data.
#
# ### What you are learning in this exercise:
# - Having a better understanding of inverted files.
# - Learn how to implement inverted files using the MapReduce framework.

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer
import nltk
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
import string
from nltk.corpus import stopwords
import math
from collections import Counter
import numpy as np
nltk.download('stopwords')
nltk.download('punkt')

stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sebastian/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/sebastian/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Tokenize, stem a document
def tokenize(text):
    """
    It tokenizes and stems an input text.
    
    :param text: str, with the input text
    :return: list, of the tokenized and stemmed tokens.
    """
    text = "".join([ch for ch in text if ch not in string.punctuation])
    tokens = nltk.word_tokenize(text)
    return " ".join([stemmer.stem(word.lower()) for word in tokens])

with open("epfldocs.txt") as f:
    content = f.readlines()
original_documents = [x.strip() for x in content] 
documents = [tokenize(d).split() for d in original_documents]
docs_n_doc_ids = list(zip(range(len(documents)), documents))

# %%
# Take a pair (doc_id, content). Example: (0, ['how', 'to', 'bake', 'bread', 'without', 'bake', 'recip'])
# Return: list of (word, doc_id). Example: ('bake', 0)
# For simplicity, we assume each mapper handles a document
def map_function(doc_id, content):
    keyvals = []
    for word in content:
        keyvals.append((word, doc_id))
        # YOUR CODE HERE (above)
    return keyvals

# %%
# Take a list of pairs (word, doc_id). Example:  [('bake', 0), ('bake', 0), ('bake', 3)]
# Return: (word, frequency, list of document ids). Example ('bake', 3, [0, 0, 3])
# For simplicity, we assume each reducer handles a word
from pydoc import doc


def reduce_function(lst):
    total = 0
    word = lst[0][0]
    doc_ids = []
    for w, doc_id in lst:
        assert(word==w) # Assume each reducer handles 1 word
        total +=1 
        doc_ids.append(doc_id)
        # YOUR CODE HERE (above)
    return (word, total, doc_ids)

# %%
# We simulate the mapreduce framework by this function
def run_mapreduce(docs_n_doc_ids):
    # Map phase
    key_values = []
    for doc_id, doc_content in docs_n_doc_ids:
        key_values.extend(map_function(doc_id, doc_content))
    # Shuffle phase
    values = set(map(lambda x:x[0], key_values))
    grouped_key_values = [[y for y in key_values if y[0]==x] for x in values]
    # Reduce phase
    inverted_files = []
    for grouped_key_value in grouped_key_values:
        word, total, doc_ids = reduce_function(grouped_key_value)
        inverted_files.append((word, total, doc_ids))
    return inverted_files

# %%
run_mapreduce(docs_n_doc_ids)
# Out:
# [('httpstcop0nrthhzqz', 1, [599]),
#  ('teacher', 2, [493, 593]),
#  ('httpstconok4aklk3a', 1, [557]),
#  ('shadaislam', 1, [270]),
#  ('glare', 1, [770]),
#  ('httpstconxduwheyyj', 1, [468]),
#  ('epflinnov', 1, [677]),
#  ('abl', 3, [84, 655, 863]),
#  ('innovant', 1, [1026]),
#  ('melodi', 1, [750]),
#  ('httpstcoh8cjpqe2', 1, [744]),
#  ('disrupt', 2, [521, 951]),
#  ('httpstcom2mwuq78mg', 1, [280]),
#  ('age', 4, [184, 186, 508, 833]),
#  ('sequencedirect', 1, [378]),
#  ('ich', 2, [890, 954]),
#  ('httpstcovu27gw28in', 1, [455]),
#  ('seem', 1, [373]),
#  ('embl', 1, [674]),
#  ('fail', 1, [813]),
#  ('mobilitätswend', 1, [1011]),
#  ('alternatif', 1, [857]),
#  ('geoschoolday2017', 2, [441, 772]),
#  ('httpstcoarslxzoshq', 1, [4]),
#  ('unterworfen', 1, [638]),
#  ('httpstcohtryoqhyq7', 1, [370]),
#  ('pattern', 2, [6, 387]),
#  ('tdgch', 3, [1054, 1070, 1071]),
#  ('satellit', 1, [666]),
#  ('these', 8, [85, 116, 269, 323, 414, 511, 641, 859]),
#  ('detail', 2, [125, 888]),
#  ('httpstcouyp6thrhbm', 1, [564]),
#  ('therapist', 1, [1029]),
#  ('effici', 8, [398, 595, 628, 628, 681, 695, 771, 834]),
#  ('httpstcopuml0rsj8d', 1, [782]),
#  ('problem', 2, [260, 260]),
#  ('jeanphilipp', 1, [431]),
#  ('httpstco856yhgi74j', 1, [58]),
#  ('tomberont', 1, [651]),
#  ('httpstcobid211ncnp', 1, [558]),
#  ('favorit', 1, [846]),
#  ('peter', 1, [957]),
#  ('montserrat', 1, [227]),
#  ('varient', 1, [925]),
#  ('ucsdnew', 1, [741]),
#  ('httpstcomll94mdiwz', 1, [332]),
#  ('httpstcoxzqq8zekqj', 1, [729]),
#  ('httpstcoynay98tg4b', 1, [622]),
#  ('httpstcont7v9hkz3o', 1, [239]),
#  ('mechanicclock', 1, [971]),
#  ('httpstcol977bmopel', 1, [390]),
#  ('not',
#   15,
#   [1, 45, 104, 260, 312, 335, 461, 512, 587, 655, 863, 863, 872, 903, 965]),
#  ('placecosandey', 1, [604]),
#  ('jeu', 1, [633]),
#  ('acsnano', 1, [916]),
#  ('laisser', 1, [1049]),
#  ('jonathonkeat', 1, [534]),
#  ('bad', 3, [104, 335, 575]),
#  ('protéin', 2, [405, 424]),
#  ('contrib', 1, [740]),
#  ('defin', 2, [260, 260]),
#  ('consid', 2, [340, 350]),
#  ('percept', 2, [292, 322]),
#  ('smartciti', 1, [963]),
#  ('scari', 1, [1044]),
#  ('snowscienc', 3, [150, 185, 526]),
#  ('msc', 1, [323]),
#  ('eric', 1, [327]),
#  ('target', 3, [242, 519, 746]),
#  ('confess', 1, [122]),
#  ('nanotechnolog', 1, [196]),
#  ('httpstcokrppxbgqqk', 1, [537]),
#  ('kinet', 1, [248]),
#  ('paris2024', 1, [1042]),
#  ('merri', 1, [263]),
#  ('quelqu', 3, [325, 402, 939]),
#  ('httpstcoh3jz6pjmta', 1, [544]),
#  ('httpstcomdanih1v5h', 1, [45]),
#  ('299', 1, [578]),
#  ('key', 1, [643]),
#  ('punkt', 1, [890]),
#  ('httpstcohxsovlrngb', 1, [107]),
#  ('bilanz', 1, [295]),
#  ('inherit', 1, [422]),
#  ('espion', 1, [599]),
#  ('prospérité', 1, [26]),
#  ('no1', 1, [4]),
#  ('introductori', 1, [34]),
#  ('facad', 1, [155]),
#  ('sae', 1, [574]),
#  ('httpstco99djfmjkt8', 1, [539]),
#  ('claquer', 1, [927]),
#  ('httpstcoywky7cxgbd', 1, [342]),
#  ('françai', 3, [244, 744, 939]),
#  ('httpstcoulurhrsqwi', 1, [353]),
#  ('parmelin', 1, [238]),
#  ('nberpub', 4, [294, 294, 468, 468]),
#  ('occur', 1, [45]),
#  ('ehr', 1, [25]),
#  ('httpstcoh5x6sei7od', 1, [387]),
#  ('lch', 1, [400]),
#  ('foresti', 1, [653]),
#  ('httpstco8wktgl06vq', 1, [881]),
#  ('sconnect', 1, [62]),
#  ('wef17', 2, [396, 776]),
#  ('art', 5, [210, 210, 243, 316, 969]),
#  ('golfweek', 1, [1018]),
#  ('scientist', 12, [6, 77, 84, 132, 135, 159, 264, 394, 628, 648, 725, 732]),
#  ('hand', 5, [76, 76, 596, 725, 941]),
#  ('httpstcosmknizeyip', 1, [898]),
#  ('legales', 1, [236]),
#  ('dgtswitzerland',
#   16,
#   [148,
#    200,
#    251,
#    263,
#    321,
#    382,
#    399,
#    501,
#    506,
#    525,
#    573,
#    573,
#    624,
#    645,
#    826,
#    1024]),
#  ('considér', 1, [62]),
#  ('httpstcos3gmguc9sf', 1, [997]),
#  ('httpstcokm1p7dnpr4', 1, [919]),
#  ('jai', 5, [12, 287, 659, 1030, 1043]),
#  ('each', 2, [858, 858]),
#  ('vusurlecampu', 3, [331, 794, 877]),
#  ('focus', 2, [303, 507]),
#  ('dernièr', 1, [12]),
#  ('passion', 1, [143]),
#  ('lyesselaloui', 2, [512, 601]),
#  ('haben', 2, [443, 451]),
#  ('potenti', 6, [69, 112, 158, 547, 677, 734]),
#  ('lifespan', 1, [55]),
#  ('scrutini', 1, [564]),
#  ('deepartio', 1, [612]),
#  ('idiap', 1, [859]),
#  ('saveourwildcat', 1, [630]),
#  ('httpstcomboskllti5', 1, [507]),
#  ('presidentielle2017', 1, [825]),
#  ('ailleur', 1, [896]),
#  ('run', 3, [166, 490, 539]),
#  ('news', 2, [4, 630]),
#  ('modestinogroup', 1, [626]),
#  ('erlaubt', 1, [638]),
#  ('waterborn', 1, [248]),
#  ('ventur', 3, [286, 506, 1027]),
#  ('gerolimini', 1, [805]),
#  ('singlephoton', 1, [226]),
#  ('tueindhoven', 3, [71, 669, 1006]),
#  ('ecosystem', 1, [432]),
#  ('httpstcoju8ess8cuj', 1, [798]),
#  ('differ', 3, [176, 648, 734]),
#  ('httpstco1kcnfc67xr', 1, [996]),
#  ('activ', 11, [6, 24, 67, 153, 333, 335, 470, 697, 724, 755, 932]),
#  ('httpstcomass98crri', 2, [328, 527]),
#  ('oscienc', 9, [24, 67, 111, 153, 328, 355, 527, 811, 932]),
#  ('turn', 4, [333, 360, 396, 722]),
#  ('robot',
#   50,
#   [9,
#    14,
#    17,
#    31,
#    86,
#    102,
#    102,
#    104,
#    169,
#    169,
#    208,
#    246,
#    249,
#    254,
#    292,
#    353,
#    379,
#    379,
#    407,
#    407,
#    407,
#    414,
#    414,
#    414,
#    414,
#    425,
#    440,
#    450,
#    585,
#    585,
#    599,
#    647,
#    651,
#    660,
#    703,
#    719,
#    774,
#    835,
#    835,
#    871,
#    897,
#    905,
#    924,
#    926,
#    942,
#    972,
#    1008,
#    1029,
#    1033,
#    1038]),
#  ('référenc', 3, [739, 993, 993]),
#  ('polair', 1, [636]),
#  ('25novemb', 1, [774]),
#  ('damasio', 1, [472]),
#  ('httpstcoxeefqwvkbf', 1, [601]),
#  ('danser', 2, [168, 197]),
#  ('optimis', 1, [636]),
#  ('energyeffici', 1, [867]),
#  ('succè', 3, [565, 665, 705]),
#  ('opendatach', 3, [587, 621, 656]),
#  ('produc', 6, [64, 80, 301, 497, 533, 680]),
#  ('wed', 1, [301]),
#  ('nouvel', 3, [705, 882, 893]),
#  ('chemistri', 5, [171, 275, 720, 743, 847]),
#  ('scnatch', 1, [201]),
#  ('symposium', 3, [28, 481, 807]),
#  ('winter', 3, [368, 749, 963]),
#  ('al', 6, [264, 608, 661, 735, 851, 948]),
#  ('disabl', 1, [649]),
#  ('ouvron', 1, [282]),
#  ('public', 10, [13, 107, 163, 301, 339, 366, 635, 745, 975, 1017]),
#  ('open',
#   26,
#   [2,
#    49,
#    54,
#    109,
#    188,
#    245,
#    260,
#    348,
#    393,
#    393,
#    420,
#    442,
#    453,
#    480,
#    504,
#    515,
#    587,
#    590,
#    688,
#    688,
#    703,
#    730,
#    850,
#    898,
#    911,
#    960]),
#  ('voir', 1, [644]),
#  ('httpstco0l63qx5qmr', 1, [400]),
#  ('entier', 1, [644]),
#  ('httpstcohrx0n07gtj', 1, [469]),
#  ('pain', 3, [718, 907, 907]),
#  ('raclett', 1, [587]),
#  ('shine', 1, [269]),
#  ('place', 12, [0, 0, 137, 283, 429, 560, 764, 873, 886, 976, 977, 1048]),
#  ('besar', 1, [1020]),
#  ('chicco785', 1, [346]),
#  ('businessinsider…', 1, [897]),
#  ('httpstcoknbo1qjpfq', 1, [976]),
#  ('repèr', 1, [266]),
#  ('httpstcom80vlqskfq', 1, [1069]),
#  ('httpstcoevqyqd7ffl', 1, [30]),
#  ('ferdinand', 1, [927]),
#  ('mauricelibrarysecur', 3, [325, 345, 860]),
#  ('protéger', 1, [1050]),
#  ('httpstcojnmlxmguo', 1, [316]),
#  ('tensorflow', 1, [276]),
#  ('15h15', 1, [569]),
#  ('messag', 1, [68]),
#  ('httpstcoewpqrcc817', 1, [733]),
#  ('verantwortung', 1, [105]),
#  ('ic', 2, [287, 316]),
#  ('codeweekch', 1, [333]),
#  ('codeur', 1, [233]),
#  ('artwork', 1, [458]),
#  ('fds2017', 1, [766]),
#  ('httpstcooyjavnzdna', 1, [647]),
#  ('antichrist', 1, [281]),
#  ('lemondefr', 1, [109]),
#  ('impost', 2, [249, 414]),
#  ('50', 3, [525, 528, 531]),
#  ('vet', 1, [308]),
#  ('rich', 1, [5]),
#  ('hi',
#   16,
#   [142,
#    142,
#    195,
#    296,
#    310,
#    458,
#    485,
#    503,
#    550,
#    550,
#    674,
#    816,
#    855,
#    867,
#    869,
#    960]),
#  ('httpstcopxrazr8xo1', 1, [245]),
#  ('miss', 6, [35, 512, 559, 635, 732, 909]),
#  ('httpstcouwvuz7i9v9', 1, [501]),
#  ('irem\u200b', 1, [77]),
#  ('httpstcozsy1cshedk', 1, [196]),
#  ('fête', 1, [277]),
#  ('httpstcoaa0crtmgnf', 1, [294]),
#  ('cela', 2, [356, 392]),
#  ('mesnier', 1, [63]),
#  ('httpstcojr2dh5kofq', 1, [22]),
#  ('2nd', 3, [391, 393, 899]),
#  ('httpstcofiup9zphwo', 1, [26]),
#  ('venturekick', 1, [247]),
#  ('festiv', 2, [313, 1032]),
#  ('materialwissenschaft', 1, [309]),
#  ('tweet', 1, [160]),
#  ('on🇪🇺eufund', 1, [717]),
#  ('myswitzerlandf', 1, [15]),
#  ('lappel', 1, [526]),
#  ('liker', 1, [366]),
#  ('httpstcorm46e0v8gi', 1, [628]),
#  ('vincent', 1, [463]),
#  ('stream', 1, [119]),
#  ('trace', 4, [24, 67, 153, 932]),
#  ('httpstcoayzqdgq6r4', 1, [449]),
#  ('metoo', 1, [979]),
#  ('markboulo', 1, [247]),
#  ('mélodi', 1, [942]),
#  ('httpstco9qmkshraqj', 1, [802]),
#  ('sontil', 1, [921]),
#  ('gill', 1, [15]),
#  ('exposit', 4, [93, 453, 844, 844]),
#  ('srfarena', 1, [890]),
#  ('participatif', 1, [569]),
#  ('osaopex', 2, [712, 966]),
#  ('passport', 1, [1073]),
#  ('httpstco9lr6sbjlil', 1, [669]),
#  ('httpstcoot4yk1wuoo', 1, [493]),
#  ('mainten', 3, [307, 567, 1019]),
#  ('httpstcosn49k4qc8o', 1, [877]),
#  ('🌱', 1, [637]),
#  ('meta', 1, [80]),
#  ('12000', 1, [684]),
#  ('httpstcozwtkplh6ht', 1, [420]),
#  ('scrnaseq', 1, [734]),
#  ('👉httpstcoplgg4cfe4t', 1, [281]),
#  ('ceremoni', 5, [137, 238, 255, 288, 767]),
#  ('sur',
#   37,
#   [11,
#    12,
#    26,
#    61,
#    149,
#    244,
#    252,
#    283,
#    302,
#    342,
#    342,
#    383,
#    408,
#    437,
#    463,
#    554,
#    566,
#    571,
#    604,
#    653,
#    705,
#    740,
#    744,
#    922,
#    925,
#    953,
#    961,
#    978,
#    978,
#    1019,
#    1023,
#    1035,
#    1040,
#    1042,
#    1063,
#    1066,
#    1067]),
#  ('scriven', 1, [748]),
#  ('httpstco0gkajw4qsi', 1, [666]),
#  ('except', 2, [605, 790]),
#  ('doe', 3, [260, 613, 736]),
#  ('eucommiss', 7, [140, 237, 391, 549, 1057, 1058, 1059]),
#  ('🚆ferroviair', 1, [567]),
#  ('easi', 2, [321, 373]),
#  ('6th', 1, [301]),
#  ('sdscdatasci', 7, [235, 295, 443, 480, 610, 982, 984]),
#  ('enabl', 3, [229, 259, 628]),
#  ('lecercleduth', 1, [192]),
#  ('💡👉httpstcoobwvlkso6f', 1, [936]),
#  ('hackuarium', 1, [176]),
#  ('httpstcosmokpqawtf', 1, [510]),
#  ('mjf', 1, [844]),
#  ('demain', 4, [39, 243, 265, 1037]),
#  ('contribu', 1, [26]),
#  ('lead', 7, [139, 237, 354, 558, 577, 712, 966]),
#  ('coder', 2, [347, 1047]),
#  ('nsf', 1, [697]),
#  ('dmfunil', 1, [86]),
#  ('detect', 3, [695, 926, 1008]),
#  ('them', 11, [109, 259, 458, 577, 641, 679, 679, 691, 778, 899, 938]),
#  ('fox', 1, [945]),
#  ('httpstcop7t3kzdyer', 1, [73]),
#  ('httpstcop6oxc1fnh6', 1, [683]),
#  ('auch', 2, [319, 890]),
#  ('httpstcoivlpjaimhi', 2, [256, 389]),
#  ('reduc', 2, [718, 907]),
#  ('httpstcofqknaemwgu', 1, [193]),
#  ('africangeek', 1, [233]),
#  ('également', 1, [682]),
#  ('no', 8, [65, 107, 236, 615, 620, 674, 938, 979]),
#  ('evid', 1, [110]),
#  ('httpstcot7ui6snzek', 1, [1067]),
#  ('assistez', 1, [894]),
#  ('httpstcosrdnowtcyu', 1, [517]),
#  ('attack', 2, [547, 880]),
#  ('good',
#   16,
#   [3,
#    83,
#    100,
#    190,
#    275,
#    307,
#    485,
#    511,
#    575,
#    626,
#    626,
#    716,
#    746,
#    960,
#    1046,
#    1065]),
#  ('clubhealthcar', 1, [1003]),
#  ('stew', 1, [190]),
#  ('collid', 2, [273, 1016]),
#  ('spheroid', 1, [100]),
#  ('signatur', 1, [365]),
#  ('décret', 1, [1054]),
#  ('coldion', 1, [661]),
#  ('sticker', 1, [409]),
#  ('prematur', 1, [514]),
#  ('sustain', 7, [229, 401, 510, 669, 669, 748, 915]),
#  ('speci', 3, [446, 491, 777]),
#  ('httpstcowsnmjekhmo', 1, [770]),
#  ('guider', 1, [789]),
#  ('sphere', 1, [221]),
#  ('yet', 2, [691, 903]),
#  ('center',
#   17,
#   [54,
#    194,
#    390,
#    443,
#    464,
#    476,
#    480,
#    546,
#    606,
#    640,
#    829,
#    872,
#    973,
#    974,
#    992,
#    1009,
#    1048]),
#  ('it',
#   62,
#   [21,
#    31,
#    44,
#    44,
#    50,
#    58,
#    58,
#    73,
#    85,
#    91,
#    91,
#    103,
#    110,
#    115,
#    124,
#    126,
#    134,
#    155,
#    198,
#    206,
#    214,
#    215,
#    224,
#    247,
#    271,
#    312,
#    312,
#    318,
#    337,
#    348,
#    373,
#    390,
#    390,
#    418,
#    464,
#    480,
#    490,
#    499,
#    501,
#    530,
#    530,
#    581,
#    581,
#    613,
#    635,
#    650,
#    650,
#    657,
#    703,
#    722,
#    726,
#    809,
#    839,
#    845,
#    858,
#    903,
#    904,
#    938,
#    938,
#    1009,
#    1055,
#    1060]),
#  ('agepoli', 4, [22, 161, 267, 846]),
#  ('surtout', 1, [1049]),
#  ('infiltr', 2, [249, 414]),
#  ('shortliv', 1, [66]),
#  ('version', 2, [164, 343]),
#  ('httpstcoqygdqtlvgt', 1, [159]),
#  ('société', 1, [565]),
#  ('bibliographiqu', 2, [602, 739]),
#  ('propriété', 1, [923]),
#  ('httpstco9f2iuduopr', 1, [1008]),
#  ('neinzunobillag', 1, [144]),
#  ('école', 2, [913, 1062]),
#  ('httpstcokjzgnss9y0', 1, [265]),
#  ('write', 3, [200, 346, 391]),
#  ('doehlergroup', 1, [522]),
#  ('psychologist', 1, [507]),
#  ('ex', 1, [739]),
#  ('epflsb', 2, [406, 757]),
#  ('showcas', 1, [990]),
#  ('oncl', 1, [927]),
#  ('httpstcovui3aaz3z6', 1, [968]),
#  ('commeric', 1, [628]),
#  ('minuten', 1, [1015]),
#  ('httpstcob9jpcjfjsz', 1, [640]),
#  ('präsident', 1, [1015]),
#  ('expo', 2, [174, 1060]),
#  ('fpbock', 1, [86]),
#  ('httpstcoilctlfatmt', 1, [340]),
#  ('httpstcodp3fdxfp3z', 1, [941]),
#  ('silk', 1, [172]),
#  ('dr', 4, [105, 163, 226, 365]),
#  ('httpstcoptjukxxkk4', 1, [79]),
#  ('gigant', 1, [75]),
#  ('massiv', 1, [515]),
#  ('uber', 1, [930]),
#  ('analyz', 1, [690]),
#  ('laperrouza', 1, [900]),
#  ('databas', 2, [133, 415]),
#  ('cecam', 1, [335]),
#  ('eel', 2, [145, 926]),
#  ('worldli', 1, [675]),
#  ('delay', 1, [108]),
#  ('keep', 3, [14, 91, 1013]),
#  ('httpstco1rc2edm3bc', 1, [913]),
#  ('olymp', 1, [1042]),
#  ('wait', 2, [255, 899]),
#  ('feasibl', 1, [101]),
#  ('entrepreneuri', 1, [910]),
#  ('populair', 1, [742]),
#  ('fiberopt', 1, [544]),
#  ('httpstcossx0gcjaki', 1, [457]),
#  ('angewchem', 1, [550]),
#  ('informatiqu', 2, [742, 742]),
#  ('resumé', 1, [181]),
#  ('let', 4, [236, 305, 466, 580]),
#  ('user', 3, [23, 236, 438]),
#  ('httpstcon8diph71tu', 1, [582]),
#  ('httpstcoubvaih1mjp', 1, [711]),
#  ('jp', 1, [724]),
#  ('devenu', 1, [921]),
#  ('weed', 1, [31]),
#  ('blockfest', 1, [561]),
#  ('grenobleinp', 1, [196]),
#  ('httpstcoixgzzoaatx', 1, [658]),
#  ('creapol', 1, [346]),
#  ('swissnex', 1, [963]),
#  ('dario', 1, [318]),
#  ('demonstr', 2, [104, 909]),
#  ('httpstcoj2equhxb66', 1, [309]),
#  ('bese', 1, [741]),
#  ('action', 2, [541, 549]),
#  ('aleaf', 1, [237]),
#  ('fev', 1, [144]),
#  ('two', 9, [23, 206, 373, 407, 605, 791, 898, 1006, 1013]),
#  ('kakkoii', 1, [715]),
#  ('génie', 1, [842]),
#  ('s',
#   27,
#   [13,
#    44,
#    58,
#    58,
#    104,
#    114,
#    152,
#    248,
#    292,
#    337,
#    473,
#    517,
#    532,
#    589,
#    592,
#    630,
#    684,
#    755,
#    770,
#    770,
#    817,
#    849,
#    849,
#    853,
#    935,
#    968,
#    975]),
#  ('kinemat', 1, [786]),
#  ('fondamental', 1, [827]),
#  ('rx', 1, [109]),
#  ('champel28', 1, [1071]),
#  ('dieser', 1, [105]),
#  ('perspect', 2, [562, 831]),
#  ('httpstcoaskf9ui0mi', 1, [511]),
#  ('vegan', 1, [253]),
#  ('testament', 1, [70]),
#  ('mxartlab', 1, [781]),
#  ('syndic', 1, [857]),
#  ('cisbat2017', 1, [804]),
#  ('httpstcozyenraseir', 1, [5]),
#  ('mister', 2, [330, 819]),
#  ('httpstcoupvwgqkpez', 1, [973]),
#  ('knight', 1, [99]),
#  ('fitfund', 1, [891]),
#  ('groupecofina', 2, [269, 559]),
#  ('marzari', 1, [89]),
#  ('codev', 1, [1007]),
#  ('adressé', 1, [742]),
#  ('présidenc', 1, [665]),
#  ('humanbrainproj', 1, [709]),
#  ('host', 7, [15, 445, 501, 513, 594, 724, 741]),
#  ('edtech', 6, [91, 222, 273, 273, 386, 652]),
#  ('florislondon', 1, [582]),
#  ('effet', 1, [978]),
#  ('9', 6, [39, 202, 525, 586, 615, 741]),
#  ('newdawn', 1, [608]),
#  ('httpstcoznphy0ralc', 1, [57]),
#  ('fill', 4, [742, 752, 752, 1047]),
#  ('assembl', 1, [378]),
#  ('httpstcoitndng8wsf', 1, [85]),
#  ('mobil', 8, [37, 104, 250, 275, 292, 294, 468, 842]),
#  ('httpstcoybkxlwpuow', 1, [348]),
#  ('held', 1, [126]),
#  ('hauteecolearc', 1, [402]),
#  ('instagram', 1, [345]),
#  ('cmi', 1, [225]),
#  ('cdmissionindia', 1, [15]),
#  ('mblokesch', 1, [513]),
#  ('tdiethinktank', 1, [815]),
#  ('edit', 2, [390, 464]),
#  ('conseilepf', 1, [785]),
#  ('prendrai', 1, [61]),
#  ('enorm', 1, [158]),
#  ('undergrad', 1, [88]),
#  ('httpstcosp5h61ese', 1, [738]),
#  ('multijunct', 2, [398, 681]),
#  ('surround', 1, [1032]),
#  ('httpstcosx2wyozlpj', 1, [168]),
#  ('httpstco2n1qwhfuti', 1, [456]),
#  ('httpstcolyf2gfihav', 1, [486]),
#  ('currenc', 2, [294, 468]),
#  ('scm2018', 2, [203, 662]),
#  ('securityprivaci', 1, [640]),
#  ('httpstco8owqib0csc', 1, [96]),
#  ('grow', 2, [410, 589]),
#  ('philipp', 3, [162, 213, 479]),
#  ('dachat', 1, [325]),
#  ('httpstcowyhpdhbcq1', 1, [821]),
#  ('ta', 1, [790]),
#  ('stori', 3, [163, 231, 846]),
#  ('ericdubay', 2, [99, 240]),
#  ('creat', 10, [395, 414, 414, 449, 480, 534, 546, 547, 669, 858]),
#  ('proje…', 1, [93]),
#  ('httpstcog09yb45hzq', 1, [254]),
#  ('servir', 1, [682]),
#  ('httpstcosikakpfu0o', 1, [684]),
#  ('cage', 1, [124]),
#  ('previous', 1, [45]),
#  ('jilasci', 1, [431]),
#  ('•', 1, [613]),
#  ('httpstcowpkspxtdc9', 1, [460]),
#  ('par',
#   22,
#   [157,
#    160,
#    172,
#    197,
#    261,
#    327,
#    382,
#    383,
#    404,
#    495,
#    627,
#    633,
#    651,
#    665,
#    844,
#    862,
#    955,
#    1010,
#    1018,
#    1022,
#    1054,
#    1068]),
#  ('smlotzd', 1, [732]),
#  ('klein', 1, [319]),
#  ('joe', 1, [620]),
#  ('chip', 2, [865, 916]),
#  ('often', 1, [134]),
#  ('httpstcod2jzzta3ca', 1, [604]),
#  ('lovedata18', 2, [125, 466]),
#  ('deni', 3, [359, 783, 921]),
#  ('curieus', 1, [417]),
#  ('csnew', 1, [772]),
#  ('métal', 1, [327]),
#  ('relevé', 2, [167, 252]),
#  ('unit', 1, [66]),
#  ('détect', 1, [383]),
#  ('checkpoint', 1, [349]),
#  ('guy', 3, [238, 482, 621]),
#  ('huang', 1, [260]),
#  ('pui', 1, [604]),
#  ('duboul', 1, [783]),
#  ('central', 2, [617, 885]),
#  ('dimer', 1, [170]),
#  ('diminué', 1, [266]),
#  ('httpstco6jehtk8y7i', 1, [189]),
#  ('soil', 2, [289, 512]),
#  ('osaekomi', 1, [295]),
#  ('httpstco4uidxckvaq', 1, [172]),
#  ('httpstcoijwbaebocj', 1, [795]),
#  ('fillett', 1, [742]),
#  ('httpstcoos7mfkm1eh', 1, [177]),
#  ('qui', 9, [26, 56, 168, 282, 383, 548, 682, 752, 913]),
#  ('httpstcoipwddkwnuf', 1, [546]),
#  ('bind', 1, [170]),
#  ('start',
#   17,
#   [31,
#    134,
#    230,
#    255,
#    257,
#    260,
#    274,
#    288,
#    359,
#    441,
#    656,
#    719,
#    910,
#    975,
#    984,
#    998,
#    1015]),
#  ('httpstco6rcktsojc7', 1, [610]),
#  ('zia', 1, [935]),
#  ('httpstcong5qq85s3m', 1, [679]),
#  ('prêter', 1, [1049]),
#  ('juin', 1, [967]),
#  ('httpstcoit0sbqlkqc', 1, [228]),
#  ('denfer', 1, [130]),
#  ('maiti', 1, [748]),
#  ('spun', 1, [1014]),
#  ('httpstcochibnceiwj', 1, [125]),
#  ('3001', 1, [243]),
#  ('léprouvett', 1, [265]),
#  ('cv', 1, [674]),
#  ('bbc', 3, [216, 634, 634]),
#  ('httpstco3vujybmevd', 1, [341]),
#  ('débusqu', 2, [405, 424]),
#  ('httpstcon6ljsys9t2', 1, [479]),
#  ('httpstcoruvegs5egz', 1, [204]),
#  ('state', 1, [66]),
#  ('trump', 3, [556, 620, 1054]),
#  ('dhlab', 1, [316]),
#  ('special', 1, [259]),
#  ('httpstcoqeimkjiqyy', 1, [534]),
#  ('rayonsx', 1, [351]),
#  ('httpstcophsuxdc7hp', 1, [88]),
#  ('httpstcor5vo6fuylg', 1, [896]),
#  ('cad', 1, [603]),
#  ('go', 12, [323, 347, 430, 471, 525, 542, 572, 772, 981, 999, 1006, 1036]),
#  ('eaten', 1, [1033]),
#  ('text', 1, [582]),
#  ('voyagebachelor', 1, [369]),
#  ('acadsci', 1, [311]),
#  ('fret', 1, [959]),
#  ('la',
#   102,
#   [11,
#    11,
#    11,
#    12,
#    12,
#    16,
#    20,
#    26,
#    26,
#    26,
#    26,
#    26,
#    47,
#    51,
#    56,
#    61,
#    61,
#    81,
#    94,
#    118,
#    149,
#    149,
#    149,
#    157,
#    168,
#    182,
#    183,
#    197,
#    199,
#    202,
#    244,
#    252,
#    287,
#    300,
#    304,
#    304,
#    322,
#    325,
#    342,
#    345,
#    357,
#    362,
#    382,
#    383,
#    386,
#    386,
#    392,
#    404,
#    404,
#    452,
#    463,
#    526,
#    565,
#    566,
#    568,
#    584,
#    592,
#    603,
#    604,
#    610,
#    636,
#    644,
#    659,
#    706,
#    723,
#    766,
#    783,
#    784,
#    788,
#    788,
#    800,
#    806,
#    842,
#    844,
#    860,
#    874,
#    894,
#    895,
#    901,
#    902,
#    913,
#    919,
#    923,
#    929,
#    958,
#    958,
#    961,
#    976,
#    977,
#    978,
#    988,
#    996,
#    1016,
#    1016,
#    1018,
#    1022,
#    1030,
#    1030,
#    1042,
#    1054,
#    1066,
#    1066]),
#  ('daeinar', 2, [213, 479]),
#  ('length', 2, [103, 845]),
#  ('thymio', 1, [382]),
#  ('httpstco1oxxxs6mg', 1, [1064]),
#  ('standard', 5, [116, 184, 186, 508, 939]),
#  ('swisscom', 2, [62, 605]),
#  ('httpstcokzbzzlzn5c', 1, [972]),
#  ('envirobot', 3, [145, 828, 1008]),
#  ('coût', 1, [283]),
#  ('mit', 4, [188, 638, 972, 1015]),
#  ('normal', 2, [104, 234]),
#  ('nm2conf', 3, [135, 179, 223]),
#  ('corpor', 1, [957]),
#  ('highthroughput', 2, [545, 663]),
#  ('proud', 13, [33, 42, 64, 264, 501, 576, 605, 703, 720, 776, 846, 934, 963]),
#  ('understand',
#   13,
#   [73, 292, 307, 312, 397, 448, 498, 507, 540, 818, 839, 856, 948]),
#  ('old', 5, [525, 531, 979, 1046, 1065]),
#  ('did', 3, [80, 142, 323]),
#  ('httpstcokmp1urxpuo', 1, [156]),
#  ('httpstcold04jbxpsw', 1, [978]),
#  ('dispon', 1, [157]),
#  ('httpstcoq3zob59dwu', 1, [337]),
#  ('ignobel', 2, [230, 380]),
#  ('obvious', 1, [591]),
#  ('aura', 5, [144, 243, 252, 902, 958]),
#  ('moyen', 1, [520]),
#  ('hep', 1, [20]),
#  ('independ', 2, [30, 30]),
#  ('territori', 1, [261]),
#  ('genom', 4, [228, 284, 352, 358]),
#  ('parti', 2, [592, 875]),
#  ('nois', 1, [221]),
#  ('2018',
#   30,
#   [27,
#    28,
#    30,
#    32,
#    46,
#    137,
#    144,
#    168,
#    197,
#    202,
#    250,
#    263,
#    277,
#    350,
#    390,
#    393,
#    464,
#    465,
#    466,
#    512,
#    560,
#    586,
#    642,
#    688,
#    709,
#    719,
#    719,
#    801,
#    898,
#    1007]),
#  ('coltran', 1, [189]),
#  ('emprunt', 1, [157]),
#  ('caus', 1, [777]),
#  ('heart', 4, [717, 717, 758, 758]),
#  ('httpstcozdnwhb0ezl', 1, [1045]),
#  ('citat', 2, [63, 993]),
#  ('strong', 5, [103, 116, 150, 187, 640]),
#  ('upscal', 1, [36]),
#  ('machinglearn', 1, [347]),
#  ('epflphd', 1, [246]),
#  ('httpstcoaxxf5tgqj3', 1, [692]),
#  ('httpstcoqjrbjbdrv0', 1, [271]),
#  ('snsfch', 2, [288, 905]),
#  ('am', 7, [48, 52, 167, 338, 582, 741, 863]),
#  ('send', 2, [641, 979]),
#  ('httpstcojh2nndxm00', 1, [789]),
#  ('expliqu', 1, [205]),
#  ('bike', 1, [239]),
#  ('overhead', 1, [909]),
#  ('lab',
#   16,
#   [95,
#    95,
#    100,
#    245,
#    258,
#    387,
#    419,
#    419,
#    503,
#    532,
#    591,
#    699,
#    731,
#    864,
#    958,
#    980]),
#  ('fourth', 1, [863]),
#  ('👌☀️', 1, [992]),
#  ('interpret', 1, [236]),
#  ('avion', 1, [815]),
#  ('kellyannepol', 1, [637]),
#  ('datamanag', 1, [678]),
#  ('insid', 5, [24, 67, 153, 245, 932]),
#  ('testé', 1, [172]),
#  ('mozz', 1, [141]),
#  ('pribabl', 1, [535]),
#  ('dotsecurityio', 1, [213]),
#  ('canton', 2, [876, 1039]),
#  ('httpstcoqdt2txjrgl', 1, [615]),
#  ('lipid', 2, [638, 638]),
#  ('httpstcodrvhknmmlf', 1, [732]),
#  ('charl', 1, [921]),
#  ('httpstcopiufk3cdna', 1, [931]),
#  ('rappel', 1, [168]),
#  ('en',
#   56,
#   [12,
#    20,
#    26,
#    51,
#    61,
#    63,
#    81,
#    81,
#    129,
#    162,
#    168,
#    197,
#    207,
#    252,
#    261,
#    268,
#    279,
#    283,
#    297,
#    327,
#    336,
#    345,
#    345,
#    366,
#    369,
#    383,
#    386,
#    392,
#    429,
#    467,
#    467,
#    488,
#    488,
#    554,
#    610,
#    627,
#    644,
#    687,
#    740,
#    815,
#    815,
#    815,
#    821,
#    829,
#    840,
#    840,
#    844,
#    862,
#    882,
#    900,
#    939,
#    953,
#    958,
#    958,
#    1031,
#    1039]),
#  ('httpstcoe0libndjkc', 1, [671]),
#  ('epflecallab', 1, [245]),
#  ('seoul', 1, [93]),
#  ('method', 6, [166, 332, 377, 551, 638, 786]),
#  ('bachelor', 1, [287]),
#  ('httpstcoty35u7vfah', 1, [712]),
#  ('union', 2, [294, 468]),
#  ('seront', 1, [554]),
#  ('lieux', 1, [144]),
#  ('button', 1, [790]),
#  ('entr', 4, [304, 304, 345, 925]),
#  ('stilofficiel', 2, [569, 902]),
#  ('ecologi', 1, [644]),
#  ('former', 5, [390, 493, 741, 874, 978]),
#  ('httpstcocmiyfgtdn0', 1, [435]),
#  ('sorbonneuniv', 1, [164]),
#  ('scientistswhoselfi', 1, [288]),
#  ('aublebanon', 1, [695]),
#  ('avant', 3, [197, 207, 543]),
#  ('wave', 5, [44, 328, 527, 534, 908]),
#  ('manchu', 1, [48]),
#  ('vitrag', 1, [1070]),
#  ('town', 1, [108]),
#  ('httpstco6ixddicblu', 1, [964]),
#  ('httpstco4hmazta9qa', 1, [49]),
#  ('retina', 1, [234]),
#  ('httpstcowt09cxhcaa', 1, [1050]),
#  ('refract', 1, [770]),
#  ('vleadersfintech', 1, [148]),
#  ('interact', 7, [55, 55, 66, 164, 371, 444, 809]),
#  ('httpstcontplsnrafn', 1, [165]),
#  ('velux', 1, [376]),
#  ('fort', 1, [543]),
#  ('eksobion', 1, [871]),
#  ('climatiqu', 1, [962]),
#  ('earli', 4, [30, 296, 671, 885]),
#  ('dot', 2, [377, 551]),
#  ('personalis', 1, [758]),
#  ('giovannitoti', 1, [639]),
#  ('ethdomain', 1, [187]),
#  ('stationn', 1, [687]),
#  ('socialbusi', 1, [635]),
#  ('globu', 1, [1011]),
#  ('tech4dev2018', 1, [350]),
#  ('ericsson', 1, [212]),
#  ('properti', 1, [507]),
#  ('wish', 5, [277, 307, 491, 940, 1034]),
#  ('plongé', 1, [456]),
#  ('ktsakmakidi', 1, [728]),
#  ('grapheneco', 1, [334]),
#  ('flaviacorda', 1, [530]),
#  ('whose', 1, [979]),
#  ('psw', 1, [916]),
#  ('schoolchildren', 1, [450]),
#  ('limb', 1, [970]),
#  ('bioinformat', 2, [320, 381]),
#  ('pratiqu', 4, [61, 252, 265, 342]),
#  ('032017', 1, [862]),
#  ('scireport', 2, [79, 680]),
#  ('complet', 1, [315]),
#  ('cinema', 2, [301, 339]),
#  ('past', 1, [296]),
#  ('écrivezn', 1, [197]),
#  ('httpstco7g2w1geiz9', 1, [860]),
#  ('cafe', 1, [1032]),
#  ('httpstcohtaq0sxygw', 1, [660]),
#  ('théoriqu', 1, [61]),
#  ('architecturaux', 1, [967]),
#  ('wpcapit', 1, [399]),
#  ('afriquemagazin', 1, [1010]),
#  ('sandec', 1, [975]),
#  ('réussit', 1, [783]),
#  ('déjà', 2, [168, 996]),
#  ('moniqu', 1, [1021]),
#  ('métro', 1, [93]),
#  ('threat', 2, [112, 746]),
#  ('tree', 1, [416]),
#  ('seednight', 2, [156, 553]),
#  ('xma', 1, [263]),
#  ('httpstcoym6u32ngfp', 1, [566]),
#  ('httpstcohe7xqif7cf', 1, [641]),
#  ('especi', 1, [716]),
#  ('biociment', 1, [283]),
#  ('pourrait', 2, [682, 789]),
#  ('like', 7, [80, 281, 413, 482, 542, 647, 979]),
#  ('httpstcotism9yrbeb', 1, [629]),
#  ('cours', 6, [165, 493, 515, 600, 790, 798]),
#  ('httpstcox2y212dkup', 1, [7]),
#  ('httpstcov76kmjplkx', 1, [497]),
#  ('pytorch', 2, [859, 859]),
#  ('lassoci', 2, [729, 1035]),
#  ('httpstcogfpx3df7y8', 1, [414]),
#  ('could',
#   14,
#   [131, 314, 354, 396, 532, 558, 577, 695, 712, 813, 813, 966, 997, 1034]),
#  ('defens', 2, [645, 743]),
#  ('httpstcofiymwvlnar', 1, [512]),
#  ('universel', 1, [602]),
#  ('solut', 5, [109, 217, 318, 687, 842]),
#  ('partner', 6, [106, 196, 212, 522, 775, 1072]),
#  ('cybathlon', 1, [178]),
#  ('🇨🇭', 2, [241, 382]),
#  ('conundrum', 1, [394]),
#  ('ouvert', 1, [801]),
#  ('take',
#   17,
#   [27,
#    125,
#    137,
#    341,
#    422,
#    613,
#    628,
#    719,
#    765,
#    772,
#    873,
#    886,
#    937,
#    963,
#    979,
#    1004,
#    1009]),
#  ('déchanger', 1, [437]),
#  ('indoor', 1, [104]),
#  ('known', 1, [45]),
#  ('holzer', 1, [219]),
#  ('mahgenev', 1, [243]),
#  ('httpstcojc6dcitrx2', 2, [328, 527]),
#  ('httpstco6tiu1sc7oi', 1, [601]),
#  ('ask', 8, [50, 198, 409, 580, 646, 679, 791, 846]),
#  ('httpstcoh45eoihqmh', 1, [819]),
#  ('clinic', 1, [352]),
#  ('httpstco00omllvto8', 1, [136]),
#  ('origamiinspir', 1, [124]),
#  ('httpstcohoypozoy93', 1, [453]),
#  ('meetup', 1, [427]),
#  ('seht', 1, [319]),
#  ('l',
#   35,
#   [70,
#    123,
#    197,
#    197,
#    277,
#    282,
#    294,
#    363,
#    383,
#    388,
#    403,
#    463,
#    468,
#    495,
#    627,
#    644,
#    651,
#    665,
#    710,
#    800,
#    821,
#    843,
#    857,
#    862,
#    862,
#    889,
#    894,
#    901,
#    947,
#    958,
#    1023,
#    1025,
#    1026,
#    1026,
#    1071]),
#  ('epigenet', 1, [622]),
#  ('epflcdm', 1, [817]),
#  ('stammt', 1, [241]),
#  ('less', 6, [64, 323, 531, 778, 809, 979]),
#  ('httpstcoevlw3kf6v', 1, [998]),
#  ('researchdata', 1, [125]),
#  ('impact', 7, [144, 166, 280, 342, 672, 986, 1023]),
#  ('httpstcou3unicyadi', 1, [300]),
#  ('été', 2, [710, 710]),
#  ('found', 2, [732, 979]),
#  ('15billion', 1, [107]),
#  ('leg', 2, [108, 373]),
#  ('member', 4, [13, 88, 457, 699]),
#  ('httpstcof2bc5igpvo', 1, [1057]),
#  ('httpstcoepymyqckzw', 1, [1048]),
#  ('ive', 1, [262]),
#  ('traditionalcathol', 1, [936]),
#  ('httpstcoboreqiexit', 1, [105]),
#  ('httpstcoubz0qtqpqz', 1, [1009]),
#  ('dfloreano', 1, [905]),
#  ('stage', 1, [56]),
#  ('manag', 4, [510, 515, 640, 673]),
#  ('25kmh', 1, [430]),
#  ('call', 4, [222, 224, 393, 688]),
#  ('httpstcoynvyv7enuk', 1, [222]),
#  ('campaign', 1, [981]),
#  ('lign', 3, [12, 252, 958]),
#  ('httpstcooqc4s2tv3z', 1, [1017]),
#  ('physicaltherapi', 1, [444]),
#  ('lieu', 4, [243, 252, 902, 958]),
#  ('funprog', 1, [224]),
#  ('engadget', 1, [647]),
#  ('noir', 6, [174, 174, 782, 837, 837, 1043]),
#  ('👌🏻', 1, [1032]),
#  ('bci', 3, [178, 438, 459]),
#  ('ict4develop', 1, [46]),
#  ('httpstcotavirrwpkc', 1, [178]),
#  ('gefahren', 1, [737]),
#  ('2018hpeworkshop', 1, [611]),
#  ('kukaroboticsd', 1, [48]),
#  ('lehner', 1, [62]),
#  ('so', 11, [42, 106, 124, 269, 608, 612, 679, 691, 736, 872, 1055]),
#  ('academ', 1, [642]),
#  ('httpstcoqnsa7r8don', 1, [1073]),
#  ('sciencevalai', 1, [743]),
#  ('troi', 2, [43, 900]),
#  ('opticalsocieti', 1, [966]),
#  ('2017',
#   24,
#   [48,
#    48,
#    63,
#    121,
#    154,
#    178,
#    265,
#    420,
#    422,
#    431,
#    538,
#    560,
#    609,
#    705,
#    730,
#    887,
#    929,
#    931,
#    934,
#    975,
#    1015,
#    1062,
#    1064,
#    1066]),
#  ('train', 5, [116, 200, 391, 557, 775]),
#  ('exchang', 1, [106]),
#  ('inscrivezv', 1, [929]),
#  ('rewir', 1, [84]),
#  ('httpstcojt7hmcgny', 1, [915]),
#  ('aij', 1, [439]),
#  ('httpstcoeac5pmdphr', 1, [1046]),
#  ('httpstcojlnocxclmg', 1, [868]),
#  ('mrd', 1, [822]),
#  ('lorsqu', 1, [942]),
#  ('httpstcoqjzmsogwyo', 1, [397]),
#  ('maddoxpr', 2, [778, 1006]),
#  ('prison', 1, [122]),
#  ('codeweekeu', 1, [333]),
#  ('proposai', 1, [862]),
#  ('🚄', 1, [382]),
#  ('httpstcokf6e0am2kb', 1, [51]),
#  ('marché', 1, [162]),
#  ('seguin', 1, [316]),
#  ('httpstcoxlbsoh30io', 1, [966]),
#  ('httpstconyebnjz9iq', 1, [726]),
#  ('nm2', 1, [135]),
#  ('bionic', 1, [725]),
#  ('cancertreat', 1, [529]),
#  ('httpstcopkikecf1ux', 1, [594]),
#  ('uighur', 1, [746]),
#  ('httpstcoxlnmwh85oj', 1, [1020]),
#  ('biorxivneursci', 1, [290]),
#  ('gafam', 1, [924]),
#  ('nobillag', 1, [144]),
#  ('conway', 1, [886]),
#  ('gainde2000', 1, [559]),
#  ('valentina', 1, [240]),
#  ('dune', 3, [183, 325, 356]),
#  ('rrlepfl', 2, [1046, 1065]),
#  ('httpstco3zvz8pwqlc', 1, [852]),
#  ('cortexia', 1, [383]),
#  ('re', 1, [60]),
#  ('diseas', 6, [28, 264, 298, 717, 850, 879]),
#  ('arena', 1, [919]),
#  ('décerné', 1, [710]),
#  ('peac', 1, [263]),
#  ('wild', 1, [557]),
#  ('httpstcot84i2mbiun', 1, [913]),
#  ('évaluat', 2, [167, 252]),
#  ('découvrez', 3, [63, 243, 729]),
#  ('newest', 1, [591]),
#  ('prenant', 1, [794]),
#  ('cornavin', 1, [671]),
#  ('sensefli', 1, [318]),
#  ('4person', 1, [1014]),
#  ('order', 1, [87]),
#  ('chang', 2, [768, 869]),
#  ('martinvetterli',
#   26,
#   [49,
#    57,
#    60,
#    82,
#    263,
#    330,
#    346,
#    369,
#    390,
#    470,
#    477,
#    563,
#    565,
#    573,
#    612,
#    643,
#    652,
#    665,
#    665,
#    672,
#    776,
#    779,
#    819,
#    940,
#    974,
#    996]),
#  ('visitor', 2, [245, 898]),
#  ('httpstcoknvilhwpgb', 1, [426]),
#  ('nouveauné', 1, [922]),
#  ('httpstcorsfg9abopb', 1, [875]),
#  ('geomechaepfl', 3, [512, 601, 710]),
#  ('inv', 1, [489]),
#  ('brief', 3, [334, 704, 704]),
#  ('détruir', 1, [789]),
#  ('mscaction', 1, [931]),
#  ('ed', 1, [119]),
#  ('venu', 2, [601, 626]),
#  ('professionnel', 2, [244, 261]),
#  ('industrietag', 1, [1015]),
#  ('inspir', 9, [132, 264, 376, 390, 455, 464, 588, 738, 790]),
#  ('hit', 2, [411, 808]),
#  ('über', 3, [309, 737, 828]),
#  ('lesoepfl', 4, [299, 608, 867, 881]),
#  ('unildur', 2, [586, 961]),
#  ('httpstcoxvevamgjgi', 1, [299]),
#  ('superpouvoir', 1, [94]),
#  ('communelausann', 1, [52]),
#  ('httpstco5mvdxw3ofn', 1, [152]),
#  ('avoir', 2, [752, 939]),
#  ('httpstcoicjzbgikkg', 1, [331]),
#  ('dimprovis', 1, [894]),
#  ('httpstconhpahrisgp', 1, [154]),
#  ('si', 4, [12, 61, 877, 877]),
#  ('postcarworld', 1, [763]),
#  ('httpstcolrvirfnywc', 1, [924]),
#  ('cheesecak', 1, [253]),
#  ('progress', 3, [935, 937, 1053]),
#  ('ping', 1, [987]),
#  ('appliedmlday', 8, [34, 127, 276, 501, 503, 572, 605, 612]),
#  ('god', 1, [278]),
#  ('httpstco7bq0irddss', 1, [288]),
#  ('tesar', 2, [294, 468]),
#  ('httpstcodpemd35x1r', 1, [260]),
#  ('façad', 7, [51, 152, 473, 517, 853, 913, 968]),
#  ('blown', 1, [323]),
#  ('ahead', 2, [474, 992]),
#  ('camil', 1, [248]),
#  ('httpstco81jojeidzx', 1, [299]),
#  ('hier', 1, [1052]),
#  ('➡', 2, [894, 958]),
#  ('saliba', 1, [535]),
#  ('55', 1, [150]),
#  ('mean', 1, [312]),
#  ('sélectionné', 1, [160]),
#  ('retinai', 1, [447]),
#  ('collabor', 10, [183, 197, 237, 264, 387, 650, 703, 829, 917, 984]),
#  ('environn', 1, [162]),
#  ('jimstolz', 1, [898]),
#  ('meteolak', 1, [766]),
#  ('biolog', 10, [24, 30, 67, 73, 153, 298, 365, 625, 839, 932]),
#  ('calibr', 1, [438]),
#  ('slingshot', 1, [746]),
#  ('swissrobot', 2, [646, 657]),
#  ('rock', 1, [621]),
#  ('neural', 1, [387]),
#  ('chute', 1, [1050]),
#  ('robotiqu', 3, [20, 382, 929]),
#  ('icrc', 2, [830, 975]),
#  ('sbiaau', 1, [376]),
#  ('httpstcofmf9ged4km', 1, [901]),
#  ('captur', 3, [575, 585, 770]),
#  ('contreexpertis', 1, [857]),
#  ('opendata', 3, [2, 235, 982]),
#  ('ar', 3, [241, 518, 521]),
#  ('hgststorag', 1, [1012]),
#  ('swisseuresearch', 1, [200]),
#  ('spread', 1, [530]),
#  ('sensibl', 1, [251]),
#  ('split', 1, [918]),
#  ('congrat',
#   18,
#   [0,
#    4,
#    53,
#    77,
#    187,
#    190,
#    267,
#    295,
#    344,
#    364,
#    470,
#    550,
#    628,
#    707,
#    771,
#    807,
#    933,
#    994]),
#  ('maje', 1, [504]),
#  ('denken', 1, [338]),
#  ('brantut', 1, [431]),
#  ('highli', 1, [151]),
#  ('journé', 2, [467, 1042]),
#  ('httpstcoxrd9acgjgj', 1, [848]),
#  ('back', 5, [267, 335, 649, 814, 938]),
#  ('stress', 3, [28, 490, 1031]),
#  ('auront', 1, [924]),
#  ('aéronautiqu', 1, [16]),
#  ('sunris', 1, [749]),
#  ('994', 2, [191, 257]),
#  ('bereich', 1, [822]),
#  ('astronom', 1, [869]),
#  ('swisstechepfl', 4, [425, 760, 902, 1019]),
#  ('disast', 1, [519]),
#  ('httpstco23kjig8pxt', 1, [1]),
#  ('hts18', 1, [898]),
#  ('clean', 7, [152, 419, 473, 517, 853, 866, 968]),
#  ('hint', 2, [341, 865]),
#  ('500', 1, [429]),
#  ('ksacceler', 1, [222]),
#  ('immun', 6, [264, 352, 365, 529, 547, 879]),
#  ('into',
#   14,
#   [9, 50, 73, 88, 303, 396, 669, 692, 722, 726, 746, 754, 774, 839]),
#  ('childcar', 2, [60, 308]),
#  ('function', 3, [231, 365, 370]),
#  ('legal', 1, [645]),
#  ('nicholasdemil', 1, [741]),
#  ('nest', 1, [659]),
#  ('planvélo', 1, [687]),
#  ('algorithm', 4, [80, 100, 557, 572]),
#  ('lowcost', 2, [217, 918]),
#  ('and',
#   215,
#   [0,
#    10,
#    10,
#    13,
#    27,
#    27,
#    28,
#    34,
#    42,
#    44,
#    59,
#    64,
#    65,
#    65,
#    66,
#    68,
#    68,
#    68,
#    68,
#    78,
#    80,
#    86,
#    101,
#    103,
#    103,
#    108,
#    108,
#    108,
#    109,
#    112,
#    116,
#    121,
#    121,
#    124,
#    125,
#    126,
#    126,
#    138,
#    139,
#    142,
#    150,
#    164,
#    166,
#    166,
#    170,
#    171,
#    175,
#    176,
#    185,
#    190,
#    191,
#    193,
#    195,
#    210,
#    210,
#    217,
#    220,
#    229,
#    250,
#    250,
#    258,
#    259,
#    262,
#    263,
#    263,
#    264,
#    269,
#    272,
#    284,
#    290,
#    290,
#    291,
#    292,
#    292,
#    294,
#    296,
#    299,
#    301,
#    307,
#    308,
#    313,
#    315,
#    321,
#    328,
#    334,
#    336,
#    337,
#    339,
#    339,
#    341,
#    341,
#    348,
#    352,
#    352,
#    376,
#    376,
#    390,
#    390,
#    401,
#    409,
#    416,
#    419,
#    419,
#    427,
#    440,
#    442,
#    449,
#    458,
#    458,
#    464,
#    468,
#    469,
#    485,
#    498,
#    501,
#    507,
#    513,
#    515,
#    518,
#    518,
#    525,
#    526,
#    526,
#    527,
#    531,
#    545,
#    547,
#    557,
#    561,
#    561,
#    575,
#    575,
#    577,
#    585,
#    589,
#    598,
#    606,
#    613,
#    623,
#    625,
#    626,
#    628,
#    639,
#    639,
#    641,
#    641,
#    642,
#    650,
#    658,
#    660,
#    662,
#    663,
#    666,
#    671,
#    671,
#    671,
#    675,
#    678,
#    679,
#    686,
#    688,
#    689,
#    690,
#    694,
#    699,
#    699,
#    703,
#    719,
#    724,
#    733,
#    734,
#    741,
#    743,
#    743,
#    745,
#    745,
#    756,
#    777,
#    785,
#    798,
#    807,
#    813,
#    820,
#    820,
#    830,
#    830,
#    845,
#    847,
#    850,
#    858,
#    859,
#    866,
#    869,
#    873,
#    898,
#    905,
#    908,
#    928,
#    933,
#    938,
#    941,
#    959,
#    960,
#    973,
#    981,
#    982,
#    995,
#    1014,
#    1036,
#    1036,
#    1036,
#    1046,
#    1060,
#    1065,
#    1072]),
#  ('australia', 1, [278]),
#  ('httpstcocmoowb3eh6', 1, [93]),
#  ('clock', 1, [361]),
#  ('michel', 1, [782]),
#  ('poulet', 1, [927]),
#  ('exosom', 1, [529]),
#  ('httpstcor3t1sszogo', 1, [564]),
#  ('gamelab🕹rtstribu', 1, [893]),
#  ('rape', 2, [122, 979]),
#  ('exoplanet', 1, [768]),
#  ('dindin', 3, [787, 787, 787]),
#  ('eurosys2018', 3, [274, 306, 306]),
#  ('justinegdc', 1, [808]),
#  ('httpstcobezxs7dnvg', 1, [273]),
#  ('ani', 4, [80, 164, 260, 692]),
#  ('soap', 1, [75]),
#  ('httpstco6houuycwab', 1, [167]),
#  ('frequent', 1, [35]),
#  ('animaux', 2, [789, 789]),
#  ('point', 7, [108, 175, 251, 272, 292, 312, 1067]),
#  ('ppurtweet', 1, [710]),
#  ('wit', 1, [191]),
#  ('natxopago', 1, [335]),
#  ('platform', 2, [46, 214]),
#  ('floor', 1, [537]),
#  ('as',
#   19,
#   [35,
#    44,
#    44,
#    58,
#    88,
#    104,
#    229,
#    270,
#    328,
#    373,
#    373,
#    390,
#    490,
#    527,
#    589,
#    757,
#    875,
#    908,
#    912]),
#  ('httpstcoiyxfpxdcbq', 1, [589]),
#  ('bientôt', 1, [202]),
#  ('flourish', 1, [432]),
#  ('httpstcorssxorvwmg', 1, [957]),
#  ('myswitzerland', 1, [749]),
#  ('highenthalpi', 1, [79]),
#  ('inscript', 2, [277, 958]),
#  ('h2020sc5', 1, [341]),
#  ('httpstco9f9q98oxp', 1, [921]),
#  ('trust', 9, [21, 50, 198, 580, 580, 581, 581, 640, 1044]),
#  ('rang', 1, [499]),
#  ('left', 1, [941]),
#  ('right', 2, [107, 576]),
#  ('représent', 1, [989]),
#  ('httpstcojqle5pexa4', 1, [35]),
#  ('swissquotenew', 1, [825]),
#  ('uni', 1, [1014]),
#  ('httpstco2vdekx9yhv', 1, [341]),
#  ('httpstcoopwuhvzs5d', 1, [896]),
#  ('problèm', 1, [823]),
#  ('cold', 1, [661]),
#  ('polic', 5, [122, 163, 278, 979, 979]),
#  ('mi', 1, [383]),
#  ('httpstcoqczodmndjj', 1, [570]),
#  ('httpstcocujsqv4kfd', 1, [185]),
#  ('nwo', 1, [281]),
#  ('scicomm', 4, [301, 339, 420, 730]),
#  ('httpstcoum0imlludj', 1, [361]),
#  ('understood', 1, [938]),
#  ('httpstcofhw6avwslu', 1, [525]),
#  ('httpstco5nmydbcuzk', 1, [884]),
#  ('affront', 1, [565]),
#  ('goodby', 1, [907]),
#  ('apparti', 1, [439]),
#  ('prend', 1, [705]),
#  ('retir', 1, [988]),
#  ('wast', 3, [166, 323, 555]),
#  ('httpstconr5ni3chy4', 1, [984]),
#  ('knecht', 2, [137, 506]),
#  ('enr', 2, [913, 1070]),
#  ('swissunivers', 1, [121]),
#  ('rate', 1, [834]),
#  ...]

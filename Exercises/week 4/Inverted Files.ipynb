# %% [markdown]
# ## 📚 Exercise 2: Inverted Files
#
# In this exercise, we will understand the functioning of the Inverted Files and how implement them using MapReduce.
#
# ### Overview
#
# We learnt in the lecture that terms are typically stored in an inverted list. Now, in the inverted list, instead of only storing document identifiers of the documents in which the term appears, assume we also store an *offset* of the appearance of a term in a document. An $offset$ of a term $l_k$ given a document is defined as the number of words between the start of the document and $l_k$. Thus our inverted list is now:
#
# $l_k= \langle f_k: \{d_{i_1} \rightarrow [o_1,\ldots,o_{n_{i_1}}]\},
# \{d_{i_2} \rightarrow [o_1,\ldots,o_{n_{i_2}}]\}, \ldots,
# \{d_{i_k} \rightarrow [o_1,\ldots,o_{n_{i_k}}]\} \rangle$
#
# This means that in document $d_{i_1}$ term $l_k$ appears $n_{i_1}$ times and at offset $[o_1,\ldots,o_{n_{i_1}}]$, where $[o_1,\ldots,o_{n_{i_1}}]$ are sorted in ascending order, these type of indices are also known as term-offset indices. An example of a term-offset index is as follows:
#
# **Obama** = $⟨4 : {1 → [3]},{2 → [6]},{3 → [2,17]},{4 → [1]}⟩$
#
# **Governor** = $⟨2 : {4 → [3]}, {7 → [14]}⟩$
#
# **Election** = $⟨4 : {1 → [1]},{2 → [1,21]},{3 → [3]},{5 → [16,22,51]}⟩$
#
# Which is to say that the term **Governor** appear in 2 documents. In document 4 at offset 3, in document 7 at offset 14. Now let us consider the *SLOP/x* operator in text retrieval. This operator has the syntax: *QueryTerm1 SLOP/x QueryTerm2* finds occurrences of *QueryTerm1* within $x$ (but not necessarily in that order) words of *QueryTerm2*, where $x$ is a positive integer argument ($x \geq 1$). Thus $x = 1$ demands that *QueryTerm1* be adjacent to *QueryTerm2*.
#
# ### Questions
#
# 1. List the set of documents that satisfy the query **Obama** *SLOP/2* **Election**.
# 2. List each set of values for which the query **Obama** *SLOP/x* **Election** has a different set of documents as answers (starting from $x = 1$).
# 3. Consider the general procedure for "merging" two term-offset inverted lists for a given document, to determine where the document satisfies a *SLOP/x* clause (since in general there will be many offsets at which each term occurs in a document). Let $L$ denote the total number of occurrences of the two terms in the document. Assume we have a pointer to the list of occurrences of each term and can move the pointer along this list. As we do so we check whether we have a hit for $SLOP/x$ (i.e. the $SLOP/x$ clause is satisfied). Each move of either pointer counts as a step. Based on this assumption is there a general "merging" procedure to determine whether the document satisfies a $SLOP/x$ clause, for which the following is true? Justify your answer.
#
#     1. The merge can be accomplished in a number of steps linear in $L$ regardless of $x$, and we can ensure that each pointer moves only to the right (i.e. forward).
#     2. The merge can be accomplished in a number of steps linear in $L$, but a pointer may be forced to move to the left (i.e. backwards).
#     3. The merge can require $x \times L$ steps in some cases.

# %% [markdown]
# ## Create inverted files using MapReduce
# In this exercise, we want to create the inverted files using the MapReduce framework. Write the **map** and **reduce** function.
# Note that the code of **run_mapreduce** is just a simulation of the behavior of  map-reduce system.
#
# ## Goal:
# - Create inverted files using the MapReduce framework.
# - Test the implementation on `epfldocs.txt` data.
#
# ### What you are learning in this exercise:
# - Having a better understanding of inverted files.
# - Learn how to implement inverted files using the MapReduce framework.

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer
import nltk
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
import string
from nltk.corpus import stopwords
import math
from collections import Counter
import numpy as np
nltk.download('stopwords')
nltk.download('punkt')

stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sebastian/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/sebastian/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Tokenize, stem a document
def tokenize(text):
    """
    It tokenizes and stems an input text.
    
    :param text: str, with the input text
    :return: list, of the tokenized and stemmed tokens.
    """
    text = "".join([ch for ch in text if ch not in string.punctuation])
    tokens = nltk.word_tokenize(text)
    return " ".join([stemmer.stem(word.lower()) for word in tokens])

with open("epfldocs.txt") as f:
    content = f.readlines()
original_documents = [x.strip() for x in content] 
documents = [tokenize(d).split() for d in original_documents]
docs_n_doc_ids = list(zip(range(len(documents)), documents))

# %%
# Take a pair (doc_id, content). Example: (0, ['how', 'to', 'bake', 'bread', 'without', 'bake', 'recip'])
# Return: list of (word, doc_id). Example: ('bake', 0)
# For simplicity, we assume each mapper handles a document
def map_function(doc_id, content):
    keyvals = []
    for word in content:
        keyvals.append((word, doc_id))
    return keyvals

# %%
# Take a list of pairs (word, doc_id). Example:  [('bake', 0), ('bake', 0), ('bake', 3)]
# Return: (word, frequency, list of document ids). Example ('bake', 3, [0, 0, 3])
# For simplicity, we assume each reducer handles a word
def reduce_function(lst):
    total = 0
    word = lst[0][0]
    doc_ids = []
    for w, doc_id in lst:
        assert(word==w) # Assume each reducer handles 1 word
        # YOUR CODE HERE
        total += 1 
        doc_ids.append(doc_id)
    return (word, total, doc_ids)

# %%
# We simulate the mapreduce framework by this function
def run_mapreduce(docs_n_doc_ids):
    # Map phase
    key_values = []
    for doc_id, doc_content in docs_n_doc_ids:
        key_values.extend(map_function(doc_id, doc_content))
    # Shuffle phase
    values = set(map(lambda x:x[0], key_values))
    grouped_key_values = [[y for y in key_values if y[0]==x] for x in values]
    # Reduce phase
    inverted_files = []
    for grouped_key_value in grouped_key_values:
        word, total, doc_ids = reduce_function(grouped_key_value)
        inverted_files.append((word, total, doc_ids))
    return inverted_files

# %%
run_mapreduce(docs_n_doc_ids)
# Out:
# [('vacanc', 1, [81]),
#  ('elderli', 1, [486]),
#  ('code', 8, [233, 347, 525, 528, 636, 707, 742, 752]),
#  ('aihealth', 6, [21, 50, 198, 580, 581, 722]),
#  ('topic', 8, [10, 134, 350, 466, 502, 526, 628, 643]),
#  ('phd', 7, [30, 336, 442, 677, 709, 867, 1034]),
#  ('deep', 3, [208, 600, 859]),
#  ('someth', 1, [689]),
#  ('elektroden', 1, [701]),
#  ('antarcticbas', 1, [108]),
#  ('cors', 1, [906]),
#  ('unternehmertum', 1, [105]),
#  ('httpstcou4fnmegdup', 1, [990]),
#  ('vr', 7, [102, 313, 313, 518, 654, 907, 1014]),
#  ('phbismuth', 1, [472]),
#  ('mubizfr', 1, [561]),
#  ('editor', 1, [629]),
#  ('forschung', 1, [822]),
#  ('bring', 3, [624, 648, 849]),
#  ('heathercmil', 1, [315]),
#  ('serendip', 1, [258]),
#  ('smartgrid', 1, [510]),
#  ('spread', 1, [530]),
#  ('httpstcohrow4kecko', 1, [858]),
#  ('polair', 1, [636]),
#  ('hubbl', 3, [111, 355, 811]),
#  ('mozz', 1, [141]),
#  ('httpstcosx2wyozlpj', 1, [168]),
#  ('fabric', 2, [327, 1000]),
#  ('waltz', 1, [865]),
#  ('site', 5, [342, 705, 770, 800, 1039]),
#  ('ou', 3, [815, 874, 1051]),
#  ('eca', 1, [291]),
#  ('been', 9, [104, 264, 269, 387, 407, 507, 540, 812, 963]),
#  ('18h30', 1, [782]),
#  ('fhll', 1, [980]),
#  ('httpstcopiufk3cdna', 1, [931]),
#  ('altitud', 1, [611]),
#  ('hacker', 1, [143]),
#  ('chiccommun', 2, [90, 780]),
#  ('restetil', 1, [1069]),
#  ('httpstcoavujdhhuvu', 1, [834]),
#  ('njit', 1, [77]),
#  ('titlelength', 1, [280]),
#  ('harmanton', 1, [336]),
#  ('territori', 1, [261]),
#  ('martelinnov', 2, [263, 391]),
#  ('httpstcoxaxuscw6kp', 1, [648]),
#  ('lhonneur', 1, [844]),
#  ('besoin', 3, [118, 283, 1030]),
#  ('revolution', 3, [69, 136, 856]),
#  ('grade', 1, [540]),
#  ('deceiv', 1, [50]),
#  ('été', 2, [710, 710]),
#  ('degrad', 1, [986]),
#  ('httpstcoqlhytdtuy3', 1, [275]),
#  ('champel28', 1, [1071]),
#  ('httpstcok7ndmjyqbi', 1, [233]),
#  ('haut', 1, [919]),
#  ('lereseau', 3, [251, 321, 645]),
#  ('fox', 1, [945]),
#  ('httpstcomtl9l8rnev', 1, [280]),
#  ('rampd', 1, [71]),
#  ('devenir', 1, [627]),
#  ('vd', 1, [86]),
#  ('septembr', 3, [47, 901, 929]),
#  ('dakar', 1, [233]),
#  ('laserplasma', 1, [164]),
#  ('co2', 2, [900, 965]),
#  ('👉', 1, [743]),
#  ('marathon', 1, [363]),
#  ('mactar', 1, [56]),
#  ('dotsecurityio', 1, [213]),
#  ('httpstcobid211ncnp', 1, [558]),
#  ('collect', 1, [316]),
#  ('abandonnerai', 1, [1021]),
#  ('adrien', 1, [855]),
#  ('psichen', 1, [984]),
#  ('jan', 2, [68, 590]),
#  ('slice', 1, [497]),
#  ('exoplanet', 1, [768]),
#  ('ensmmofficiel', 1, [304]),
#  ('😂🧀', 1, [587]),
#  ('sonor', 1, [876]),
#  ('denfer', 1, [130]),
#  ('loccas', 1, [345]),
#  ('socialmedia', 1, [27]),
#  ('kinemat', 1, [786]),
#  ('dispositif', 1, [383]),
#  ('flyabil', 1, [1036]),
#  ('httpstcob2egco0qbn', 1, [836]),
#  ('vitro', 1, [354]),
#  ('httpstcozl8ig3vbau', 1, [36]),
#  ('wpdl', 1, [916]),
#  ('attir', 1, [821]),
#  ('rirh', 1, [572]),
#  ('httpstco7lkkao5780', 1, [2]),
#  ('httpstcoj8pzbx8p6v', 1, [726]),
#  ('dtutweet', 2, [71, 1006]),
#  ('theworldin', 1, [231]),
#  ('il', 8, [12, 325, 659, 682, 939, 1049, 1049, 1071]),
#  ('6902010', 1, [739]),
#  ('httpstcox3emciegkd', 1, [758]),
#  ('la2024', 1, [1042]),
#  ('cheat', 1, [240]),
#  ('httpstcowfi6bx6p79', 1, [526]),
#  ('👌cc', 1, [878]),
#  ('realli', 8, [58, 260, 353, 387, 691, 790, 938, 999]),
#  ('februar', 1, [167]),
#  ('laserbas', 1, [1000]),
#  ('knight', 1, [99]),
#  ('ic', 2, [287, 316]),
#  ('spectacl', 1, [604]),
#  ('httpstcomy5jlwsxud', 1, [730]),
#  ('bereich', 1, [822]),
#  ('fractur', 1, [1030]),
#  ('ex', 1, [739]),
#  ('httpstcoxxmuldcqlg', 1, [464]),
#  ('mitochondri', 1, [149]),
#  ('swisssporttv', 1, [52]),
#  ('opendata', 3, [2, 235, 982]),
#  ('infra', 1, [520]),
#  ('tou', 4, [63, 168, 860, 988]),
#  ('pictur', 2, [559, 866]),
#  ('3ème', 1, [202]),
#  ('cdu', 3, [1057, 1058, 1059]),
#  ('ident', 1, [957]),
#  ('conférenc', 7, [12, 243, 633, 782, 958, 967, 1048]),
#  ('itw', 2, [526, 1068]),
#  ('kevinschawinski', 2, [187, 501]),
#  ('ehlnew', 2, [244, 302]),
#  ('innose', 1, [421]),
#  ('bern', 2, [480, 523]),
#  ('httpstcoofhq1oxs4n', 1, [719]),
#  ('enquêt', 1, [821]),
#  ('bcdiploma', 1, [561]),
#  ('swissnex', 1, [963]),
#  ('chemjob', 1, [617]),
#  ('listen', 1, [21]),
#  ('startinggood', 1, [793]),
#  ('httpstcoyrkoycbsl', 1, [1022]),
#  ('fujilove30', 1, [455]),
#  ('molsystbiol', 1, [629]),
#  ('practition', 2, [33, 946]),
#  ('metabol', 2, [629, 694]),
#  ('swissmissioneu', 1, [346]),
#  ('handi', 1, [845]),
#  ('chiefdisrupt', 1, [802]),
#  ('httpstcocixq0xhiu9', 1, [657]),
#  ('vibrio', 2, [591, 738]),
#  ('interdisciplinair', 1, [183]),
#  ('unigeen', 4, [192, 489, 541, 803]),
#  ('httpstcoptjukxxkk4', 1, [79]),
#  ('embark', 1, [177]),
#  ('1315', 1, [1047]),
#  ('dfloreano', 1, [905]),
#  ('serious', 2, [519, 573]),
#  ('httpstcoeoe8vhmgek', 1, [804]),
#  ('zero', 1, [869]),
#  ('coup', 2, [356, 781]),
#  ('navig', 2, [104, 1005]),
#  ('httpstcojz7tpghojn', 1, [771]),
#  ('algèbr', 1, [429]),
#  ('review', 4, [225, 334, 694, 948]),
#  ('africa', 2, [775, 1061]),
#  ('fascin', 2, [414, 903]),
#  ('ressourc', 2, [539, 939]),
#  ('singlephoton', 1, [226]),
#  ('httpstcoqr5bho3ejh', 1, [794]),
#  ('chicco785', 1, [346]),
#  ('oneher', 1, [591]),
#  ('httpstcoa5in0tcls7', 1, [731]),
#  ('sauver', 1, [123]),
#  ('usiunivers', 1, [346]),
#  ('vasilgelev', 1, [639]),
#  ('gehen', 1, [701]),
#  ('contr', 2, [603, 740]),
#  ('frequent', 1, [35]),
#  ('etudesantedusoir', 2, [266, 1031]),
#  ('complet', 1, [315]),
#  ('jusqu', 1, [604]),
#  ('🎧', 2, [168, 197]),
#  ('marzari', 1, [89]),
#  ('httpstcoscmuhk60vn', 1, [611]),
#  ('voir', 1, [644]),
#  ('youtub', 7, [12, 107, 459, 676, 843, 1062, 1064]),
#  ('httpstcovzvmpcj3hv', 1, [102]),
#  ('students🏅🏆', 1, [471]),
#  ('httpstcomfrjlnuopt', 1, [662]),
#  ('most', 12, [139, 187, 308, 407, 589, 631, 632, 759, 817, 903, 912, 934]),
#  ('franceia', 1, [118]),
#  ('induc', 1, [469]),
#  ('lsm', 1, [731]),
#  ('buccipergenova', 1, [639]),
#  ('httpstcoj2zolk2fma', 1, [865]),
#  ('httpstcov9rrdrv5jz', 1, [907]),
#  ('aviat', 2, [16, 711]),
#  ('ufcuniv', 1, [304]),
#  ('httpstcof9bwoytwvg', 1, [269]),
#  ('again', 2, [646, 1029]),
#  ('complex', 3, [29, 743, 1038]),
#  ('pioneer', 1, [317]),
#  ('patent', 1, [881]),
#  ('inflight', 1, [318]),
#  ('signatur', 1, [365]),
#  ('eight', 1, [984]),
#  ('hasard', 1, [651]),
#  ('bi', 1, [1015]),
#  ('secret', 2, [70, 414]),
#  ('problem', 2, [260, 260]),
#  ('bscampmast', 1, [196]),
#  ('destroy', 1, [577]),
#  ('scène', 1, [1019]),
#  ('httpstcovgetzu1k9z', 1, [323]),
#  ('thebaltimoretim', 1, [814]),
#  ('sunrised', 1, [582]),
#  ('didn', 1, [692]),
#  ('andrea', 3, [264, 498, 879]),
#  ('darchitectur', 1, [633]),
#  ('rehabilit', 3, [440, 693, 852]),
#  ('apparti', 1, [439]),
#  ('httpstcohnsuosekx3', 1, [344]),
#  ('httpstco3ekteqvhor', 1, [638]),
#  ('live', 7, [17, 95, 112, 180, 257, 589, 992]),
#  ('ambassador', 2, [15, 191]),
#  ('jo', 2, [915, 1042]),
#  ('s3', 3, [126, 126, 704]),
#  ('forumwslsuisseromand', 1, [653]),
#  ('httpstcoxdbiszjw1u', 1, [992]),
#  ('follicularlymphoma', 1, [943]),
#  ('httpstcod2oi9inptx', 1, [177]),
#  ('photo', 3, [345, 507, 914]),
#  ('mediaroad', 1, [27]),
#  ('profil', 2, [477, 592]),
#  ('recogn', 1, [547]),
#  ('kellyannepol', 1, [637]),
#  ('httpstco89ziiby5f', 1, [990]),
#  ('menu', 1, [304]),
#  ('limplant', 1, [1030]),
#  ('solv', 3, [104, 114, 728]),
#  ('httpstcoen0umiyykp', 1, [835]),
#  ('impati', 1, [860]),
#  ('sweat', 1, [690]),
#  ('5th', 1, [0]),
#  ('giovannitoti', 1, [639]),
#  ('obes', 1, [494]),
#  ('lapp', 1, [366]),
#  ('today',
#   22,
#   [143,
#    154,
#    191,
#    258,
#    270,
#    320,
#    411,
#    412,
#    480,
#    518,
#    528,
#    630,
#    700,
#    707,
#    712,
#    764,
#    878,
#    903,
#    905,
#    966,
#    992,
#    1032]),
#  ('moëll', 1, [1030]),
#  ('thinksportsuccessstori', 1, [1060]),
#  ('httpstco8oypzdqbhd', 1, [716]),
#  ('iman', 1, [931]),
#  ('csl', 3, [61, 439, 939]),
#  ('détendr', 1, [277]),
#  ('cobay', 1, [1030]),
#  ('heigvd', 1, [200]),
#  ('slashandburn', 1, [808]),
#  ('tetranucleosom', 1, [66]),
#  ('michaeljfoxorg', 1, [945]),
#  ('near', 1, [957]),
#  ('sécurité', 3, [81, 892, 978]),
#  ('smartspecialis', 1, [704]),
#  ('cafe', 1, [1032]),
#  ('assess', 1, [166]),
#  ('psich', 1, [504]),
#  ('napoleon', 1, [927]),
#  ('program', 10, [57, 125, 306, 347, 370, 421, 481, 512, 703, 888]),
#  ('vleadersfintech', 1, [148]),
#  ('close', 2, [32, 352]),
#  ('cusophd', 2, [301, 339]),
#  ('intestin', 1, [607]),
#  ('rethink', 1, [762]),
#  ('médecin', 1, [566]),
#  ('naiv', 1, [321]),
#  ('uchicago', 1, [349]),
#  ('découvrez', 3, [63, 243, 729]),
#  ('king', 1, [1012]),
#  ('wellunderstood', 1, [809]),
#  ('exampl', 2, [576, 669]),
#  ('swissmem', 1, [1015]),
#  ('biomolecul', 1, [695]),
#  ('includ', 2, [13, 471]),
#  ('mahamad', 1, [56]),
#  ('ibmresearch', 1, [231]),
#  ('xile', 1, [288]),
#  ('stage', 1, [56]),
#  ('httpstco42qaeby17w', 1, [452]),
#  ('bibliograph', 1, [739]),
#  ('httpstcouui9tmgnxt', 1, [916]),
#  ('mi', 1, [383]),
#  ('simplifi', 1, [692]),
#  ('hslu', 1, [11]),
#  ('httpstcox4p8uwpivg', 1, [347]),
#  ('httpstco05rvcqymng', 1, [785]),
#  ('artificialintellig', 3, [292, 414, 452]),
#  ('httpstcomsnlgmpaol', 1, [246]),
#  ('videogam', 2, [715, 715]),
#  ('acquir', 1, [318]),
#  ('chromatin', 3, [378, 378, 959]),
#  ('alternatif', 1, [857]),
#  ('1200cet', 1, [992]),
#  ('stm', 1, [303]),
#  ('besmart', 1, [143]),
#  ('httpstcomynhu4trvi', 1, [376]),
#  ('dan',
#   20,
#   [81,
#    172,
#    345,
#    382,
#    456,
#    548,
#    554,
#    570,
#    610,
#    665,
#    739,
#    789,
#    825,
#    844,
#    860,
#    876,
#    976,
#    977,
#    983,
#    996]),
#  ('httpstcou09m0mpdu', 1, [396]),
#  ('reconfigur', 1, [719]),
#  ('chinagoabroad', 1, [530]),
#  ('charg', 1, [303]),
#  ('httpstcooheor1ejhp', 1, [826]),
#  ('donnez', 1, [144]),
#  ('visitor', 2, [245, 898]),
#  ('invest', 5, [7, 146, 146, 146, 858]),
#  ('diseas', 6, [28, 264, 298, 717, 850, 879]),
#  ('2eme', 1, [825]),
#  ('populair', 1, [742]),
#  ('18th', 1, [225]),
#  ('bouri', 1, [861]),
#  ('hearcingenieri', 1, [402]),
#  ('ucsdnew', 1, [741]),
#  ('unicopenhagen', 1, [817]),
#  ('httpstco2bbtingzup', 1, [98]),
#  ('prudenc', 1, [185]),
#  ('food', 5, [158, 323, 587, 606, 1056]),
#  ('httpstcokf6e0am2kb', 1, [51]),
#  ('hour', 1, [919]),
#  ('httpstco4yts0a28x', 1, [403]),
#  ('europ', 5, [270, 531, 686, 912, 958]),
#  ('httpstcoqfzdfohgpp', 1, [129]),
#  ('httpstcovh9qgloqrr', 1, [5]),
#  ('scientificqu', 1, [280]),
#  ('7047', 1, [161]),
#  ('httpstcoelpyorrs7', 1, [251]),
#  ('nouveau', 5, [20, 252, 261, 567, 983]),
#  ('martin', 3, [568, 643, 863]),
#  ('kawaii', 1, [715]),
#  ('particip', 11, [57, 301, 325, 339, 345, 390, 471, 572, 601, 724, 1007]),
#  ('neural', 1, [387]),
#  ('jordi', 1, [227]),
#  ('coucou', 2, [670, 1039]),
#  ('policevalai', 1, [979]),
#  ('httpstcoqklwlqjifd', 1, [217]),
#  ('direct', 3, [366, 874, 953]),
#  ('karni', 1, [608]),
#  ('croisé', 1, [304]),
#  ('month', 5, [247, 407, 438, 471, 615]),
#  ('ng', 2, [170, 415]),
#  ('read',
#   13,
#   [109, 109, 150, 236, 262, 278, 546, 550, 577, 820, 935, 981, 986]),
#  ('httpstco2byw3asuc2', 1, [267]),
#  ('aux',
#   13,
#   [129, 161, 161, 261, 297, 405, 424, 439, 710, 742, 773, 1020, 1026]),
#  ('swim', 1, [1008]),
#  ('compress', 1, [855]),
#  ('mikrotechnik', 1, [309]),
#  ('httpstcodenokqywrc', 1, [404]),
#  ('connai', 1, [199]),
#  ('heluc', 2, [235, 569]),
#  ('repositori', 1, [799]),
#  ('citec', 1, [842]),
#  ('onboard', 1, [666]),
#  ('httpstcoihyjn6az2i', 1, [242]),
#  ('eaten', 1, [1033]),
#  ('httpstco7whgqt8bmg', 1, [398]),
#  ('into',
#   14,
#   [9, 50, 73, 88, 303, 396, 669, 692, 722, 726, 746, 754, 774, 839]),
#  ('store', 1, [217]),
#  ('httpstcolwpdzh4kyi', 1, [651]),
#  ('measurecomput', 1, [80]),
#  ('akademischen', 1, [188]),
#  ('championn', 1, [923]),
#  ('solliancesolar', 1, [419]),
#  ('prospérité', 1, [26]),
#  ('go', 12, [323, 347, 430, 471, 525, 542, 572, 772, 981, 999, 1006, 1036]),
#  ('someon', 3, [134, 778, 791]),
#  ('compt', 1, [627]),
#  ('swisstech', 1, [992]),
#  ('off', 7, [17, 33, 230, 413, 465, 643, 1004]),
#  ('quand', 4, [12, 183, 208, 823]),
#  ('although', 1, [685]),
#  ('solutionssolar', 1, [980]),
#  ('httpstcob1rcngnblz', 2, [213, 479]),
#  ('symposium', 3, [28, 481, 807]),
#  ('hubaux', 2, [182, 724]),
#  ('enrol', 1, [41]),
#  ('doehlergroup', 1, [522]),
#  ('eat', 1, [813]),
#  ('vom', 1, [1015]),
#  ('réservez', 1, [1048]),
#  ('httpstcowpllsit0kd', 1, [253]),
#  ('beauti', 2, [458, 601]),
#  ('traver', 3, [70, 351, 893]),
#  ('explor', 1, [134]),
#  ('sbb', 1, [250]),
#  ('httpstco2sdcrepbwj', 1, [158]),
#  ('httpstco3zvz8pwqlc', 1, [852]),
#  ('ski', 1, [786]),
#  ('httpstcolcs564yavr', 1, [98]),
#  ('ml', 7, [34, 97, 347, 501, 691, 899, 899]),
#  ('verifi', 1, [581]),
#  ('learn',
#   27,
#   [33,
#    60,
#    176,
#    194,
#    208,
#    229,
#    231,
#    337,
#    347,
#    347,
#    390,
#    390,
#    411,
#    426,
#    464,
#    587,
#    600,
#    613,
#    623,
#    747,
#    859,
#    872,
#    888,
#    899,
#    974,
#    1009,
#    1048]),
#  ('horizon2020ict', 1, [457]),
#  ('yosef', 1, [910]),
#  ('httpstcoeituenfoax', 1, [81]),
#  ('softwar', 4, [314, 485, 562, 831]),
#  ('pfurrer', 1, [346]),
#  ('corpor', 1, [957]),
#  ('httpstcofmf9ged4km', 1, [901]),
#  ('nvmt', 1, [77]),
#  ('cltucci', 2, [19, 470]),
#  ('coder', 2, [347, 1047]),
#  ('tisseo', 1, [857]),
#  ('nm2', 1, [135]),
#  ('lutolf', 1, [607]),
#  ('nespresso', 1, [951]),
#  ('swissnexindia', 1, [143]),
#  ('y', 3, [287, 682, 1024]),
#  ('httpstco2vtdqhgppr', 1, [532]),
#  ('prenant', 1, [794]),
#  ('spécifiqu', 2, [742, 840]),
#  ('httpstcoevqyqd7ffl', 1, [30]),
#  ('universitelav', 1, [554]),
#  ('bah', 1, [265]),
#  ('objectif', 1, [996]),
#  ('compact', 1, [66]),
#  ('embol', 1, [446]),
#  ('oskarfreysing', 1, [979]),
#  ('theori', 2, [535, 750]),
#  ('jeux', 1, [893]),
#  ('httpstcofpkkytclij', 1, [972]),
#  ('artlab', 3, [174, 363, 895]),
#  ('authorprofil', 1, [550]),
#  ('httpstcobezxs7dnvg', 1, [273]),
#  ('nettra', 1, [635]),
#  ('mayb', 2, [312, 938]),
#  ('rabelai', 1, [238]),
#  ('liker', 1, [366]),
#  ('cerveau', 1, [362]),
#  ('httpstcouhcezifc7t', 1, [347]),
#  ('httpstcolypd9fhvlx', 1, [535]),
#  ('httpstcozmvfhhyhli', 1, [141]),
#  ('est',
#   15,
#   [61,
#    252,
#    382,
#    604,
#    627,
#    627,
#    627,
#    659,
#    665,
#    729,
#    766,
#    929,
#    996,
#    1016,
#    1031]),
#  ('snsf', 2, [720, 756]),
#  ('2nd', 3, [391, 393, 899]),
#  ('httpstcolxigtfhnyz', 1, [534]),
#  ('débusqu', 2, [405, 424]),
#  ('toholdaquil', 1, [314]),
#  ('industri', 8, [64, 158, 212, 492, 657, 863, 933, 1036]),
#  ('httpstcoel8rjs7wc1', 1, [766]),
#  ('attest', 1, [752]),
#  ('900', 1, [337]),
#  ('ericdubay', 2, [99, 240]),
#  ('return', 1, [221]),
#  ('ulb', 1, [633]),
#  ('msc', 1, [323]),
#  ('galaxi', 1, [410]),
#  ('httpstco1oxxxs6mg', 1, [1064]),
#  ('ration', 1, [739]),
#  ('cant', 1, [359]),
#  ('belgianthem', 1, [875]),
#  ('präsident', 1, [1015]),
#  ('bilanmagazin', 1, [243]),
#  ('hp1a', 2, [66, 959]),
#  ('somat', 1, [734]),
#  ('mahgenev', 1, [243]),
#  ('httpstcoho0yhh1i4b', 1, [60]),
#  ('relat', 1, [103]),
#  ('nsf', 1, [697]),
#  ('illustré', 1, [739]),
#  ('guess', 1, [1060]),
#  ('unibern', 2, [223, 489]),
#  ('almost', 1, [471]),
#  ('httpstcovhv9ame2i2', 1, [74]),
#  ('httpstconkalr6x1z0', 1, [513]),
#  ('compétitivité', 1, [26]),
#  ('professionnel', 2, [244, 261]),
#  ('sxsw', 3, [50, 215, 722]),
#  ('httpstco6epuivmddz', 1, [586]),
#  ('vsco', 1, [326]),
#  ('httpstcoktstr2m5yi', 1, [984]),
#  ('advantag', 1, [341]),
#  ('cleantech', 1, [813]),
#  ('tf1', 1, [744]),
#  ('httpstcoynvyv7enuk', 1, [222]),
#  ('leaf', 1, [237]),
#  ('coldion', 1, [661]),
#  ('microchip', 1, [636]),
#  ('case', 3, [635, 704, 845]),
#  ('manufactur', 1, [375]),
#  ('key', 1, [643]),
#  ('dargent', 1, [927]),
#  ('graphen', 3, [395, 642, 695]),
#  ('medic', 2, [514, 695]),
#  ('auch', 2, [319, 890]),
#  ('sarah', 1, [919]),
#  ('gruenebw', 3, [1057, 1058, 1059]),
#  ('carandach', 1, [475]),
#  ('pist', 1, [1039]),
#  ('social', 4, [292, 292, 783, 1031]),
#  ('xma', 1, [263]),
#  ('associ', 2, [207, 457]),
#  ('wirkung', 1, [49]),
#  ('venture2018', 3, [445, 506, 613]),
#  ('seen', 2, [691, 751]),
#  ('3d', 7, [109, 193, 206, 332, 544, 544, 680]),
#  ('httpstcoc4nv8d9eay', 1, [650]),
#  ('pleurobot', 1, [95]),
#  ('access', 6, [107, 107, 348, 878, 911, 917]),
#  ('univantil', 1, [554]),
#  ('undergrad', 1, [88]),
#  ('librari', 6, [125, 136, 136, 326, 466, 655]),
#  ('around', 4, [290, 614, 689, 764]),
#  ('httpstcoxivngafghi', 1, [871]),
#  ('event', 13, [15, 27, 33, 62, 180, 420, 471, 559, 605, 762, 874, 973, 987]),
#  ('danss', 1, [1030]),
#  ('vote', 2, [903, 1042]),
#  ('share', 7, [310, 341, 346, 438, 613, 944, 960]),
#  ('wonderqueen', 1, [764]),
#  ('solarpanel', 1, [155]),
#  ('whole', 2, [95, 691]),
#  ('securityprivaci', 1, [640]),
#  ('étude', 7, [282, 331, 571, 584, 794, 896, 1068]),
#  ('httpstco6yp1ywa7ww', 1, [206]),
#  ('apprendr', 5, [118, 311, 827, 827, 1026]),
#  ('reiter', 1, [104]),
#  ('feet', 1, [649]),
#  ('invas', 1, [32]),
#  ('httpstcojcpt6xyjzm', 1, [832]),
#  ('less', 6, [64, 323, 531, 778, 809, 979]),
#  ('httpstcobpnpc47k3l', 1, [746]),
#  ('produktivität', 1, [425]),
#  ('httpstcoealk3tvsem', 1, [958]),
#  ('consanguin', 1, [112]),
#  ('wind', 2, [150, 1055]),
#  ('évaluat', 2, [167, 252]),
#  ('jchenal', 3, [976, 977, 1010]),
#  ('httpstcob539k4mylr', 1, [637]),
#  ('vulnérabilité', 1, [1031]),
#  ('httpstcoorznq4ra90', 1, [377]),
#  ('httpstcome5kez2lh2', 1, [542]),
#  ('bbc', 3, [216, 634, 634]),
#  ('thingofbeauti', 1, [749]),
#  ('httpstcoz9peeqtzc', 1, [788]),
#  ('incubateur', 1, [297]),
#  ('steven', 1, [746]),
#  ('httpstcofhj9vlbq5r', 1, [1035]),
#  ('cryptosecur', 2, [213, 479]),
#  ('autonom', 2, [292, 1008]),
#  ('deepartio', 1, [612]),
#  ('atomtron', 1, [431]),
#  ('cela', 2, [356, 392]),
#  ('2030agenda', 1, [541]),
#  ('supsich', 1, [346]),
#  ('httpstcoqein9qwqol', 1, [968]),
#  ('billard', 1, [118]),
#  ('httpstcoggucszbsxr', 1, [523]),
#  ('rape', 2, [122, 979]),
#  ('httpstcoc4xprlshiy', 1, [346]),
#  ('httpstcoponztf3vft', 1, [778]),
#  ('st', 2, [175, 272]),
#  ('🚄', 1, [382]),
#  ('httpstcocmx5oahu6a', 1, [446]),
#  ('inaugur', 3, [106, 273, 826]),
#  ('sdscdatasci', 7, [235, 295, 443, 480, 610, 982, 984]),
#  ('magistrale2017', 3, [191, 593, 1019]),
#  ('healthi', 3, [131, 532, 997]),
#  ('spun', 1, [1014]),
#  ('sciencebiencomm', 1, [393]),
#  ('httpstcouyp6thrhbm', 1, [564]),
#  ('efficacité', 1, [644]),
#  ('blockfest', 1, [561]),
#  ('pv', 2, [184, 913]),
#  ('jesusmessiah7', 1, [52]),
#  ('prochain', 1, [252]),
#  ('highthroughput', 2, [545, 663]),
#  ('technionl', 1, [522]),
#  ('collegium', 1, [304]),
#  ('httpstco3rjiief5ag', 1, [995]),
#  ('httpstcoj3gzqu9pqa', 1, [705]),
#  ('rt', 8, [69, 144, 566, 566, 573, 573, 732, 1029]),
#  ('edtechaccelch', 1, [222]),
#  ('gosh', 1, [393]),
#  ('nazi', 1, [979]),
#  ('httpstcokcwnh9i9sf', 1, [396]),
#  ('challeng', 6, [71, 158, 267, 492, 657, 724]),
#  ('predict', 2, [127, 557]),
#  ('evidencebas', 1, [126]),
#  ('httpstcosiaunzx3f8', 1, [132]),
#  ('worth', 1, [650]),
#  ('ces2017', 1, [460]),
#  ('genom', 4, [228, 284, 352, 358]),
#  ('mai', 7, [202, 265, 439, 592, 740, 844, 925]),
#  ('httpstcod76buifpkw', 1, [952]),
#  ('risqu', 2, [185, 1048]),
#  ('note', 2, [682, 840]),
#  ('tlemberg', 1, [629]),
#  ('richter', 1, [1053]),
#  ('scaday', 1, [862]),
#  ('httpstcobuda7w2icm', 1, [629]),
#  ('plasmon', 1, [113]),
#  ('mal', 2, [96, 789]),
#  ('mobilis', 1, [541]),
#  ('trouverez', 1, [342]),
#  ('httpstconsylbiszna', 1, [273]),
#  ('httpstco462ghoecml', 1, [1033]),
#  ('httpstcojovwcjqzeh', 1, [903]),
#  ('crispri', 1, [513]),
#  ('httpstcorsfg9abopb', 1, [875]),
#  ('mlaniepron1', 1, [472]),
#  ('httpstcofzp3zsaqyn', 1, [17]),
#  ('26th', 1, [447]),
#  ('moham', 1, [861]),
#  ('httpstcoixjnhrirwi', 1, [97]),
#  ('uzh', 1, [905]),
#  ('pribabl', 1, [535]),
#  ('httpstcoancm3qlido', 1, [25]),
#  ('polytechniqu', 5, [98, 164, 482, 841, 1062]),
#  ('caution', 2, [185, 185]),
#  ('fulli', 2, [457, 660]),
#  ('verbeek', 1, [915]),
#  ('paus', 1, [207]),
#  ('bürgi', 1, [948]),
#  ('drpetti', 2, [320, 381]),
#  ('grave', 1, [922]),
#  ('popular', 3, [407, 490, 1056]),
#  ('luckili', 1, [1013]),
#  ('touchscreen', 1, [878]),
#  ('syndic', 1, [857]),
#  ('arbeitsplätz', 1, [425]),
#  ('httpstcogq9outmsd4', 1, [399]),
#  ('httpstcowo4wo77xm2', 1, [639]),
#  ('nanocrystallit', 1, [303]),
#  ('music', 4, [221, 221, 394, 750]),
#  ('mass', 2, [624, 745]),
#  ('durabl', 1, [996]),
#  ('détecter', 1, [892]),
#  ('design',
#   15,
#   [83, 133, 138, 260, 260, 453, 493, 511, 518, 669, 692, 703, 714, 798, 906]),
#  ('rewalkrobot', 1, [871]),
#  ('databas', 2, [133, 415]),
#  ('innat', 1, [833]),
#  ('deciph', 2, [755, 809]),
#  ('meet',
#   25,
#   [95,
#    98,
#    143,
#    203,
#    225,
#    270,
#    274,
#    305,
#    306,
#    323,
#    339,
#    459,
#    487,
#    489,
#    578,
#    588,
#    601,
#    607,
#    629,
#    643,
#    679,
#    699,
#    733,
#    748,
#    1008]),
#  ('ever', 6, [178, 328, 407, 527, 608, 908]),
#  ('httpstcojogvkdfeln', 1, [953]),
#  ('httpstcoyx312g9r4i', 1, [159]),
#  ('goal', 1, [126]),
#  ('httpstcoqgyot0yvzn', 1, [545]),
#  ('ein', 5, [49, 209, 638, 721, 721]),
#  ('matrixbind', 1, [349]),
#  ('gold', 1, [577]),
#  ('democrat', 1, [614]),
#  ('zusammen', 1, [105]),
#  ('ehr', 1, [25]),
#  ('iranian', 2, [359, 556]),
#  ('compos', 2, [452, 942]),
#  ('alexandr', 1, [69]),
#  ('httpstcoiiqto9dkut', 1, [548]),
#  ('httpstcohtaq0sxygw', 1, [660]),
#  ('je', 11, [12, 61, 161, 199, 199, 439, 467, 862, 988, 1030, 1054]),
#  ('manag', 4, [510, 515, 640, 673]),
#  ('httpstcosrdnowtcyu', 1, [517]),
#  ('circl', 1, [340]),
#  ('enjeux', 3, [62, 978, 1042]),
#  ('neue', 2, [167, 638]),
#  ('summer', 3, [28, 78, 535]),
#  ('prixbcninnovation17', 1, [568]),
#  ('recommand', 1, [603]),
#  ('deliveri', 1, [1061]),
#  ('httpstcox7zx3pfsfv', 1, [845]),
#  ('wcsj2017', 1, [594]),
#  ('unicef', 1, [143]),
#  ('représent', 1, [989]),
#  ('httpstcobmpozyou0x', 1, [922]),
#  ('httpstcor3t1sszogo', 1, [564]),
#  ('lordsofmap', 1, [772]),
#  ('plenti', 3, [34, 485, 813]),
#  ('httpstcoidxc7gqulf', 1, [797]),
#  ('httpstcot9bil1adqz', 1, [688]),
#  ('gener', 9, [117, 303, 396, 459, 685, 760, 762, 858, 865]),
#  ('neuchatel', 1, [971]),
#  ('a…', 1, [426]),
#  ('canard', 1, [1052]),
#  ('reprendr', 1, [207]),
#  ('630pm', 1, [390]),
#  ('savoirpati', 1, [1035]),
#  ('enjoy', 1, [575]),
#  ('edtech', 6, [91, 222, 273, 273, 386, 652]),
#  ('httpstcoqnijn705t9', 1, [1065]),
#  ('formula', 1, [260]),
#  ('🙏🏻', 1, [418]),
#  ('scorth', 1, [1017]),
#  ('httpstcow4ax9gcawo', 1, [440]),
#  ('visuallyimpair', 2, [435, 878]),
#  ('countdown', 1, [868]),
#  ('chaîn', 1, [12]),
#  ('adress', 1, [197]),
#  ('architectur', 9, [77, 123, 232, 376, 453, 455, 714, 788, 788]),
#  ('feedback', 3, [668, 708, 864]),
#  ('get',
#   19,
#   [5,
#    211,
#    222,
#    348,
#    352,
#    390,
#    464,
#    554,
#    557,
#    649,
#    688,
#    719,
#    941,
#    953,
#    979,
#    985,
#    1006,
#    1046,
#    1065]),
#  ('taught', 1, [164]),
#  ('photovolta', 2, [757, 1004]),
#  ('recherch', 6, [16, 168, 197, 569, 892, 1023]),
#  ('young', 6, [259, 264, 489, 531, 1046, 1065]),
#  ('se', 12, [26, 168, 244, 437, 495, 627, 653, 784, 815, 874, 896, 978]),
#  ('tara', 1, [748]),
#  ('progress', 3, [935, 937, 1053]),
#  ('high', 6, [428, 446, 611, 637, 639, 1055]),
#  ('rail', 1, [567]),
#  ('florislondon', 1, [582]),
#  ('asemday', 1, [270]),
#  ('httpstcoxlbsoh30io', 1, [966]),
#  ('mainten', 3, [307, 567, 1019]),
#  ('sconnect', 1, [62]),
#  ('land', 1, [451]),
#  ('httpstcommrkgwkdhp', 1, [538]),
#  ('vu', 1, [130]),
#  ('1', 11, [30, 61, 100, 121, 266, 422, 471, 572, 880, 936, 1031]),
#  ('mindblow', 1, [1014]),
#  ('start',
#   17,
#   [31,
#    134,
#    230,
#    255,
#    257,
#    260,
#    274,
#    288,
#    359,
#    441,
#    656,
#    719,
#    910,
#    975,
#    984,
#    998,
#    1015]),
#  ('httpstcowyhpdhbcq1', 1, [821]),
#  ('sportscrunchind', 1, [291]),
#  ('lifeinnyon', 1, [192]),
#  ('fabriqu', 1, [877]),
#  ('httpstco5t7egh0quw', 1, [29]),
#  ('einem', 1, [241]),
#  ('lacadémi', 1, [1022]),
#  ('10h', 1, [243]),
#  ('oscienc', 9, [24, 67, 111, 153, 328, 355, 527, 811, 932]),
#  ('sign', 5, [426, 436, 866, 873, 982]),
#  ('physicaltherapi', 1, [444]),
#  ('interiordesign', 1, [232]),
#  ('boschglob', 1, [522]),
#  ('storag', 3, [117, 558, 575]),
#  ('httpstco66xc0kojlp', 1, [487]),
#  ('data',
#   22,
#   [27,
#    34,
#    80,
#    117,
#    125,
#    250,
#    315,
#    415,
#    426,
#    442,
#    443,
#    466,
#    466,
#    558,
#    600,
#    625,
#    666,
#    673,
#    685,
#    741,
#    930,
#    957]),
#  ('avc', 1, [43]),
#  ('httpstcohjbhwul4pv', 1, [979]),
#  ('nationaltrust', 1, [630]),
#  ('vie', 2, [266, 705]),
#  ('httpstcoumkzw0yvo0', 1, [820]),
#  ('incontro', 1, [851]),
#  ('rencontrez', 1, [1035]),
#  ('modèl', 1, [149]),
#  ('collaboratif', 2, [304, 385]),
#  ('molecularscal', 1, [303]),
#  ('golang', 1, [347]),
#  ('prise', 1, [665]),
#  ('umrcarrtel', 1, [766]),
#  ('think', 9, [63, 82, 260, 333, 556, 692, 768, 812, 938]),
#  ('suivr', 3, [417, 780, 892]),
#  ('fulltext', 1, [469]),
#  ('spheroid', 1, [100]),
#  ('tesla', 1, [209]),
#  ('show', 12, [17, 189, 230, 380, 609, 671, 764, 765, 790, 838, 864, 1002]),
#  ('httpstcoszexxfm9bt', 1, [322]),
#  ('insiscnr', 1, [304]),
#  ('stellar', 1, [269]),
#  ('dindin', 3, [787, 787, 787]),
#  ('patient', 3, [566, 972, 1035]),
#  ('medal', 1, [413]),
#  ('conscious', 1, [497]),
#  ('énergétiqu', 1, [644]),
#  ('droit', 1, [939]),
#  ('augmenté', 1, [408]),
#  ('silkroad', 1, [530]),
#  ('trekkinglemon', 2, [60, 310]),
#  ('httpstcoli5nturtjh', 1, [596]),
#  ('worldwid', 1, [631]),
#  ('cwarwarrior', 1, [810]),
#  ('accord', 3, [71, 112, 140]),
#  ('lîlot', 1, [952]),
#  ('httpstcojosupjdg7k', 1, [14]),
#  ('traitant', 1, [840]),
#  ('partir', 1, [840]),
#  ('polimi', 1, [639]),
#  ('venture2017', 2, [445, 974]),
#  ('httpstconjovod2dsn', 1, [243]),
#  ('létudi', 1, [893]),
#  ('httpstco9jgkw9qz6x', 1, [550]),
#  ('labiotecheu', 1, [879]),
#  ('httpstcodntchhce5l', 1, [541]),
#  ('entr', 4, [304, 304, 345, 925]),
#  ('empach', 2, [785, 984]),
#  ('sportif', 1, [129]),
#  ('instal', 8, [115, 152, 155, 473, 517, 627, 853, 968]),
#  ('httpstcoscnzxhptgu', 1, [303]),
#  ('evot', 1, [903]),
#  ('jenmccutcheon', 1, [108]),
#  ('critic', 2, [150, 292]),
#  ('ee', 1, [875]),
#  ('giulia', 1, [633]),
#  ('epflsv', 6, [30, 98, 365, 509, 509, 593]),
#  ('léducat', 2, [297, 382]),
#  ('techforgood', 1, [635]),
#  ('httpstco27enjydfx9', 1, [978]),
#  ('httpstcoepymyqckzw', 1, [1048]),
#  ('httpstcoks6eqjapqi', 1, [417]),
#  ('httpstcogbftwzax5f', 1, [808]),
#  ('sustain', 7, [229, 401, 510, 669, 669, 748, 915]),
#  ('warn', 1, [655]),
#  ('counterpart', 2, [216, 634]),
#  ('begin', 3, [471, 605, 625]),
#  ('asia', 2, [270, 531]),
#  ('dimer', 1, [170]),
#  ('glare', 1, [770]),
#  ('18h00', 1, [453]),
#  ('competit', 7, [364, 390, 390, 464, 506, 974, 1041]),
#  ('confess', 1, [122]),
#  ('hackuarium', 1, [176]),
#  ('breakfast', 1, [1013]),
#  ('womensmarch', 2, [281, 582]),
#  ('overlayjourn', 1, [799]),
#  ('httpstco2vqqgqhact', 1, [11]),
#  ('gehendragurung', 1, [350]),
#  ('ma', 4, [261, 392, 752, 988]),
#  ('former', 5, [390, 493, 741, 874, 978]),
#  ('immun', 6, [264, 352, 365, 529, 547, 879]),
#  ('geotherm', 2, [79, 79]),
#  ('reportag', 3, [244, 302, 744]),
#  ('roberv', 1, [710]),
#  ('bionic', 1, [725]),
#  ('httpstcopzhx72iq33', 1, [945]),
#  ('surprisingli', 1, [87]),
#  ('ict4dev', 1, [46]),
#  ('dies', 1, [451]),
#  ('cad', 1, [603]),
#  ('httpstcodcuyrn9fng', 1, [606]),
#  ('httpstcoigesfw6leg', 1, [781]),
#  ('httpstcornarscdjil', 1, [496]),
#  ('dominiqueforay', 2, [126, 704]),
#  ('poulet', 1, [927]),
#  ('appreci', 1, [151]),
#  ('superglaz', 1, [231]),
#  ('26', 1, [990]),
#  ('she', 1, [270]),
#  ('gesisorg', 1, [935]),
#  ('materialwissenschaft', 1, [309]),
#  ('split', 1, [918]),
#  ('☔', 1, [1009]),
#  ('irak', 1, [1067]),
#  ('du',
#   41,
#   [12,
#    20,
#    26,
#    56,
#    63,
#    123,
#    182,
#    243,
#    304,
#    304,
#    311,
#    356,
#    388,
#    495,
#    565,
#    569,
#    592,
#    604,
#    653,
#    766,
#    780,
#    782,
#    800,
#    842,
#    851,
#    862,
#    894,
#    895,
#    902,
#    923,
#    924,
#    947,
#    958,
#    961,
#    967,
#    1016,
#    1030,
#    1042,
#    1043,
#    1063,
#    1068]),
#  ('nikola', 1, [805]),
#  ('httpstcofh09qifrdh', 1, [482]),
#  ('httpstco2va71avjyg', 1, [841]),
#  ('solut', 5, [109, 217, 318, 687, 842]),
#  ('wo', 1, [438]),
#  ('regain', 1, [970]),
#  ('uniofread', 1, [522]),
#  ('replac', 1, [572]),
#  ('jfellay', 1, [922]),
#  ('fret', 1, [959]),
#  ('stay', 5, [78, 125, 722, 813, 836]),
#  ('envirobot', 3, [145, 828, 1008]),
#  ('soumen', 1, [748]),
#  ('httpstcozj5yvdq6w8', 1, [560]),
#  ('httpstcoubvaih1mjp', 1, [711]),
#  ('httpstcodnot4oimmv', 1, [969]),
#  ('talk',
#   26,
#   [27,
#    68,
#    120,
#    213,
#    227,
#    258,
#    287,
#    365,
#    376,
#    431,
#    433,
#    459,
#    466,
#    474,
#    503,
#    513,
#    518,
#    545,
#    575,
#    607,
#    663,
#    733,
#    757,
#    802,
#    869,
#    928]),
#  ('httpstcofhtmlunack', 1, [52]),
#  ('mess', 1, [48]),
#  ('tmech', 1, [407]),
#  ('httpstco5mf6xxcaih', 1, [103]),
#  ('httpstcovnvszikvoc', 1, [415]),
#  ('pollut', 3, [145, 926, 1008]),
#  ('erc', 1, [717]),
#  ('largest', 7, [152, 158, 471, 473, 517, 853, 968]),
#  ('sequencedirect', 1, [378]),
#  ('wsl', 1, [526]),
#  ('xaviercoad', 1, [472]),
#  ('jorgensundberg', 1, [232]),
#  ('expscifilm17', 2, [301, 339]),
#  ('long', 4, [26, 246, 948, 1012]),
#  ('intelligenz', 1, [737]),
#  ('color', 1, [684]),
#  ('zebrafish', 1, [249]),
#  ('👌elektromobilitaet', 1, [1011]),
#  ('inscrut', 1, [236]),
#  ('nanoparticl', 1, [577]),
#  ('allen', 1, [449]),
#  ('httpstco8f4bnl7aa', 1, [458]),
#  ('date', 5, [339, 441, 464, 887, 1060]),
#  ('httpstcotlieahzlsd', 1, [232]),
#  ('tune', 5, [78, 125, 374, 432, 813]),
#  ('julio', 1, [231]),
#  ('5ten', 1, [1011]),
#  ('soulag', 2, [300, 837]),
#  ('projet',
#   13,
#   [12, 205, 304, 386, 403, 567, 569, 740, 780, 857, 955, 1024, 1037]),
#  ('httpstco3vujybmevd', 1, [341]),
#  ('unil',
#   21,
#   [15,
#    42,
#    52,
#    192,
#    219,
#    238,
#    258,
#    265,
#    301,
#    339,
#    489,
#    586,
#    674,
#    720,
#    727,
#    730,
#    780,
#    925,
#    961,
#    1025,
#    1063]),
#  ('filigran', 1, [451]),
#  ('commenc', 3, [331, 452, 1063]),
#  ('organisateur', 1, [1020]),
#  ('httpstcovu27gw28in', 1, [455]),
#  ('swisscytometri', 8, [98, 98, 203, 509, 509, 509, 509, 578]),
#  ('territoirela', 1, [851]),
#  ('httpstcoluraa7vj2c', 1, [261]),
#  ('fhaptic', 1, [102]),
#  ('bild', 3, [1057, 1058, 1059]),
#  ('train', 5, [116, 200, 391, 557, 775]),
#  ('carinadjey', 1, [233]),
#  ('avion', 1, [815]),
#  ('httpstconpfe5lge1a', 1, [520]),
#  ('tableau', 1, [311]),
#  ('httpstcore0xb2vbz0', 1, [536]),
#  ('gixedu', 1, [106]),
#  ('ictpnew', 1, [663]),
#  ('mang', 1, [927]),
#  ('déjà', 2, [168, 996]),
#  ('dtu', 1, [648]),
#  ('srsa', 1, [1066]),
#  ('dnasequenc', 1, [159]),
#  ('httpstco0whox0aktr', 1, [109]),
#  ('httpstcoerqa06qoiy', 1, [62]),
#  ('httpstco6pgdtcpyhq', 1, [817]),
#  ('électroniqu', 1, [265]),
#  ('httpstcojaqq6zqkdc', 1, [358]),
#  ('idtechexshow', 1, [642]),
#  ('art', 5, [210, 210, 243, 316, 969]),
#  ('httpstcou1ottqcvlu', 1, [145]),
#  ('httpstcos48gvdstqa', 1, [943]),
#  ('bâtiment', 3, [644, 1023, 1070]),
#  ('haenni', 1, [903]),
#  ('win', 5, [77, 175, 267, 272, 688]),
#  ('achiev', 4, [397, 448, 519, 681]),
#  ('proje…', 1, [93]),
#  ('glisser', 1, [548]),
#  ('1989', 1, [720]),
#  ('dessin', 1, [462]),
#  ('post', 1, [286]),
#  ('mdeff', 1, [816]),
#  ('httpstcoazwevbdhvv', 1, [493]),
#  ('algebraictopolog', 1, [818]),
#  ('ukni', 1, [215]),
#  ('httpstcowsosmmrtbl', 1, [974]),
#  ('erlaubt', 1, [638]),
#  ('emeritu', 1, [762]),
#  ('park', 1, [209]),
#  ('cv', 1, [674]),
#  ('rade', 1, [11]),
#  ('httpstcomyyi0qn04g', 1, [745]),
#  ('httpstco7e2mgk4jiu', 1, [338]),
#  ('magistretti', 1, [741]),
#  ('httpstcof8lulsdz04', 1, [676]),
#  ('her', 2, [359, 808]),
#  ('entré', 1, [782]),
#  ('swissedtechcollid', 3, [91, 143, 273]),
#  ('httpstco1kcnfc67xr', 1, [996]),
#  ('httpstcoveig9f8bpl', 1, [35]),
#  ('fems2017', 4, [55, 498, 809, 991]),
#  ('httpstco0bajjgzvtj', 1, [465]),
#  ('sport', 1, [471]),
#  ('hessovalai', 5, [130, 200, 205, 742, 829]),
#  ('proposé', 3, [261, 844, 862]),
#  ('httpstcojpwhjdpxsu', 1, [891]),
#  ('smartpark', 1, [963]),
#  ('digital', 3, [384, 565, 822]),
#  ('aura', 5, [144, 243, 252, 902, 958]),
#  ('informat', 1, [116]),
#  ('httpstcogyh0xlimff', 1, [704]),
#  ('ieeeorg', 1, [77]),
#  ('dure', 10, [89, 107, 173, 245, 333, 341, 854, 931, 999, 1013]),
#  ('uniqu', 3, [801, 883, 884]),
#  ('t', 5, [140, 278, 373, 691, 692]),
#  ('réell', 1, [794]),
#  ('tournament', 1, [535]),
#  ('fatherjenkin', 1, [936]),
#  ('gro', 1, [922]),
#  ('archimagredac', 2, [70, 351]),
#  ('socialimpact', 1, [589]),
#  ('either', 1, [791]),
#  ('franc', 9, [51, 150, 185, 304, 471, 546, 687, 806, 858]),
#  ('jeudi', 2, [569, 782]),
#  ('imperialcolleg', 2, [76, 933]),
#  ('page', 5, [247, 401, 615, 741, 776]),
#  ('lancement', 2, [233, 1016]),
#  ('fwd', 1, [951]),
#  ('vertical', 1, [766]),
#  ('sanfrancisco', 1, [963]),
#  ('jet', 2, [90, 115]),
#  ('quelqu', 3, [325, 402, 939]),
#  ('epfl',
#   694,
#   [2,
#    4,
#    5,
#    6,
#    8,
#    9,
#    10,
#    11,
#    15,
#    16,
#    18,
#    20,
#    22,
#    23,
#    25,
#    26,
#    27,
#    28,
#    29,
#    31,
#    31,
#    32,
#    33,
#    34,
#    40,
#    40,
#    42,
#    43,
#    44,
#    46,
#    47,
#    49,
#    52,
#    57,
#    59,
#    60,
#    61,
#    62,
#    63,
#    64,
#    68,
#    69,
#    70,
#    74,
#    75,
#    77,
#    81,
#    83,
#    85,
#    86,
#    87,
#    88,
#    90,
#    92,
#    93,
#    96,
#    98,
#    102,
#    104,
#    105,
#    106,
#    107,
#    107,
#    108,
#    109,
#    112,
#    115,
#    116,
#    117,
#    118,
#    123,
#    124,
#    125,
#    126,
#    129,
#    130,
#    131,
#    132,
#    133,
#    135,
#    136,
#    137,
#    138,
#    141,
#    143,
#    144,
#    145,
#    149,
#    150,
#    154,
#    157,
#    158,
#    160,
#    161,
#    162,
#    163,
#    164,
#    165,
#    166,
#    167,
#    168,
#    168,
#    171,
#    171,
#    172,
#    174,
#    174,
#    175,
#    176,
#    177,
#    178,
#    180,
#    181,
#    183,
#    184,
#    185,
#    188,
#    188,
#    189,
#    190,
#    191,
#    191,
#    192,
#    193,
#    194,
#    197,
#    197,
#    201,
#    202,
#    203,
#    205,
#    207,
#    208,
#    209,
#    210,
#    212,
#    213,
#    215,
#    216,
#    217,
#    218,
#    220,
#    225,
#    226,
#    229,
#    230,
#    231,
#    232,
#    233,
#    238,
#    239,
#    241,
#    243,
#    244,
#    245,
#    246,
#    247,
#    248,
#    249,
#    250,
#    250,
#    252,
#    253,
#    255,
#    255,
#    258,
#    259,
#    260,
#    261,
#    262,
#    264,
#    265,
#    266,
#    267,
#    268,
#    272,
#    273,
#    274,
#    275,
#    276,
#    280,
#    282,
#    283,
#    284,
#    287,
#    289,
#    290,
#    291,
#    292,
#    296,
#    297,
#    299,
#    300,
#    301,
#    302,
#    303,
#    304,
#    306,
#    307,
#    309,
#    310,
#    310,
#    311,
#    312,
#    313,
#    314,
#    315,
#    316,
#    317,
#    320,
#    322,
#    323,
#    325,
#    326,
#    327,
#    329,
#    330,
#    331,
#    334,
#    335,
#    339,
#    342,
#    343,
#    345,
#    347,
#    350,
#    351,
#    352,
#    353,
#    356,
#    357,
#    359,
#    360,
#    362,
#    363,
#    366,
#    367,
#    368,
#    369,
#    370,
#    371,
#    371,
#    373,
#    375,
#    378,
#    380,
#    381,
#    382,
#    383,
#    384,
#    386,
#    387,
#    388,
#    390,
#    390,
#    391,
#    393,
#    402,
#    403,
#    404,
#    405,
#    407,
#    408,
#    409,
#    411,
#    413,
#    416,
#    419,
#    423,
#    424,
#    427,
#    428,
#    429,
#    431,
#    432,
#    435,
#    436,
#    437,
#    438,
#    439,
#    440,
#    440,
#    443,
#    444,
#    444,
#    446,
#    448,
#    449,
#    451,
#    452,
#    453,
#    454,
#    455,
#    456,
#    458,
#    459,
#    460,
#    462,
#    463,
#    464,
#    466,
#    467,
#    470,
#    471,
#    472,
#    475,
#    476,
#    477,
#    479,
#    481,
#    487,
#    488,
#    489,
#    491,
#    492,
#    494,
#    494,
#    495,
#    496,
#    497,
#    500,
#    501,
#    503,
#    506,
#    509,
#    509,
#    514,
#    518,
#    523,
#    525,
#    526,
#    528,
#    529,
#    533,
#    536,
#    536,
#    537,
#    540,
#    541,
#    543,
#    544,
#    545,
#    545,
#    547,
#    550,
#    551,
#    552,
#    553,
#    553,
#    554,
#    555,
#    556,
#    559,
#    563,
#    564,
#    565,
#    566,
#    567,
#    568,
#    569,
#    570,
#    571,
#    572,
#    573,
#    574,
#    575,
#    577,
#    578,
#    585,
#    586,
#    588,
#    589,
#    592,
#    593,
#    594,
#    596,
#    599,
#    604,
#    607,
#    609,
#    610,
#    611,
#    614,
#    617,
#    618,
#    618,
#    619,
#    621,
#    623,
#    625,
#    626,
#    627,
#    628,
#    629,
#    631,
#    632,
#    633,
#    634,
#    636,
#    638,
#    640,
#    644,
#    647,
#    648,
#    650,
#    651,
#    653,
#    654,
#    655,
#    658,
#    662,
#    663,
#    663,
#    665,
#    666,
#    667,
#    672,
#    673,
#    674,
#    676,
#    677,
#    677,
#    679,
#    681,
#    682,
#    684,
#    685,
#    688,
#    689,
#    690,
#    695,
#    696,
#    697,
#    698,
#    700,
#    700,
#    701,
#    705,
#    706,
#    710,
#    711,
#    713,
#    715,
#    716,
#    719,
#    723,
#    724,
#    726,
#    727,
#    728,
#    729,
#    730,
#    731,
#    733,
#    734,
#    735,
#    737,
#    739,
#    742,
#    743,
#    744,
#    745,
#    746,
#    747,
#    748,
#    749,
#    749,
#    750,
#    752,
#    755,
#    756,
#    757,
#    762,
#    763,
#    763,
#    765,
#    767,
#    770,
#    773,
#    774,
#    775,
#    776,
#    780,
#    781,
#    782,
#    783,
#    784,
#    785,
#    786,
#    787,
#    788,
#    791,
#    794,
#    795,
#    796,
#    796,
#    797,
#    798,
#    799,
#    800,
#    800,
#    801,
#    804,
#    805,
#    806,
#    807,
#    808,
#    810,
#    814,
#    815,
#    817,
#    819,
#    820,
#    821,
#    822,
#    823,
#    824,
#    825,
#    826,
#    827,
#    828,
#    829,
#    830,
#    832,
#    835,
#    836,
#    837,
#    841,
#    842,
#    843,
#    844,
#    846,
#    847,
#    848,
#    849,
#    850,
#    851,
#    855,
#    859,
#    860,
#    860,
#    861,
#    862,
#    863,
#    864,
#    866,
#    870,
#    871,
#    872,
#    873,
#    874,
#    876,
#    878,
#    881,
#    882,
#    885,
#    885,
#    886,
#    887,
#    889,
#    890,
#    892,
#    893,
#    894,
#    895,
#    896,
#    899,
#    900,
#    901,
#    902,
#    903,
#    904,
#    905,
#    906,
#    907,
#    908,
#    911,
#    913,
#    915,
#    919,
#    920,
#    921,
#    922,
#    923,
#    924,
#    925,
#    926,
#    928,
#    929,
#    930,
#    931,
#    935,
#    940,
#    941,
#    942,
#    944,
#    945,
#    946,
#    946,
#    947,
#    948,
#    950,
#    951,
#    952,
#    953,
#    954,
#    955,
#    956,
#    958,
#    959,
#    960,
#    961,
#    962,
#    964,
#    964,
#    967,
#    969,
#    971,
#    974,
#    975,
#    976,
#    977,
#    978,
#    979,
#    981,
#    983,
#    985,
#    985,
#    986,
#    988,
#    989,
#    990,
#    996,
#    1001,
#    1003,
#    1003,
#    1004,
#    1005,
#    1008,
#    1009,
#    1010,
#    1013,
#    1015,
#    1016,
#    1017,
#    1018,
#    1019,
#    1020,
#    1021,
#    1022,
#    1023,
#    1024,
#    1025,
#    1026,
#    1030,
#    1031,
#    1032,
#    1033,
#    1034,
#    1035,
#    1036,
#    1037,
#    1038,
#    1039,
#    1040,
#    1041,
#    1042,
#    1043,
#    1044,
#    1045,
#    1045,
#    1046,
#    1047,
#    1048,
#    1049,
#    1050,
#    1051,
#    1052,
#    1053,
#    1054,
#    1060,
#    1061,
#    1061,
#    1062,
#    1063,
#    1064,
#    1065,
#    1066,
#    1067,
#    1068,
#    1069,
#    1070,
#    1071,
#    1071]),
#  ('httpstcoaskf9ui0mi', 1, [511]),
#  ('httpstcozdvowdckrx', 1, [93]),
#  ('würde', 1, [954]),
#  ('mar', 8, [24, 67, 153, 554, 782, 894, 902, 932]),
#  ('klok', 1, [336]),
#  ('httpstcowjzxyjg5iq', 1, [1040]),
#  ('holyghostalic', 1, [99]),
#  ('httpstco1vtjkucjfa', 1, [444]),
#  ('vraiment', 1, [627]),
#  ('httpstcoiklrksjqn5', 1, [213]),
#  ('montserrat', 1, [227]),
#  ('cio', 2, [1037, 1042]),
#  ('httpstcox62xhksp5f', 1, [846]),
#  ('philipp', 3, [162, 213, 479]),
#  ('twodimension', 2, [545, 663]),
#  ('africangeek', 1, [233]),
#  ('pse', 1, [776]),
#  ('purpos', 2, [444, 641]),
#  ('httpstcoaxxf5tgqj3', 1, [692]),
#  ('dariahteach', 1, [219]),
#  ('quil', 2, [287, 1024]),
#  ('fillett', 1, [742]),
#  ...]
